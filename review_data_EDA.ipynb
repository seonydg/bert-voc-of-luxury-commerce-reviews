# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import koreanize_matplotlib
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from preprocessing import get_reviews, get_preprocessing_reviews

# %%
data_dir = './data/'

# %%
df = get_reviews(data_dir)
df
# Out:
#        brand        user        date  \
# 0     balaan        굳맨굿맨  2023-09-07
# 1     balaan    짱구 아빠 엄마  2023-08-31
# 2     balaan       거울공주2  2023-08-29
# 3     balaan     땡글이1225  2023-08-25
# 4     balaan        차아암나  2023-08-24
# ...      ...         ...         ...
# 3955  trenbe  Google 사용자  2019-07-20
# 3956  trenbe  Google 사용자  2019-07-19
# 3957  trenbe  Google 사용자  2019-07-19
# 3958  trenbe  Google 사용자  2019-07-19
# 3959  trenbe  Google 사용자  2019-07-19
#
#                                                  review  star  label
# 0                                                아주 좋아오     5      1
# 1                             가격대비 완전만족 사이즈색상 의류감촉 최고에요     5      1
# 2     제품이 다양하고 가격도 저렴해서 눈팅 자주하고 구매도 해봅니다역시 물건 받아보니 믿...     5      1
# 3                                                 감사합니다     5      1
# 4     상품 개 구매함 오배송 건 포장불량 건 일 걸려 받은 답변  중간에서 업체와 연결하...     1      0
# ...                                                 ...   ...    ...
# 3955                                                좋아요     5      1
# 3956                                           좋아요 백점만점     5      1
# 3957        트렌비 자주 보는데 맨날 크롬 띄워서 봤는데 이젠 앱만 클릭하면 나오니 좋네요     5      1
# 3958                                           깔끔하고 좋아요     5      1
# 3959                   다른 명품앱은 느려서 너무 답답했는데 여기는 빨라서 좋아요     5      1
#
# [8964 rows x 6 columns]

# %%
df['label'].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
senti_data, cate_data, data = get_preprocessing_reviews(data_dir)

# %%
senti_data
# Out:
# [['월일에 주문에서 월일에 재고가 없어 환불처리 됐다고 통보하네요', 0],
#  ['어이가없어서 여기 믿고 물건 구매해서 안심하고 기다리다 뒤통수 맞고 다시 물건 찾는일 없도록 이용하지마세요', 0],
#  ['기다려도 물건 안와요', 0],
#  ['여기 상품반품비로 먹고사는 업체인것같습니다', 0],
#  ['나쁜놈들', 0],
#  ['가격이 넘 착해요', 1],
#  ['귀찮아서 리뷰 안 남기는데 너무 만족하고 잘 쓰고 있어요', 1],
#  [' 후기보는 재미도 있고요 후기보다가 급 지름신와서 텅장을 부여잡은게 한두번이 아니네요', 1],
#  ['지금도 제품 많지만 더 이쁘고 좋은거 마니 들어오면 좋겠어요', 1],
#  ['검색하다가 광고가 눈에 띄어 들어오게 되었는데 매장가보다 저렴하고', 1],
#  ['배송도 빠르게 와서 유용하게 잘 쓰고 있습니다', 1],
#  ['상품과 배송 모두 만족입니다', 1],
#  ['몽클 패딩 저렴하게 구입했습니다', 1],
#  ['추천추천', 1],
#  ['명품 쇼핑할때마다 너무 잘 쓰고 있어요', 1],
#  ['특히 오늘 배송상품 마음에 듭니다', 1],
#  ['알람설정해놓고 이벤트 참여하고 구경하는 것도 은근 재미있네요ㅋㅋ 랭킹메뉴도 자주 보는데 요즘 많이 사는 제품들 볼 수있어서 구매에도 도움이 됩니다',
#   1],
#  ['알람설정해놓고 이벤트 참여하고 구경하는 것도 은근 재미있네요ㅋㅋ 랭킹메뉴도 자주 보는데 요즘 많이 사는 제품들 볼 수있어서 구매에도 도움이 됩니다',
#   1],
#  ['좋은 앱 감사', 1],
#  ['다양한 브랜드를 한번에 볼수 있어서 편리해요', 1],
#  ['다양한 브랜드를 한번에 볼수 있어서 편리해요', 1],
#  ['카테고리 구분이나 필터 기능 잘 되있고', 1],
#  ['이벤트 많아 좋네요', 1],
#  ['편해요', 1],
#  ['제가 가장 많이 들어가는 앱 탑쓰리에요', 1],
#  ['저렴하게 세일이벤트나 쿠폰 받으면 평소보다 싸게 살 수 있으니 매일 안 볼수가 없네요', 1],
#  ['혜수언니가 모델이라 더 좋음', 1],
#  ['제품깨끗하게 잘 왔고 포장도 마음에 듭니다', 1],
#  ['잘 샀어요', 1],
#  ['감사합니다', 1],
#  ['여러 서비스 많이 생겨서 좋아요', 1],
#  ['리뷰쓰고 받은 적립도 꽤 많이 모았고 이걸루 물건살때 할인받으면 기분 좋아요', 1],
#  ['한가지 바람은 오늘도착상품 서비스지역이 늘어났으면 합니다', 0],
#  ['지방민은 너무 슬퍼요', 0],
#  ['그냥 일주일 맘놓고 기다리고있는데 갑자기 택배 도착했다고 문자와서 부리나케 집 달려갔어요', 1],
#  ['포장도 꼼꼼하게 잘되어있었어요ㅎ', 1],
#  ['상세페이지에서 본 그대로고', 1],
#  ['명품 주얼리에 눈 뜬후로 발란 애용합니다', 1],
#  ['처음에는 매장에서 샀었는데 발란이용해보니 그럴 필요가 없어졌어요', 1],
#  ['후기 꼼꼼히 살피고 구입하니 항상 성공합니다', 1],
#  ['오 검수영상 신선하네요', 1],
#  ['믿음직스럽습니다', 1],
#  ['백화점 가기 귀찮은 저에게 딱입니다', 1],
#  ['너무 편하고', 1],
#  ['빠르게 물건 받았어요', 1],
#  ['다른데서 최저가 찾았다 하고 보면 관세 미포함이라 낚인 기분이였는데 발란은 관세포함가네요', 1],
#  ['따로 계산 안해도되서 편하고 좋아요', 1],
#  ['다양한 상품이 많아요', 1],
#  ['판매자별로 가격과 배송기간 등을 비교해서 볼 수 있어 유용합니다', 1],
#  ['입점 업체 거래 만족도를 보고 사는 것도 팁', 1],
#  ['처음에는 좀 앱적응이 안됐는데 사용하다보니 상품이나 할인전 등 알아서 찾아보고 있어요 찜목록터질 지경이네요', 1],
#  ['선착순 쿠폰이나 랜덤쿠폰 이벤트 줬으면 좋겠어요', 1],
#  ['잘 쓰고 있습니다', 1],
#  ['핫딜과 쿠폰 적립금 등 잘 사용하면 최저가보다 더 싸게 살 수 있어요', 1],
#  ['가격 형성이 아주 잘되어있는것 같습니다', 1],
#  ['좋은 브랜드와', 1],
#  ['예전같으면 꼭 백화점에 가야 했는데 퇴근하면서 살펴보고 비교해놓고 월급날되면 지르고 있어요', 1],
#  ['가격 훨씬 저렴하면서', 1],
#  ['컨디션 좋은 상품 받고 있어요', 1],
#  ['가격이 좋으니 계속 구매합니다', 1],
#  ['포장이 아쉬운 것도 간혹있지만', 0],
#  ['보기편하게 잘 정리되어있어요', 1],
#  ['판매량순으로 보는데', 1],
#  ['어쩜 하나같이 다 이뿌고', 1],
#  ['가격도 착하고ㅠㅜㅠㅜㅠ', 1],
#  ['리뷰 수정하기가 없어서 엄청 불편하네요', 0],
#  ['아주 같이 만들었어요', 0],
#  ['아주 같은 앱', 0],
#  ['내일 도착하는것처럼 다 설명해놓고 막상 주문하면 맨날 주일 넘게 걸려요 ㅎㅎ 항상 도착 예정일 보면서 빨리 도착할만한곳에 돈 더주고 구매하는데 다 무용지물입니다',
#   0],
#  ['처음 구매에 예정일보다 한참 늦게 도착했을땐 아 내가 그냥 운이 안좋아서 그랬구나 하고 말혀고했는데 다음에 주문해도 똑같이 개늦게 배송돼서',
#   0],
#  ['배송으로 이렇게 장난질 치는 플랫폼은 역시 트랜비가 처음이네요', 0],
#  ['신기한 경험 감사하고 앞으로도 쭉 이용 안하겠습니다', 0],
#  ['감사합니다', 1],
#  ['가격도 착함 굿', 1],
#  ['직구인데도 불구하고 배송이 빠른편', 1],
#  ['엄마 선물로 발란에서 구매했어요', 1],
#  ['생각했던 예산보다 더 저렴하게 샀어요ㅋㅋ', 1],
#  ['전 상당히 맘에들어요', 1],
#  ['어그 슬리퍼 사려고 가입했는데 예상외로 배송도 빨리왔고', 1],
#  ['상품도 좋아요', 1],
#  ['어플 반응도 빠르기 때문에 답답하지 않아요', 1],
#  ['친절하고', 1],
#  ['빨라요', 1],
#  ['걍 오케이몰 쓰셈 정품인지도 불안함', 0],
#  ['뒤로가는거도 없어서 계속 껐다 키고', 0],
#  ['애플로 로그인해야되는데 로그인 버튼 눌러도 안되고 계속 터치도 안됨', 0],
#  ['그리고 반품비가 만원이상', 0],
#  ['추천되는 상품 보고 있으면 시간순삭이네용', 1],
#  ['가격도 다른곳에 비해 착하고', 1],
#  ['종류도 다양해서 훑어보기 바빠요', 1],
#  ['매장갔다가 이쁜거 없어서 그냥 왔는데 발란에서 득템한 것도 여러 개네요', 1],
#  ['초창기때부터 사용해왔는데요', 1],
#  ['관심있는 브랜드나 가방 등 있으면 가장 먼저 찾아보는 앱입니다', 1],
#  ['앱도 편하게 바뀌어서 잘 사용하고 있습니다', 1],
#  ['점점 서비스도 다양해지고', 1],
#  ['좋네여', 1],
#  ['가격비교하는거 너무 귀찮았는데 알아서 해주니 너무 편합니당 ㅋㅋㅋㅋ 잘 쓸게영', 1],
#  ['잘 사용하고 있고 실제로 가방 하나 사서 잘 쓰고 있어요', 1],
#  ['왜 장바구니 물건들 바로 팔렸는지 안 팔린건지 못 보게 해놓는건가요', 1],
#  ['아주 기능이 좋습니다', 1],
#  ['특정 브랜드만 고집해서 샀는데 발란 알고나서는 다양한 브랜드를 접하고 있어요', 1],
#  ['예를 들면 라는 스타일의 가방이 브랜드에만 있는지 알았는데 사에도 있는 등이요', 1],
#  ['오늘 도착하는 상품 정말 쵝오입니다', 1],
#  ['ㅜㅜ 매장만 가도 줄 서거나 대기표 뽑아야 하는데 그런것도 없고요', 1],
#  ['시간 절약합시당', 1],
#  ['이번달 쿠폰 받아서 저렴하게 잘 삿어용 이벤트 계속 많이 했으면 좋겠어용 ㅎㅎ', 1],
#  ['패알못은 옷을 사고 싶어서 어떤걸 사야 되나 고민될 때가 많은데 시즌별 이벤트별로 상품 셀렉해서 구성해서 올려주는게 도움이 많이 돼요 거기에 할인도 많이 들어가면 개이득이고요',
#   1],
#  ['거기에 할인도 많이 들어가면 개이득이고요', 1],
#  ['쉽게 간편하게 구매할수 있어서 좋아요', 1],
#  ['토할 거 같음', 0],
#  ['맘에 드는게 제품 사진이요 제품만 딱 집중해서 볼 수 있게 되어 있어서 좋아요 깔끔해서 계속 쓰려구요', 1],
#  ['쇼핑하러 돌아다니는 거 안 좋아하는 저한테 딱 맞는 앱입니다', 1],
#  ['조금이라도 더 저렴하게 구매하려고 검색 많이 하는 편인데 이 앱에서 한번에 해결하니 시간 절약되고 좋았네요', 1],
#  ['배송도 빨라서 엄청 만족했어요', 1],
#  ['최근에 발란앱에서 제품 하나 샀었는데 퀄리티도 좋고상품 받기 전엔 약간 걱정도 됐었는데 괜한 일이었네요  앞으로 더 잘되길 바랄게요',
#   1],
#  ['명품 사려는 사람은 꼭 다운 받아야할 앱임 발란앱 안 받고 명품 사는 건 돈낭비임', 1],
#  ['발란앱 깔아 놓고 가방이랑 옷 업데이트 되는 거 구경 하느라 시간 가는 줄도 모르고 있어요', 1],
#  ['스타일 다양하게 시도하는 편인데 제품이 엄청 다양해서 잘 쓰고 있어요', 1],
#  ['명품 사고 싶을 때 발란앱부터 들어가봐요', 1],
#  ['보기 쉽게 잘 되어 있어요', 1],
#  ['가격도 할인하고', 1],
#  ['백화점에 문의했을때보다 엄청 저렴하게 구입했네요', 1],
#  ['ㅋㅋ 종종 이용할 거 같아요', 1],
#  ['왜 이렇게 이쁜 게 많나여ㅠㅠㅠ 지금 장바구니 터질거 같아여ㅠㅠ 이번달도 이미 몇 개 샀는데 다 너무 이뻐여', 1],
#  ['발란앱때문에 텅장되고 있음 근데 끊을수가 없다 하루에도 몇번씩 들어가서 랭킹 확인하고 있음', 1],
#  ['중요한 날 입고 가려고 옷 구매했었는데 출발이랑 도착예정 보기 쉽게 되어있어서 좋았어요', 1],
#  ['배송도 예상일보다 빨랐어요', 1],
#  ['배송왔는데 퀄리티도 좋고 빨리 추워져서 입고 다니고 싶어용', 1],
#  ['상품이 다양해서 좋았어요', 1],
#  ['할인상품이 다양해서 좋았어요', 1],
#  ['할인상품이 다양해서 좋았어요', 1],
#  ['맘에듬', 1],
#  ['시간이 없어서 명품 사러 오프라인 매장은 가기 힘들더라구요', 1],
#  ['여기저기 보다가 여기로 정착했네요', 1],
#  ['앱 사용하기 편해요', 1],
#  ['ㅋㅋㅋ 브랜드도 많아서 잘 쓰고 있어요', 1],
#  ['백화점 멀어서 인터넷으로 사는 편인데 다양한 브랜드 한 곳에서 볼 수 있어서 이용하고 있어요', 1],
#  ['명품 선물할 일이 있어서 인터넷으로 찾아보다가 발견했는데 이용하기도 쉽고', 1],
#  ['배송도 빠르더라구요 다음에 선물 살 일 있으면 또 이용할게요', 1],
#  ['여기서 구매해서 매장가서 받는거 신박하네요', 1],
#  ['걱정도 안되고 너무 좋았어요', 1],
#  ['최저가 보기 엄청 편하네요', 1],
#  ['ㅋㅋㅋㅋ 가격이 중요해서 ㅋㅋ 계속 이렇게 해주세요', 1],
#  ['면세로만 명품 샀었는데 여기가 더 싼거 같네요', 1],
#  ['ㅋㅋ 여행 못가고 있는데 잘됐어요', 1],
#  ['이번에 가방 하나 샀는데 정품 맞네요', 1],
#  ['이제 걱정안하고 여기서 사면 되겠어요', 1],
#  ['명품 매장 안가도 돼서 종종 이용합니다', 1],
#  ['실시간 업데이트 엄청 좋아요', 1],
#  ['예쁜 거 많아서 다 사고 싶어요', 1],
#  ['해외여행 못가서 면세점 이용 못했는데 발란앱으로 다시 명품백 모으고 있네요', 1],
#  ['걱정했었는데 배송받고 걱정 싹 날라가서 계속 이 앱 쓰려구요', 1],
#  ['직구 못해서 원래 매장에서 돈주고 사는 사람인데 여기 앱쓰니까 직구 편하게 하네요', 1],
#  ['제품 사기 전에 몇가지 궁금한게 있어서 채팅 했는데 답도 빠르고 친절해서 믿고 주문했네요', 1],
#  ['배송 조회돼서 너무 좋아요', 1],
#  ['검수 영상도 있던데 그래서 믿음이 확 가더라구요', 1],
#  ['골프에 빠졌는데 여기 골프 브랜드 엄청 많아서 너무너무 좋아여', 1],
#  ['어제도 발란 구경하느라 늦잠자서 피곤해요', 1],
#  ['힘내려고 어제 봐뒀던거 결제했습니다', 1],
#  ['명품 좋아하는 사람이라면 다운 받아야할 앱인거 같아요', 1],
#  ['명품 브랜드들 많아서 좋네요', 1],
#  ['딴데는 제가 찾는 브랜드 없는데 여기엔 있어요', 1],
#  ['할인 잘하고 쿠폰 쓰기 쉬워서 좋음', 1],
#  ['배송 언제오냐고 재차 확인했는데 말씀해주신 날짜에 잘 도착해서 목숨건졌어요', 1],
#  ['저렴한 가격에', 1],
#  ['좋은 제품 정말 감사합니다', 1],
#  ['ㅎㅎㅎ 오픈런해도 못구하던 제품 득템했어요', 1],
#  ['소리벗고 팬티질러예', 1],
#  ['쿠폰 주는거 좋아요', 1],
#  ['이번에도 앱에서 쿠폰 써서 하나 질렀어요', 1],
#  ['실시간랭킹 서비스 좋네요', 1],
#  ['트렌드 못읽을까봐 걱정할 필요가 없겠어요 발란이 읽어줍니다', 1],
#  ['예쁜 신상은 또 오래걸릴줄알고 호다닥 주문했는데 진짜 빨리왔어요', 1],
#  ['심지어 당일 배송상품도있네요', 1],
#  ['제품 검색하면 바로 최저가 비교 가능 너무 편해요', 1],
#  ['진짜 감동', 1],
#  ['이용하기 편하고', 1],
#  ['이용하기 편하고 특히 제가 좋아하는 브랜드 자주 올라와서 좋아요', 1],
#  ['만족만족', 1],
#  ['요새 명품에 빠져서 발란앱만 들여다 보고 있는데 잘쓰고 있어요', 1],
#  ['어플 자체는 나쁘지은흠', 1],
#  ['어플 설치하면 쿠폰준다고 꼬시고막상 다운받고 설치하면 타쿠폰과 중복할인 안된다고 막아놓음 미리 써놓기라도 하던가하는짓이 토악질 나와서 이미 털린 개인정보지만 바로 탈퇴하고 앱삭제전 후기남김제품은 다른 백화점 온라인사이트에서 몇천원 더 주고 주문함',
#   0],
#  ['사고 싶은거 저렴하게 샀는데 계속 이 상태로 쭉 가는 그런 앱 되길', 1],
#  ['발란앱으로 시키면 배송 엄청 빠르네요 느긋하게 있었는데 배송왔다고 해서 놀랐네요', 1],
#  ['빨리 해결해주세요', 0],
#  ['애플 로그인이 안됩니다', 0],
#  ['사장님 신규가입 쿠폰 이렇게 막 뿌리셔도 되겠어요', 1],
#  ['감사합니다', 1],
#  ['현금매입가 반값으로 후려침 애매한 안내로 사람 헷갈리게 잘함 개 꾸림 바로 삭제 이딴앱 필요없음', 0],
#  ['장바구니에서 주문하기 눌러도 멈춰있고', 0],
#  ['사용하기 좋아요', 1],
#  ['맨날 살까말까했던 신발 쿠폰이랑 신규가입으로 저렴하게 겟챠', 1],
#  ['명품 쇼핑몰이라길래 나랑은 상관없겠구나 했는데 뉴발나이키같은 운동화들도 저렴하게 구매가능하네여 ', 1],
#  ['저렴한 가격 사이즈없음 비싼 가격 사이즈 있음 짜증나서 그냥 안살라했는데 발란에 있었어요', 1],
#  ['심지어 저렴하기까지해요 감격스러워서 감사의 마음으로 리뷰 남깁니다', 1],
#  ['최고최고 번창하세요 ㅎㅎㅎ', 1],
#  ['보통 면세점에서 쿠폰이랑 적립금써서 명품 구입하는데 코로나땜에 못나가다보니 인터넷으로 정품최저가 찾아보게됐어요', 1],
#  ['면세점 쿠폰이랑 이벤트적립금 쓴거보다 훨씬 저렴하고', 1],
#  ['심지어 집 앞까지 빠르게 배송오네요', 1],
#  ['남은 쿠폰도 마저 써야겠어요 ', 1],
#  ['정품 맞음ㅇㅇ 사촌형 신발 산거 예쁘길래 따라샀어요', 1],
#  ['정품인지 봐달라고했는데 맞다면서 자기보다 저렴하게 샀다고 놀라더라구요', 1],
#  ['자기보다 저렴하게 샀다고 놀라더라구요', 1],
#  ['믿고 사는 발란 정품 맞아요 이제 더 이상 의심하지 않아요', 1],
#  ['예쁘고저렴한 물건 찾기에만 집중ㅋ', 1],
#  ['해외제품 사는게 처음이라 이거저거 궁금해서 물어볼게 많았는데 친절하고 꼼꼼하게 상담해주셔서 안심됐어요', 1],
#  ['해외제품 사는게 처음이라 이거저거 궁금해서 물어볼게 많았는데 친절하고 꼼꼼하게 상담해주셔서 안심됐어요', 1],
#  ['직접 물건 받아보니 너무 겁먹었었던거같네요 정품 맞고', 1],
#  ['무엇보다 배송이 빠릅니다', 1],
#  ['강추', 1],
#  ['뭐죠 제 취향을 어떻게 이렇게 잘 아시죠 저보다 잘 아는거같아요', 1],
#  ['추천 상품 싹 다 제 서타일ㅎ', 1],
#  ['고급지네요', 1],
#  ['포장상태 아주 깔끔 이태리 그 잡채', 1],
#  ['신속정확한 배송 감사합니다', 1],
#  ['그라지아', 1],
#  ['신규가입쿠폰 너무 혜자네요', 1],
#  ['너무 저렴해서 걱정했는데 진품이고', 1],
#  ['심지어 이렇게나 빨리 받다니 최고십니다', 1],
#  ['모르던 브랜드도 많네요', 1],
#  ['시야가 넓어진 느낌 저렴하고 예쁜 아이들도 많고 좋네요', 1],
#  ['시야가 넓어진 느낌 저렴하고 예쁜 아이들도 많고 좋네요', 1],
#  ['살림살이에 도움이 되겠어요', 1],
#  ['앱 이상해요', 0],
#  ['악세서리에서 지갑 눌렀는데 아무것도 안뜸 가입할때 이런적없엇는데 지메일 인증메일도 안오고 물건을 사란건지말란건지', 0],
#  ['회원가입흐려거 하니까 회원가입창에서 계속 멈춰 있네요', 0],
#  ['뭘 눌러도 반응이 없어요 어케 해야 하나요', 0],
#  ['타사이트 물건값 완전 저렴하길래 구매할라고 보면 관부과세 폭탄때려서 훅 비싸지는데 발란은 물건값에 포함 되어있네요', 1],
#  ['이게 포함한 값이라니 개이득ㅋㅋㅋ', 1],
#  ['평일에 발란에서 찜해두고 주말에 오프라인가서 실물확인하고 집 오는 길에 결제합니다', 1],
#  ['오프라인 가격보다가 발란판매가 보면 누가 채갈까 무서워요', 1],
#  ['정품보증되니까 믿고 이용중입니다', 1],
#  ['저렴한데다가', 1],
#  ['헐헐헐 원하던 제품 발란에서 구매성공했어요', 1],
#  ['명품을 온라인에서 살때마다 불안한 맘이 있었는데 포장영상보내주시는거 보고 안심했어요', 1],
#  ['배송단계 트래킹도 잘되고', 1],
#  ['보통 초록창으로 일일히 저장하고 캡쳐하면서 최저가 찾는데 발란으로 그런 수고로움 덜었네여 가격할인율제품정보를 한번에 비교할 수 있어서 좋아요',
#   1],
#  ['예쁜거 다 담다보니 장바구니가 터지려고하네요', 1],
#  ['쿠폰땜에 하나 살거 두개 샀어요ㅋㅋㅋㅠㅜ', 1],
#  ['해외배송직구하면 그냥 주문해놓고 언젠가 오겠지 하고 맘비우고 기다리는 편인데 여기는 맘 비우려고 하는데 도착해요', 1],
#  ['ㅋㅋ배송짱빠릅니다', 1],
#  ['빨리빨리 한국인 정서에 딱 맞는 곳', 1],
#  ['백화점 쇼핑을 아직 내외하는 인왠지 매장에서 물건을 보면 사야될것만 같다는 생각에 부담스러웠는데 온라인에서 구매하니 몸도 마음도 편하네요',
#   1],
#  ['이벤트랑 쿠폰 이용해서 저렴하게 번째 구매입니다', 1],
#  ['어느새 보니 적립급이 꽤나 쌓였네요', 1],
#  ['꽁돈생긴느낌 번째구매에는 적립금도 써야겠어요 ㅎㅎㅎ', 1],
#  ['정품 보상제도가 있다해서 항상 믿고 구매합니다', 1],
#  ['새상품에 하자가 있는데 환불이 안되네요', 0],
#  ['다신 이용 안 하겠습니다', 0],
#  ['브랜드별로 모아두고 가격비교하면서 쇼핑할 수 있어서 좋아요', 1],
#  ['브랜드별로 모아두고 가격비교하면서 쇼핑할 수 있어서 좋아요', 1],
#  ['결정장애로 매번 골치아팠는데 많은 도움이 됐어요', 1],
#  ['트렌비에서 나이키 신발 샀는데 몇 주 걸려 받은', 0],
#  ['신발상태가 중고사이트였나 싶을정도 나이키 텍에 누렇게 오염있길래 환불 아니고 교환 문의 드렸더니 공정상 발생할 수 있는거라 교환불가 교환시만원정도 ㅎㅎ 바로 삭제합니다',
#   0],
#  ['다른거 이용하세요 머스트잇이나 많잖아요', 0],
#  ['최저가 제품 찾아 들어왔는데 쿠폰까지 쓰니 초초초초최저가 제 텅장을 지켜주셔서 감사합니다', 1],
#  ['날씨가 추워질거같아서 아우터 구매했는데 진짜 빨리 도착했어요', 1],
#  ['장모님 생신이라서 와이프랑 가방검색하다가 발란에서 최저가 찾아서 결제하기로했어요', 1],
#  ['와이프에게는 최저가로 샀다고 했는데 쿠폰써서 제 비상금 만들었어요 나이쑤', 1],
#  ['아니 양말 보러 들어왔다가 신발까지 사버렸네요', 1],
#  ['그치만 놓칠 수 없는 가격이였어요', 1],
#  ['저는 인터넷으로 사서 불안했는데 요목조목 다 따져보니 정품맞아요', 1],
#  ['저는 쿠폰이랑 신규가입혜택으로 백화점 가격보다 훨씬 저렴하게 사서 기분좋았어요', 1],
#  ['브랜드마다 사이즈가 달라서 제 체구랑 비슷한 구매자들 리뷰 보고 고릅니다', 1],
#  ['리뷰 잘 되어 있네요', 1],
#  ['여러분 조심하세요 예쁜거 담고 쿠폰 적용하다보면 순식간에 텅장이 되어버립니다', 1],
#  ['신상도 예쁘고 베스트 상품 보면 요새 다들 하나씩은 갖고있는거같고 찜해둔게 너무 많았어요', 1],
#  ['쿠폰 마니마니 주세용', 1],
#  ['아 필터기능 너무 좋아요', 1],
#  ['다양하고 방대한 양의 브랜드 제품들을 한눈에 볼 수 있어요', 1],
#  ['다양하고 방대한 양의 브랜드 제품들을 한눈에 볼 수 있어요', 1],
#  ['구체적으로나눠져있어서 검색하기도 좋고', 1],
#  ['가격들도 착해서 자주 사용할 것 같아요ㅎ', 1],
#  ['믿고 살 수 있어요', 1],
#  ['명품을 저렴한 가격으로', 1],
#  ['제품 상태는 물론 구성품도 다 있어서 맘에 들어요', 1],
#  ['온라인 쇼핑 불안해서 고객센터 연락했는데 친절하시고 응대도 잘 해주셨어요', 1],
#  ['다양하고 가성비좋네요', 1],
#  ['역시 백화점보다 훨씬 저렴한 가격에 겟', 1],
#  ['발란은 로케트로 배송하나요', 1],
#  ['직구상품을 어떻게 이렇게 빨리 배송해주시죠 감사합니다', 1],
#  ['다른 사이트들에서 보지 못한 제품들이 많네요 신상도 많고 다양한 제품들이 많아서 선택의 폭이 넓어졌어요', 1],
#  ['유니크한 제품들도 많고 종종와서 트랜드 읽기도 좋네요', 1],
#  ['배송이 생각했던 날보다 하루 빠르게 왔어요', 1],
#  ['상품도 이상없이 잘 왔습니다', 1],
#  ['물건 질이 좋아 자주 애용해야겠어요', 1],
#  ['다른곳 보다 할인율도 높고 쿠폰도 많이 주네요  이런 곳을 이제야 알았네요 ㅠㅠ 앞으로 자주 이용해야겠어요', 1],
#  ['ㅋㅋㅋ 시간가는 줄 모르고 명품 구경하게 됨 디자인이 깔끔해서 이용하기 편리해용', 1],
#  ['집에서 편하게 쇼팡할 때 좋아요 백화점 갈때 시간들이고 차도 막히고 가도 원하는 상품 못구하면 통탄스러운데 ㅋㅋㅋ 그럴 일 없음',
#   1],
#  ['실시간으로 세일 정보를 확인할 수 있어서 좋아요', 1],
#  ['오늘 도착하는 상품들도 있고', 1],
#  ['배송 예정날짜 확인할 수 있어서 유용해요', 1],
#  ['발란 덕에 요즘은 구매대행 안하구 이써요', 1],
#  ['쇼핑도 편리하네요 감사합니다', 1],
#  ['가격도 저렴하고', 1],
#  ['예전부터 알고있었는데 의심스러워서 구매는 이제야 해봤는데 제대로 정품 오더라고요', 1],
#  ['백화점가서 상품권 할인으로 사는거 아니어도 저렴하게 살 수 있어서 좋네요', 1],
#  ['행사 프로모션도 다양하게 합니다', 1],
#  ['서비스 만족도 최상 고객센터 피드백도 빠르고', 1],
#  ['굿임다', 1],
#  ['명품은 사고싶은데 뭐가 트렌든지 뭐가 좋은건지 잘 몰랐었는데 발란에서는 실시간 랭킹도 볼 수 있어서 요즘은 이런거 많이 사는구나 알 수 있어요',
#   1],
#  ['가격도 합리적이에요', 1],
#  ['명품 구매할 때 꼭 쓰는 앱 도 편리하고', 1],
#  ['오류도 없고', 1],
#  ['쿠폰팩이 쏠쏠함 ㅎㅎㅎ', 1],
#  ['여러사이트 진전할 필요 없이 명품 대부분 브랜드 올인원으로 둘러볼 수 있다는 점이 너무 편해요', 1],
#  ['여러사이트 진전할 필요 없이 명품 대부분 브랜드 올인원으로 둘러볼 수 있다는 점이 너무 편해요', 1],
#  ['익스프레스 배송도 넘 잘쓰고 있고요', 1],
#  ['한눈에 오늘의 할인 상품들 확인할 수 있어서 너무 좋아요 상품 보기가 여기가 젤 편하더라고요', 1],
#  ['따로 가격비교 안해도 되니까 시간 절약도 할 수 있고 관부가세 포함이라 이것저것 따로 계산할게 없어서 좋네요', 1],
#  ['편하게 쓰고 있습니다', 1],
#  ['환불 관련해서 문의 드렸었는데 고객센터에서 빠르고 정확하게 조치해주시더라구요 감사합니다', 1],
#  ['지인 소개로 깔아봤는데 상품 보기도 쉽게 되어있어서', 1],
#  ['브랜드랑 제품 종류 다양하고 가격대별로 확인할 수도 있어서 원하는 제품 구매할 때 편해요', 1],
#  ['브랜드랑 제품 종류 다양하고', 1],
#  ['가격대별로 확인할 수도 있어서 원하는 제품 구매할 때 편해요', 1],
#  ['진짜 정품이 오더라고요', 1],
#  ['배송도 빨랐고', 1],
#  ['배송 상태도 좋음', 1],
#  ['매장 둘러볼 시간 없을 때 편리하게 이용하고 있어요', 1],
#  ['금액대별 검색도 가능해서 누구 선물 구매할 때 짱조음', 1],
#  ['한번에 가격 비교 할 수 있으니까 여러 곳 진전할 필요가 없어요', 1],
#  ['좋아요', 1],
#  ['종종 구매하고 있어요', 1],
#  ['다른 명품커머스앱보다 할인을 자주 해주고 적립금 혜택도 커요', 1],
#  ['백화점이나 다른앱에는 없던 상품도 재고 있더라구요', 1],
#  ['다양한 브랜드', 1],
#  ['할인도 많이 해줌', 1],
#  ['보기도 좋고', 1],
#  ['트렌비 물건 많아서 좋긴 한데', 1],
#  ['그래서 너무 보는 데 오래 걸려요\n사이즈별로 색상별로 볼 수 있으면 좋겠어요', 0],
#  ['칼하트 트래퍼햇을 주문 했는데 주문하고 나서 가격대가 바로 올라서 취소 됐네요', 0],
#  ['좋아요', 1],
#  ['짱짱', 1],
#  ['재고 있다고 표시된 상품을 구매하고 일주일 가까이 기다려도 안오길래 보니깐 판매자 일방적 취소로 환불 기간 일까지 총 일 동안 구매도 못하는 상품때문에 스트레스 받았습니다',
#   0],
#  ['구매자에게 매우 불리한 시스템이니 다른 어플 이용하세요', 0],
#  ['싸다 싸', 1],
#  ['모든 명품은 여기서 다 살 수 있네요', 1],
#  ['오늘 출발이라면서 일째 출발 안 함ㅋㅋ', 0],
#  ['구입도 못하는 제품을 구입할 수있는 것처럼 속여파네요', 0],
#  ['고객센터는 본인들이 판매하는게 아니라 아무 조치를 할수없다하고 관리를 못할꺼면 뭐하러 이 앱을 만들었는지 모르겠네요', 0],
#  ['품절이면 품절표시를 정확하게 해놓으세요', 0],
#  ['품절이면 품절표시를 정확하게 해놓으세요', 0],
#  ['너무좋아요트렌비 믿고 구매 하는쇼핑 클릭롸잇나우', 1],
#  ['중고매입신청함 물품수거후 바로 매입이 진행되는줄알고 기다리다 며칠이 지나도 연락이 없어서 전화하니 주 검수시간이 걸린다고 그때서야 얘기함 왜 미리 고지를 하지않았냐 당장 그냥  추가 검수기간 고지안함 제안서 여부도 지금 댓글로 알았고 아무것도 고지안함 그러면서 다시보내라니',
#   0],
#  ['착불택배비 부담하라고하고', 0],
#  ['상담사는 자기가 고지한거 아니고 자기 잘못아니라고함 상담원은 트렌비에 왜있는지 모르겠네요', 0],
#  ['그래서 무슨 상담을 이따위로 진행하냐니 가이드가 그렇게 되어있다는데 이게 맞냐고요', 0],
#  ['알람 수신도안하는데 왜이렇게들 보내는겨 설정 찾기도 겁나어렵게해놓고', 0],
#  ['사용하기 편해요', 1],
#  ['명품 판매하기 편한 앱', 1],
#  ['깔끔하게 정리된 앱', 1],
#  ['제품이 많은데도 깔끔하게 정리된 앱', 1],
#  ['집에서 쉽게 명품 쇼핑 가능', 1],
#  ['검색 필터가 잘되어 있는 것이 장점', 1],
#  ['주문한지 달만에 재고 없다고 일방적으로 주문 취소 당했어요', 0],
#  ['정말 최악의 플랫폼', 0],
#  ['좋습니다', 1],
#  ['진짜 앱 개못만들었네 정신병걸리겠네', 0],
#  ['별 도 아까움 명품케이스도 없는제품팔고 리뷰사진과 완전다르게와서 가품같다고', 0],
#  ['협력업체 편만 들어서 환불요청했더니 반품비내라는 어이없는 발란업체입니다', 0],
#  ['여기서 제품사느니 조금더내고 정식매장에서 사는게 낫다고 봅니다', 0],
#  ['여기서 구매하시는거 다시한번 생각해보세요', 0],
#  ['반품하면 반품택배비로 수익창출 참 그지같다', 0],
#  ['결론은 판매자도 정확한 사이즈 모르고 판매한단 소리고 고객이 정확한 사이즈 구매했는데도', 0],
#  ['고객센터 한다는 소리는 브랜드마다 사이즈가 다를수 있다고', 0],
#  ['만족하고 있습니다', 1],
#  ['가품 없을 것 같아서 믿고 사용 중이예요', 1],
#  ['제품도 많지만', 1],
#  ['상품주문후 국내배송인데 담날에도 상품준비중이면 당연히재고를의심할수밖에없죠', 0],
#  ['상품주문후 국내배송인데 담날에도 상품준비중이면 당연히재고를의심할수밖에없죠', 0],
#  ['근데 판매자와통화도못하고 트렌비고객센터와의 통화만 가능한것도 이해가안되고 이래저래서 재고가의심스럽다 했으면 고객센터에서 빨리재고유무를 파악해줘야죠',
#   0],
#  ['계속상품준비중인상태로요', 0],
#  ['고객센타로 다시전화했더니 역시나 제예상대로 재고가없어서 다른매장서지금구했고 지금부터 또일을기다리라고 하더군요', 0],
#  ['배송일이 도래하자 아직도상품준비중이라', 0],
#  ['무슨이딴곳이있는지바로취소하고 다른데서 구매했습니다', 0],
#  ['바로발송해주더군요 트렌비 첨 이용해봤지만 시스템도 이상하고 고객입장은도생각안해주는거같아 앞으로 이용할생각이없습니다', 0],
#  ['인터넷 결재하려는데 배송지 입럭다 되었는데 배송지 입력하라는 오류 계속 발생 상품도 다 골라놨는데 시간만 버렸습니다', 0],
#  ['몇십만원어치 골라놨는데 결재가 안되어서 다른데에서 구매했습니다', 0],
#  ['가장 저렴해서 최종 구매는 트렌비에서 하게 되네요', 1],
#  ['가격이 저렴한건 당연한거고', 1],
#  ['사진을 좀 더 다양하게 볼 수 있다는 점이 저한테는 가장 편했어요', 1],
#  ['앞으로도 자주 이용하겠습니다', 1],
#  ['플랫폼이 노력하고 있다는 인상이에요', 1],
#  ['정품 안심 되서 자주 이용해요', 1],
#  ['타 플랫폼 대비 좋은 제품 최저가 많고', 1],
#  ['특히 배송 빠른거 같아서 굿굿', 1],
#  ['오늘 트렌비 어플 재설치 하고 첫주문 했는데 좋아요', 1],
#  ['타 구매대행 어플은 상품은 여기보다 더 비싸고 거기에 배송비 따로 검수비 따로 받아요', 1],
#  ['여기는 배송비검수비 따로 안받아 좋아요', 1],
#  ['여기는 웬지 믿음이 가네요', 1],
#  ['가격도 합리하고', 1],
#  ['트렌비 번창하세요', 1],
#  ['아무래도 가격 차 때문에 직구 많이 하는 편인데 배송 오류 때문에 스트레스가 많았어요', 1],
#  ['요즘 국내 사이트도 괜찮다고 해서 비교해보고 평 괜찮길래 구매했는데 왠걸 너무 편하네요', 1],
#  ['진짜 배송비도 무료인데다가 왠만하면 일주일도 안되서 도착하고 이 편한걸 왜 몰랐을까 싶네요', 1],
#  ['제품 검수도 정품 인증도 꼼꼼하게 잘 해서 오니까 믿음직스럽고 너무 맘에 듭니다', 1],
#  ['프로 보상제 문구가 마음에 듭니다', 1],
#  ['개인차는 있겠지만 앱 디자인이 세련됐고 사용자의 접근성도 좋습니다', 1],
#  ['계속 아이쇼핑중인데 이번 블프 끝나기전에 하나 더 장만하려고요', 1],
#  ['일단 믿음이가고', 1],
#  ['다양한 제품들 구경하는맛도 쏠쏠해요', 1],
#  ['그러다 구매까지 이어지는 것같아요 앞으로도 좋은제품들 부탁드려용', 1],
#  ['무료배송에 배송빠르고', 1],
#  ['럭키드로우 당첨된적은 없지만 매달쿠폰 활용하기 좋고 해서 자주 접속한답니다', 1],
#  ['그래도 젤 깔끔하고', 1],
#  ['싸서 자주 이용중입니다', 1],
#  ['옷 보러 왔다가 가방보고또 딴거볼 수밖에 업는 편함이라 텅장되고 있는 나름의 단점이 있네요ㅋㅋ', 1],
#  ['아주 좋아요', 1],
#  ['키즈까지 제품분류해서 볼 수있어서 가족들 제품을 한번에 살 수 있어서 편한 것같아요', 1],
#  ['정품도 보장받아서 안심하고 쇼핑하게 되요', 1],
#  ['배송도 빠르고', 1],
#  ['배송 정보 보려고 했는데 마이페이지가 안들어가집니다', 1],
#  ['정말 갖고 싶던 신발이 있었는데 국내에는 없고 직구는 어렵고 해서 포기하고 있다가 친구가 트렌비에 있다고 해서 바로 앱깔고 구매했어요',
#   1],
#  ['검수도 꼼꼼하게 해줘서 기분좋게 구매했답니다', 1],
#  ['처음 이용해보는 거라 약간 걱정했는데 생각보다 배송도 빨리오고', 1],
#  ['그 뒤로 갖고 싶은 제품이 있으면 젤 먼저 트렌비에 들어오는 거 같네요', 1],
#  ['앞으로도 다양한 제품 많이 올려주세요', 1],
#  ['성격이 꼼꼼한 편이라 하나를 사더라도 다 따져보고 사는 편인데 브랜드 공식부터 한꺼번에 다 조회가 되니까 너무 좋아요', 1],
#  ['따로 찾아보는 수고 덜어지니 훨씬 빠르게 살 수 있구요', 1],
#  ['일단 판매자분이 친절하게 응대해주셔서 기분이 좋았어요', 1],
#  ['일단 믿음이 가고', 1],
#  ['저렴한 제품들', 1],
#  ['구경하는 재미도 쏠쏠해서 자주 보게 되는데 다른 앱들보다 확실히 사용성이 좋다는 걸 느낍니다', 1],
#  ['앞으로도 좋은 서비스 부탁 드립니다', 1],
#  ['배송을 감사드립니다', 1],
#  ['확실한 품질과', 1],
#  ['가격대도 괜찮고', 1],
#  ['빠른배송도 좋아요', 1],
#  ['제품들이 다양하고', 1],
#  ['앞으로 자주 이용할게요 조금 욕심을 부리자면 가전이나 이런 카테고리도 있으면 더 좋을 것 같아요', 1],
#  ['쿠폰이나 혜택도 다양해서 자주 이용하고 있습니다', 1],
#  ['개만 구매해도 가격 상관없이 무료 배송이 되는 점이 너무 좋고 익일 배송으로 하루 만에 오니까 급하게 사야될 때 주문하기도 좋더라구요',
#   1],
#  ['가격 때문에 여러 사이트를 검색하고 비교하지만 결국 최종으로 구매하게 되는 곳이 트렌비 입니다', 1],
#  ['다른 쇼핑몰보다 풍부한 볼거리가 많고 선택의 폭이 넓어서 자주 이용 중인데', 1],
#  ['좋은 서비스 이용하게 해주셔서 감사합니다', 1],
#  ['뭐니뭐니해도 앱이 버벅거리지 않아서 넘나 맘에 들어요', 1],
#  ['왜자꾸 빈 푸쉬 알림을 보내세요', 0],
#  ['가품 논란이 많은 요즘에 가품 관련 문제로 한번도 시끄러운 적 없어서 좋습니다', 1],
#  ['명품 쇼핑을 자주 하는 편인데 가격이 있다보니까 그래도 최저가 비교하면서 사게 되더라구요 트렌비는 최저가 비교가 잘되어 있는 편이라 비교해서 좋은 가격에 구매할 수 있어서 좋아요',
#   1],
#  ['앞으로도 좋은 서비스 부탁 드려요', 1],
#  ['배송도빠르고좋아요', 1],
#  ['정품보증이 확실해서 신뢰가 갑니다', 1],
#  ['참 많은 사이트 돌아다녀 봤는데 명품은 여기가 최고네요', 1],
#  ['갑자기왜 무슨코드뜨면서 안되요', 0],
#  ['집에서 쇼핑할 수 있어서 편해요', 1],
#  ['자주자주 들어오게 됩니다', 1],
#  ['업뎃되는 핫한 상품 너무 많거든요', 1],
#  ['어플리케이션 쇼핑은 피드백이 느려서 답답한데 발란은 빠르고 프로모션도 참 다양해요', 1],
#  ['사고 싶은게 너무 많아서 매일마다 참고 또 참고 하고 있어요', 1],
#  ['정품 진짜 맞아요', 1],
#  ['라스트 피스로 세일하는 거 진짜 많아요', 1],
#  ['명품을 잘 모르는 저 같은 사람들에게 발란은 도움 완전 되는 앱네요', 1],
#  ['매일마다 들어가서 구경하고 사고 싶은 거 찜해놓고 하고 있어요', 1],
#  ['자주쓰는 명품구매처에요 저렴해요', 1],
#  ['다른 명품 샵은 배송이 진짜 엉망진창인데 반란은 진짜 특배송이네요', 1],
#  ['완전 빨라요', 1],
#  ['어플도 깔끔하고', 1],
#  ['오류도 없어서 좋네요', 1],
#  ['가입도 편하고 결제도 편해서 좋아요', 1],
#  ['신규 가입하니 쿠폰 많이 주네요', 1],
#  ['ㅋㅋㅋ 나이키 신발 사고 싶었던거 진짜 싸게 샀어요', 1],
#  ['ㅋㅋㅋ 완전 신나요', 1],
#  ['ㅎㅎ 자주 발란할게요', 1],
#  ['진짜 정품 오는 거 맞네요', 1],
#  ['진짜 정품 많고', 1],
#  ['최소  할인해서 샀어요', 1],
#  ['사고 싶었던 게 딱 반란에만 있네요', 1],
#  ['ㅋㅋ 완전 감사합니다', 1],
#  ['프로모션도 다양해서 좋아요', 1],
#  ['고객센터 피드백도 빠르고', 1],
#  ['반란은 믿고 구매할 수 있고', 1],
#  ['배송이나 상품 모든 최고에요', 1],
#  ['회원혜택 많아요', 1],
#  ['꼭 챙겨서 구매하세요', 1],
#  ['직구는 못 믿고 비싸게 백화점에서 샀었는데 이런 앱이 있어서 좋네요', 1],
#  ['명품 가방 선물 할 일이 있어서 알아보다 추천해주길래 여기서 보는데 참 다양하네요', 1],
#  ['물건이 여러개 있어서 좋은데 몽블랑 홈페이지에 없는 제품도 있고 똑같은 제품을 세일가격인데도 몇 만원은 더 비싼데요', 0],
#  ['물건이 여러개 있어서 좋은데', 1],
#  ['코로나 때문에 발란 이용하게 되었는데 굳이 백화점이나 면세점 가서 명품 살 필요', 1],
#  ['발란에서 찜하고 시간 될 때 백화점 가서 확인하고 저렴하게 사니까는 더 효율적이네요', 1],
#  ['자주 방문하고 있어요', 1],
#  ['아주좋아요', 1],
#  ['짱 짱 짱', 1],
#  ['배송까지 마음에 듭니다', 1],
#  ['달에 한 번은 반란에서 저를 위해서 선물을 구매합니다', 1],
#  ['저는 트렌디한 것보다 클래식한 거 좋아해서 엄청 세일하는 것만 골라서 구매하고 있어요', 1],
#  ['신상도 많고 다양한 제품들이 많아서 선택의 폭이 넓어서 좋아요', 1],
#  ['요즘 스타일을 발란에서 배워요', 1],
#  ['해외제품 사는게 처음이라 이거저거 궁금해서 물어볼게 많았는데 친절하고 꼼꼼하게 상담해주셔서 감사합니다', 1],
#  ['쿠폰 엄청 빠방 하네요', 1],
#  ['ㅋㅋㅋ 같은 가방 다른 데보다 훨씬 저렴하게 살 수 있어요', 1],
#  ['많은 종류의 브랜드가 있어 편리해 계속 이용하게 되네요', 1],
#  ['백화점 한번 가려면 거리적으로 부담돼서 시간을 내지 못하는 경우가 많은데 발란 이용하니까 시간 절약에 좋아요', 1],
#  ['유니크한 제품들도 많아서 트랜드 읽기도 좋네요', 1],
#  ['판매자와 채팅할 수 있는게 좋아요', 1],
#  ['검색하기 쉽고', 1],
#  ['가격도 착하고', 1],
#  ['예쁜 거 너무 많아요', 1],
#  ['쿠폰 좀 더 주세요', 1],
#  ['결혼 기념일에 선물 깜빡했다가 여기서 급하게 구매했는데 배송도 진짜 빠르네요', 1],
#  ['모두 좋아요', 1],
#  ['쇼핑하기 편리하고', 1],
#  ['저렴하네요', 1],
#  ['백화점보다 훨씬 저렴하게 구매 가능 하네요', 1],
#  ['일 기념 선물 급하게 구매했는데 대박 만족합니다', 1],
#  ['물건 참 다양하네요', 1],
#  ['프로모션도 의외로 많네요', 1],
#  ['어느새 명품 보거나 살 때는 발란을 사용하고 있어요', 1],
#  ['가입 이벤트 있어서 구경했는데 여기 물건 진짜 다양하고', 1],
#  ['기획전 다양하게 해서 좋아요', 1],
#  ['믿을 수 있어 좋습니다', 1],
#  ['발란 배송도 빠르고', 1],
#  ['저같이 명품 모르는 분들에게 발란에서 알아조고 사는거 추천합니다', 1],
#  ['절대 진짜네요', 1],
#  ['오픈런 기다리기 싫어서 찾다보다 발란 가입했는데 백화점보다 낫네요', 1],
#  ['내 취저 물건 많아서발란 늘 구경하고 구매도 합니다', 1],
#  ['발란 상품 수가 진짜 많은 거 같아요', 1],
#  ['매일마다 구경 옵니다', 1],
#  ['사고 싶은 거 너무 많아요', 1],
#  ['급하게 여친한테 선물하려고 구매했는데 배송 진짜 빠르네요', 1],
#  ['쉽게 구매 가능하고', 1],
#  ['가격도 맘에 들어요', 1],
#  ['코로나 시기에 면세점 못가서 발란 알게 됐는데 만족해서 지금까지 잘 사용하고 있어요', 1],
#  ['요즘 유행하는 패션을 한번에 볼수있어 좋아요', 1],
#  ['쿠폰 너무 좋아요ㅋㅋ 더 많은 쿠폰 주세요', 1],
#  ['더 자주 구매할게요', 1],
#  ['발란은 무조건 믿고 명품 구매하셔도 됩니다', 1],
#  ['엄청 세일 받아서 꼭 사고 싶었던 거 구매했습니다', 1],
#  ['믿음이 갑니다', 1],
#  ['시간 낭비하지 않고 더 저렴하고 편하게 반란에서 구매해요', 1],
#  ['해외여행 못가서 발란 이용하고 있는데 마음에 드는 물건 가격도 싸고 배송도 받아서 넘넘 좋아요', 1],
#  ['쿠폰팩 너무 좋아요', 1],
#  ['할인도 많이 하는데 쿠폰까지 줘서 엄청 싸게 구매했어요', 1],
#  ['관세 포함이라 별도로 계산할 필요가 없네요', 1],
#  ['백화점에 비해 가격이 너무 저렴해서 놀랐네요', 1],
#  ['정품보상제도 있네요', 1],
#  ['믿고 사용하는 발란 추천합니다', 1],
#  ['정품 확실하니까 의심할 여지없이 매번 구매하게 돼요', 1],
#  ['앱 구성이 심플해서 사용이 편하네요', 1],
#  ['백화점에서 보고 반란해서 구매', 1],
#  ['배송 빠르고', 1],
#  ['포장 깔끔합니다', 1],
#  ['발란 보면서 스타일도 참고하게 돼서 좋아요', 1],
#  ['세이라는 거 잘 골라서 진짜 잘 사고 있어요', 1],
#  ['너무 좋은 가격에', 1],
#  ['밖에서 나가지 않고 집에서 쇼핑 하니까 너무 편해요', 1],
#  ['직구상품 저렴하고', 1],
#  ['진짜 배송 빠르네요', 1],
#  ['배송이 진짜 마음에 들어요', 1],
#  ['해외 직구 치고는 진짜 배송 빠른 거 같애요', 1],
#  ['너무 감사합니다', 1],
#  ['여기저기 발품팔지 않아도 돼서 정말 편하네요', 1],
#  ['생일 선물로 구입한거라 배송에 대해 민감했는데 결국 그 다음주 수요일까지도 배송준비중이네요', 0],
#  ['몇번이고 고객센터에 물었는데 무슨 말도 안되는 핑계만 계속 대더니 나중엔 답도 안하네요', 0],
#  ['한두푼 하는 것도 아니고 명품취급하는 곳에서 이딴 식으로 일처리 진행하나요', 0],
#  ['저는 특히 옷에 대한 리뷰를 보고 스타일에 참고 할수 있어요', 1],
#  ['백화점 가지 않아도 돼서 편하게 고를 수 있어서 좋아요', 1],
#  ['최저가 제품 서치 하다가 들어왔는데 쿠폰까지 쓰니깐 완전 최저가 네요', 1],
#  ['굳이 백화점 가서 명품 살 필요 없네요 여기가 더 저렴하고', 1],
#  ['물건도 많아요', 1],
#  ['저렴한 가격으로 매번 기분 좋게 사용하게 되네요', 1],
#  ['딜도 많고 쉽고 깔끔하게 잘 만들었네요', 1],
#  ['지갑하나 구입했지만연결되는 구매가 없는이유 예시   그린 펀칭패턴 소가죽 미니토트백  봐보세요', 0],
#  ['빼꼼도 아니고 이사진 한장가지고 어떻게 구매합니까 큰가방이 필요했는데 가방치수 숫자보며 결국 착핏은 상상으로든 다른 사이트 검색이든 고객을 위한 편의성이 부족해요',
#   0],
#  ['명품을 거의 구매해 본 적이 없어서 발란 들어와 봤는데 랭킹도 있고 현재의 유행을 알 수 있네요', 1],
#  ['좋은 앱입니다', 1],
#  ['굿굿 상품수 많고 브랜드가 다양하네요', 1],
#  ['좋은 제품 특가 많이 해서 저렴하게 살 수 있어 좋아요', 1],
#  ['블프라 패딩 알아보고 있는데 눈 돌아가네요', 1],
#  ['연말에 나에게 명품백 선물하고 싶어서 발란 찾고 있는데 다 맘에 들어요', 1],
#  ['명품 직구때 늘 불안한데 발란서 맘편히 믿고 사고 있어요', 1],
#  ['백화점보다 저렴해서 구매했습니다', 1],
#  ['눈팅하러 왔는데 브랜드 제품 정말 다양하네요', 1],
#  ['국내 최고의 명품 어플이라고 생각합니다', 1],
#  ['명품 검수도 잘된다고 해서 처음 깔았는데', 1],
#  ['요거요거 보는 재미가 있네요', 1],
#  ['다양한 제품 볼 수 있어서 좋아요', 1],
#  ['\n우선 앱 작동이 스무스하게 잘 되고 메인도 한눈에 들어오는 거 같아 사용하기 훨씬 편하네요', 1],
#  ['쇼핑하기에도 딱 좋고 잘 쓰고 있어요', 1],
#  ['친구가 트렌비에서 찾아서 보내줬는데 가격도 적당하고', 1],
#  ['마침 구하던 사이즈도 딱 있어서 바로 질렀어요', 1],
#  ['하나만 사도 무료로 배송해주니까 쇼핑할때는 트렌비만 찾게 되네요', 1],
#  ['다른데서 못 보던 아이템도 많고', 1],
#  ['제품만 보내면 알아서 검수도 꼼꼼하게 하고 정품 인증도 전문적으로 해주니까 훨씬 좋아요', 1],
#  ['\n앞으로 거래 할거 있음 걍 스트레스 안 받고 트렌비에다 맡기는게 이득이에요', 1],
#  ['해외 직구 사이트에서도 잘 못 봤던 흔하지 않은 제품들이 많아서 자주 찾게 되네요', 1],
#  ['보통 그런 아이템들은 비쌀텐데 생각보다 가격도 괜찮아서 자꾸 지갑이 열려요', 1],
#  ['ㅎㅎ\n계속해서 좋은 아이템들 많이 소개해주셨으면 좋겠습니다', 1],
#  ['\n얼마 안되서 빠르게 확인해서 처리해주시고 판매자분 통해서도 한 번 더 추가로 안내를 주셨어요', 1],
#  ['단순 오류여서 배송도 별다른 문제 없이 일정보다 빠르고 안전하게 잘 도착했습니다', 1],
#  ['보통 해외 배송 건은 바로바로 확인이 어려운 경우도 많던데 빠르고 친절하게 안내해주셔서 좋았어요', 1],
#  ['매번 옷이나 신발만 구매했었는데 보니까 가구나 조명 같은 것도 들어와 있더라구요', 1],
#  ['\n마침 이사 준비 중이라 인테리어 아이템 보고 있었는데 옷보러 왔다 요런 것만 왕창 질렀네요', 1],
#  ['\n워낙 큐레이션이 좋아서 가구나 가전 쪽도 아이템이 더 많아지면 자주 구매하러 올거 같아요', 1],
#  ['조와요', 1],
#  ['디자인이 심플하고 복잡하지 않아 쇼핑하기에 다른 몰들에 비해 훨씬 편해서 좋아요', 1],
#  ['굿', 1],
#  ['좋아요분류가 쉽습니다', 1],
#  ['태어나서 이딴 앱은 처음 봄', 0],
#  ['품절이 너무 많습니다', 0],
#  ['품절된거 확인해서 구매 안되게 해주세요', 0],
#  ['정말 인터넷광고를 모하러하냐ㅋㅋㅋㅋ 앱 절대안깔고 절대안삼', 0],
#  ['사용할때마다 애플로그인 문제생겨서 몇십분을 고생해야하고 앱을 어떻게 만들면 이렇게 못만드나요', 0],
#  ['오케이몰 쓰세요', 0],
#  ['구매한지 한달이지나고 판매자한테 연락이왔는데 재고없으니까 취소한다고함ㅋㅋ어이가없다', 0],
#  ['트렌비 직원들아 일좀하셈 ', 0],
#  ['기껏 날짜 전에 시켰더니 혹시 몰라서 배송날짜 확인하니 품절이란다 일 안할꺼면 왜 웹 만들었나 싶네', 0],
#  ['다른 곳과는 다르게 넘버원 이라는 타이틀이 어울리다고 생각합니다', 1],
#  ['좋은제품 잘샀습니다', 1],
#  ['어플도 뒤로 가기 한번 하면 느려터지고 불편해 죽겠네 차라리 트렌비가 다 낫다', 0],
#  ['무슨 상품 가격이 제각각이고 원래 만원 하는 상품인데 만원에 프로 세일이라고 거짓 정보가 들어간게 너무 많어', 0],
#  ['다른곳 보다 할인율도 높고 쿠폰도 많이 주네요  이런 곳을 이제야 알았네요 ㅠㅠ 앞으로 자주 이용해야겠어요', 1],
#  ['주가 지나서 배송 문의 하였으나 해외배송이라 조금 늦을 수 있다는 답변주셨습니다', 0],
#  ['주가 지나서 배송 문의 하였으나 해외배송이라 조금 늦을 수 있다는 답변주셨습니다', 0],
#  ['주 주가 지나도록 배송현황이 변함이 없어 문의드렸더니 다음 주말까지 받을 수 있도록 해준답니다', 0],
#  ['주 주가 지나도록 배송현황이 변함이 없어 문의드렸더니 다음 주말까지 받을 수 있도록 해준답니다', 0],
#  ['배송 지연에 대한 패널티는 없고 환불하려면 만원 위약금 지불이라니 답답할 노릇입니다', 0],
#  ['해외에서 배송을 보내지도 않아서 송장이든 등기든 조회도 안되는 상황에서 환불 위약금을 만원 요구하는건 상식적으로 이해도 안되고 납득이 되지 않습니다',
#   0],
#  ['\n\n내생애 최악의 해외배송 사이트트렌비', 0],
#  ['발란 덕에 요즘은 구매대행 안하구 이써요', 1],
#  ['가격도 저렴하고 쇼핑도 편리하네요 감사합니다', 1],
#  ['검수 영상 문자로 보낸다더니 보내지도 않고 물건에는 칼로 그은듯한 기스 나있고 ㅡㅡ', 0],
#  ['와 비회원은 주문 조회도 안되게 해놓고 되는 것 처럼 문의하려니까 또 가입하라고 하고', 0],
#  ['다른 사이트들에서 보지 못한 제품들이 많네요 신상도 많고 다양한 제품들이 많아서 선택의 폭이 넓어졌어요', 1],
#  ['유니크한 제품들도 많고 종종와서 트랜드 읽기도 좋네요', 1],
#  ['저번에 백화점에서 봤던 신발 주말에 다시 나가기 귀찮아서 사진찍어뒀다가 발란에서 주문했어요', 1],
#  ['역시 백화점보다 훨씬 저렴한 가격에 겟', 1],
#  ['좋아요', 1],
#  ['할인', 1],
#  ['다양성 좋음', 1],
#  ['검수를잘하는듯', 1],
#  ['굿굿', 1],
#  ['사이즈 표기가 젤 문제 한국사람 체형 대비 사이즈 없음', 0],
#  ['알아서 감으로 찾아야함 결국 사이즈 안맞아서 돈 버리는 경우가 많음', 0],
#  ['새제품을 주문했는데 왜 검수단계에서 스크래치가 나는지 이해불가명품은 그래도 되는건가', 0],
#  ['배송상태가 업데이트 제대로 안됨', 0],
#  ['결론은 트랜비 이용안할예정', 0],
#  ['진짜 지웠다가 다시 깔아도 똑같네요', 0],
#  ['최고에요', 1],
#  ['여자 패션 키워드는 있는데 남성 패션이나 남성 상품 탭은 없어요', 0],
#  ['이 앱 자체가 여성 쇼핑몰 중점인듯 합니다', 0],
#  ['사려던 마음도 싹 사라짐 서버 무한 로딩에 로그인도 자꾸 튕김 그냥 기본조차 안되있는 어플 사려 해도 서버가 팅기는데 무슨 옷을 팔겠다고 ㅋㅋ 광고 전에서버나 잘 챙기세요',
#   0],
#  ['앱도 괜찮고 잘만드신거같은데 푸시알람 안오게설정에서 바뀠는데 내용없는 없는 알람이 계속옵니다', 0],
#  ['광고로 유일해서 설치 악질', 0],
#  ['괜춘', 1],
#  ['다양한제품을즐기고 구매할수있어좋은거같네요', 1],
#  ['저렴한가격에 구매가능하고 믿을수있어 ', 1],
#  ['저렴한가격에 구매가능하고 믿을수있어 ', 1],
#  ['저렴히', 1],
#  ['다양한 물건', 1],
#  ['어렵게 구할물건들도 종종있어서 득보고있네요', 1],
#  ['다많은 제품 보여주세요\n감사합니다', 1],
#  ['자주쓰는 명품구매처에요 저렴한편이고 좋아요', 1],
#  ['슈퍼스타 구매 했는데 아무슨 검수도 안 하고\n보내는 곳이 어디있나요', 0],
#  ['상품 하자가 있는데', 0],
#  ['그냥 검수도 안 하고 보내네요', 0],
#  ['출근 길에 발견해서 회 착용 때문에 환불도 안 되고 이런 진짜하', 0],
#  ['살짝만 사용 안 하면 로그인 다시 하라고 뜨는 거 짜증나네요 로그인 다시 할라고 비밀번호 치는데 뭔 확인 버튼만 누르면 비번이 지 혼자 두글자는 더 늘어나더니 비밀번호 틀렸다는 오류까지 나고 비번 찾을라고 인증번호 받기 눌렀더니 뭔 인증번호 하나 오는데 분이나 걸리네요',
#   0],
#  ['괜츈네요', 1],
#  ['주 내내 배송 준비 중', 0],
#  ['주문 상태 좀 더 디테일하게 좀', 0],
#  ['문의하면 계속 본질에 벗어나는 답변만 하고 ㅡㅡ', 0],
#  ['도대체 로그인을 어떻게 하는건가요 로그인 페이지가 안나와요', 0],
#  ['회원가입 하라고만 되어있고', 0],
#  ['여기서시계삿는데 무슨사용한지개월만에 고장남 와돈만 오십날렸네', 0],
#  ['좋은 상품들이 저렴하게 올라오네요', 1],
#  ['아직은잘모르지만 검색하고상품보기편해요', 1],
#  ['여기서 살바에 머스트잇에서 사겠습니딘', 0],
#  ['다른 쇼핑몰보다 풍부한 볼거리가 많고 선택의 폭이 넓은것 같습니다', 1],
#  ['상품 옵션 고를때 조금더 세밀하게 고를수 있도록 해 주세요', 0],
#  ['월일 주문한 제품이 몇 주 동안 계속 국내 배송중으로 배송정보가 뜨고 있는데 한땀 한땀 꿰매는 수제 양복 만들듯이 한걸음 한걸음 조심스럽게 배송하는건지요',
#   0],
#  ['\n아무런 해명이나 사과 통지도 없어 고객센터에 접수했더니 고객선테 마저도 느릿느릿 일주일이나 되서야 미안하다는 답변이나 보내고\n대단한 업체인듯',
#   0],
#  ['구매신청도착예정 일', 0],
#  ['한달 후 현지바잉중', 0],
#  ['기다리다 ㅈ같아서 환불처리', 0],
#  ['응 그래도 수수료 떼간다 판매자가 잘못이든 물건을 배송 안했든 아무튼 우리는 수수료 떼간다', 0],
#  ['그냥 다들 크림 사용하세요', 0],
#  ['머갈통 텅텅 빈 상담원들직원들 빡쳐서 취소하는 환불 수수료로 생계 유지 하는듯', 0],
#  ['쓰레기 앱', 0],
#  ['구매하려는데 배송지 입력이 안되네요이', 0],
#  ['배송지 추가 우편번호 검색 들어가면  에러 발생해서 주문을 못해요', 0],
#  ['다른 사이트에 광고로 랑크되어올려있는 상품좀 보려고 그상품 클릭하면 왜그상품 볼수없고 항상 메인으로 넘아가죠다른 사이트들은 안그런데요',
#   0],
#  ['어플 어쩔수없이 설치하고 그상품 클릭해도 계속 메인으로 넘어감 사이트설치 강제로 시키려고 그런의도같은데 설치하면 링크되어있는 그상품 클릭하면 바로볼수있게는 해야 하잖아요 짜증나서 어플삭제해요',
#   0],
#  ['진짜 너무 화가나요 왜 우편번호찾기 버튼이 안눌리냐고요', 0],
#  ['ㅠㅠㅠㅠㅠ주소 입력이 안되서 주문을 못하잔아요', 0],
#  ['불편해요', 0],
#  ['반품이나 사이즈교환시 비용이 만만치 않네요', 0],
#  ['구매시 신중하세요', 0],
#  ['정품이고 너무 좋습니다', 1],
#  ['배송도 빠르고', 1],
#  ['아주좋아요', 1],
#  ['왜 여기제품은 정가보다 프로정도 더 비싼건지모르겟음 다른사이트는싼대', 0],
#  ['가격은 최저가 검색되게 해놓고 키즈사이즈 끼워놓고 실제 가격은 시세에비해 너무 비쌈네이버나 지마켓 옵션 장난질하고 다를게 없음', 0],
#  ['머스트잇측에서 재고부족으로 판매취소되면 ', 0],
#  ['달랑 프로 쿠폰 한달 기간짜리줘놓고 ', 0],
#  ['첫구매 쿠폰 기회는 날라갑니다', 0],
#  ['좋은제품마니올려주세요', 1],
#  ['오류가 너무 심해요', 0],
#  ['ㅠ\n물건 볼려고 누르면 하얀색 바탕화면 나오고 \n구매할려고 시간 투자해가면서 보는데 계속 오류 걸리니깐 앱만 껏다 켯다 무한반복 설치한지 몇일되지도 않았는데답답',
#   0],
#  ['오래되지는 않았지만 좋은 느낌이예요', 1],
#  ['해외배송 상황도 볼수있었으면 합니다', 0],
#  ['너무 좋아용\n맘에 들어용', 1],
#  ['다운받았는데 쿠폰없네요', 0],
#  ['전 물건도 잘받고 생각보다 빨리오긴 했는데 어머니 생신 선물 로 바뻐서 발란 으로 주문했는데 발란박스에 딸랑 구찌주머니 그렇게줌 그걸어떻게 최소한 쇼핑백만 이라도 주었다면 말안겠슴 이젠 발란에서 안삼 명품에 가치가 있지 그걸 어떻게 선물함 꼴랑 신발주머니 같은거 포장에서 최소한에 예의지 리뷰사진보니가 박스랑 쇼핑백 포장 다 가짜리뷰 이젠안삼 여기서',
#   0],
#  ['앱 반응속도가 정말 잣같지만 상품 구매에 관해서는 괜찮네요', 0],
#  ['대부분 구매대행이라 박스 상태는 기대하지 마셈', 0],
#  ['어플도 잘되어있고 쇼핑하기도 편해요', 1],
#  ['배송 보려니까 아이폰으로 로그인 하기 눌러도 안돼서 계속 시도 해봐도 안되는데 ', 0],
#  ['오류라면 빨리 시정해주시길 바랍니다', 0],
#  ['일점도 아깝네요', 0],
#  ['구매한디 일주일이 지나도록 재고 확인도 안하고 ', 0],
#  ['배송 문의하니 품절이라며 취소해버리네요', 0],
#  ['\n발란이나 머스트비에 안되는 이유가 있네요', 0],
#  ['불쾌합니다', 0],
#  ['도대체 언제 배송이 되려고 현지 바잉으로 넘어가지도않고 입금 완료만 띄워주시는지 그냥 예상수령일을 보여주질 마시던가요', 0],
#  ['수령일보고 생일선물 주문한건데 하도 기미가 안보여서 더는 못기다리겠어요', 0],
#  ['배송도빠르고', 1],
#  ['친절하게 대응해주시고 이쁘게잘받았습니다', 1],
#  ['오늘출발 주문했으나 이틀뒤 배송준비만 뜨더니 품절이라고 취소문자옴이용할일 도 없을거 같네여', 0],
#  ['짭이 좀 있네요', 0],
#  ['좋은상품 저렴히 살수있어 좋아요', 1],
#  ['색도 바래서 진품같지도 않아보이고', 0],
#  ['저는 가슴에 해골 로고가 있는 지포어 골프 티셔츠를 구매했는데 해골 로고가 없는 티가 배송이왔고 색도 바래서 진품같지도 않아보이고 환불요청해서 반품해간지 일이 되었는데도 아직도 환불처리도 안해주고 사과도없네요',
#   0],
#  ['벨트도 주문했는데 다른컬러가와서 라운딩 다 망쳤습니다', 0],
#  ['인터넷 광고에서 제품보고 클릭해도 어플로 연결되지않네요', 0],
#  ['그럴거면 뭐하러 돈들여서 광고하십니까 광고하는 목적이 제품판매가 아니라 어플 방문회 늘리는 거에요', 0],
#  ['그제품 분 찾아보고 포기 지웁니다', 0],
#  ['자동로그인 걸어놔도 매번 로그아웃되는데다가', 0],
#  ['심지어 얼마전부턴 업데이트해도 카카오톡으로', 0],
#  ['로그인이 안되는현상이있어서 사고싶은게 있어도', 0],
#  ['못사고있네요', 0],
#  ['카카오톡 로그인 되게 해주세요', 0],
#  ['상세이미지아왜 자꾸 짤려서 나와요', 0],
#  ['원하는 명품을 쉽게 구입했습니다', 1],
#  ['옷 사 입기 좋은 어플', 1],
#  ['품절은 품절이라고 바로 표기됬으면 좋겠어요', 0],
#  ['편의성 있고 아주 유용하게 사용하고 있습니다', 1],
#  ['화면도 깔끔하고 단순해서 거래하기 쉬워서 좋아요', 1],
#  ['아이템 구성이 한 눈에 들어와 쇼핑하기에 매우 편리하고 좋습니다', 1],
#  ['명품을 싸게 살 수 있어 좋고', 1],
#  ['여러가지 패션 의류나 캠핑용품 등 다양하고 질 좋은 제품이 있어 자주 이용하고 있어요', 1],
#  ['앞으로 계속해서 이용 할께요 감사 드립니다', 1],
#  ['혜택도 좋은 것 같고 쿠폰도 구간별로 잘 지원해주는 것 같으며', 1],
#  ['고품질의 질 좋은 제품들도 기대 이상으로 꽤 많이 확보되어 있는 것 같아요', 1],
#  ['그래서 유사한 제품에 대한 라인별 퀄리티를 다양하게 비교하면서 확인할 수 있어서 좋은 것 같네요', 1],
#  ['또한 네이버페이처럼 다양한 결제 시스템을 호환 지원 가능하게 해놓아서 결제 편의성이 정말 뛰어나네요', 1],
#  ['이때까지 수십년간 사용해본 사이트 중에서 단연코 최고라 할만합니다', 1],
#  ['다만 조금 보완해야 할 점을 요청한다면 리셀상품의 경우 화질적인 측면에서 제품의 퀄리티와 상태를 선명하게 확인할 수 있도록 제품 사진에 대한 해상도를 좀 더 높여서 업로더해주시면 좋을 것 같습니다',
#   0],
#  ['현재 갤럭시 노트  사용중이므로 화질 대응에는 전혀 문제없으며 의류의 경우에는 최고 해상도로 설정 후 쇼핑합니다', 1],
#  ['베타이후가 확실히 편하고 좋아요 그런데 알림설정은 어디서 하는지 잘 모르겠네요', 1],
#  ['나머지는 리뉴얼되어서 많이 좋아진 듯 합니다', 1],
#  ['아 그리고 검색화면에 나오는 목록의 사진 크기가 살짝 크고 여백이 많은 듯 한데 이걸 좀 줄여서 한 화면에 보다 여러 상품을 볼 수 있으면 좋을 것 같아요 사진들도 하나만 나오는 것이 아니라 좀 더 추가하면 좋을 것 같구요 검색한 목록에서도 아예 거래내역이 없는 것들이 왜 최근인기순으로 나열하면 위쪽에 있는지 잘 모르겠어요',
#   0],
#  ['검색결과가 깔끔하게 정렬되는것도 맘에드는 부분중 하나입니다', 1],
#  ['트렌비에서 구매 번정도 해봤는데 쿠폰도 다양하게주시고 배송비도 무료에다가', 1],
#  ['앞으로도 계속 쿠폰 마니마니 주시고ㅎㅎ 계속 사용하겠습니다', 1],
#  ['그리고 랭킹 서비스는 옷 못입는 저에게는 가뭄에 단비같은 느낌이였습니다', 1],
#  ['ㅠㅠ ㅠ사랑해용 ㅋ', 1],
#  ['세일 정보 확인할 때 유용하게 사용중입니다', 1],
#  ['다만 푸시알림으로 찜한 상품에 대해서라도 가격 하락이나 입고 유무 등 받는 기능이 생겼으면 좋겠습니다', 0],
#  ['그리고 리셀상품의 경우 네고하기 같은 기능이 추가됐으면 합니다', 0],
#  ['감사합니다', 1],
#  ['모든 상품이 무료배송인거 같네요 넘 좋아요', 1],
#  ['익일 배송으로 하루만에 오는것도 넘 편하구요', 1],
#  ['도 다른 앱처럼 정신없이 옷사진들이 바뀌지 않아서 맘에 들어요', 1],
#  ['옷을 벌밖에 안 사봤지만 다 만족스러워서 환불한 적은 아직 없네요', 1],
#  ['요 몇 주 동안 써보면서 깨달은건 리뷰많은 상품은 사기로 결정했을 때 안 사면 품절 빨리 된다는거', 1],
#  ['기능과 아이디어는 패션 앱중 정말 혁신적이고 되게 좋습니다', 1],
#  ['하지만 보완해야 할 점이 몇 군데 보이는 것 같아서 의견 보내봅니다', 0],
#  ['패션 전문가들은 알지만 일반인들은 모르는 패션용어  각 패션용어에다 부가 설명을 붙이거나 각 패션 카테고리별로 예시 코디컷들을 보여주는 창 하나를 추가하셔도 정말 좋을 것 같네요',
#   0],
#  ['기능 상 보완 오늘 처음으로 회원가입해서 게시물 몇 개씩 보는데 같은 상품인데 다른 가격으로 노출되는 상품들이 많네요', 0],
#  ['한눈에 보면 좋을텐데 이것들만 수정되면 메이저 패션 앱으로 거듭날 것 같은 좋은 느낌을 받았습니다', 0],
#  ['유저들의 의견도 반영하려고 하는 모습도 보이는 것 같네요', 1],
#  ['번창하십시오', 1],
#  ['정말 잘 쓰고 있는데 몇가지 기능이 추가로 생기면 더 좋을거 같아요', 0],
#  ['정렬 기준에 판매순과 리뷰순이 생기면 좋을거 같습니다', 0],
#  ['찜 해놓은 상품을 사용자가 임의로 그룹으로 묶어 정리할 수 있은 기능이 생기면 편할거 같습니다', 0],
#  ['괜찮다 싶어 찜 해놓은 상품들을 보니까 너무 중구난방으로 섞여있어 보기가 힘들어요 이정도만 돼도 트렌비이란 앱이 더 인기가 많아질 수 있다고 생각해요',
#   0],
#  ['화이팅 하시길 바랍니다', 1],
#  ['기획전 상품들도 좋은거 같고', 1],
#  ['아무래도 사이즈나 디자인은 온라인으로 디테일하게 확인하기는 좀 힘드는데 다각도로 모델 사진과 제품 상세컷이 다양해 도움이 됩니다',
#   1],
#  ['교환 반품시에 드는 비용이나 시간을 생각 해 보면 특정 브렌드 때문에 앱을 사용하기에 저로썬 자주 이용하지 않게 됩니다', 0],
#  ['자주 이용할 수 있도록 콘텐츠들이 많았으면 좋겠습니다', 0],
#  ['저렴한 가격으로 매번 사용하게 됩니다', 1],
#  ['직관적인 인터페이스 ', 1],
#  ['없는게 없는 쇼핑몰이라 네이버 검색보다 먼저 찾게되네요', 1],
#  ['결제와 같은 일부 기능들은 늘 그래왔듯 신속히 개선될거라 생각되니 크게 걱정은 되지 않습니다', 1],
#  ['언제나 소비자를 위해 고민해주시는점 감사하게 생각하며 요즘 핫한 수입 중저가 가전 등도 추가되길 기원해봅니다', 1],
#  ['명품 판매하기 매우매우매우 유용한 앱입니다', 1],
#  ['앱이 엄청 좋은데 이런 앱이 있다는 홍보가 자주 보이지 않아서 꽤 많은 사람들이 모른다는 게 아쉽네요', 1],
#  ['앱 와 탭들의 디자인들도 쉽고 심플합니다', 1],
#  ['다만 이건 저의 개인적인 취향이지만 앱로고가 조금 별로네요', 0],
#  ['앱 로고와 앱 이름에 따라서 소비자가 그 앱에 대한 이미지와 분위기가 확 달라지는데 조금 아쉽네요 제 생각에는 앱 이름이나 로고를 수정하고 광고를 한다면 정말 정말 대성할 앱이라 생각합니다',
#   0],
#  ['주식이 있다면 사고 싶을 정도로요 이 앱을 만드는데 일조하신 모든분들께 감사를 표합니다', 1],
#  ['오래전부터 사용하는 사이트인데 최근 메뉴도 조금씩 개선되고 사용하기 편해지는거 같아 좋습니다', 1],
#  ['정품 명품은 이곳이 가장 안전해서 자주들어가는데', 1],
#  ['초기화면에 제가 관심없는 상품이 떠서 살짝 아쉽습니다', 1],
#  ['인기상품 내가 좋아할만한 상품시기별 추천상품 등으로 다양하게 보여주면 더 좋을거 같습니다', 0],
#  ['여름부터 알게되어서 사용했는데 진짜 잘 이용하고 있어요 특히 여름에 겨울옷 특가할때 겨울점퍼하나 샀는데 진짜 완전 득템한기분입니다',
#   1],
#  ['어떤건 너무 상품이 많고 복잡하고 어떤건 너무 상품이 없었는데 트렌비는 딱 제가원하는 스타일들이 많이 있고 사용법도 너무 간단해서 최종적으로 남은 어플이에요',
#   1],
#  ['그 후로는 틈틈히 들어가서 세일 상품도 자주 보게 되는거 같아요 세일 제품 아니더라도 기본적으로 백화점보다 조금씩 저렴하거나', 1],
#  ['매장에는 없는 상품들도 있어서 쇼핑하기 정말 좋아요', 1],
#  ['사용자에게 편리한 를 갖추고 있는 어플리케이션이라는 생각이 들었습니다', 1],
#  ['아이템 구성이 한 눈에 들어와 쇼핑하기에 매우 편리하고 좋습니다', 1],
#  ['앞으로도 편리하고 간편하게 이용하겠습니다', 1],
#  ['좋은 어플리케이션 개발해주시고 구성해주셔서 감사드립니다', 1],
#  ['앱 깔끔하고 조아요', 1],
#  ['여러 사이트를 검색하지만 결국 최후로 구매결정하게 되는 사이트가 바로 머스팃입니다', 1],
#  ['감사합니다', 1],
#  ['가격이 좋아요', 1],
#  ['작성하려고 하는데 사진 선택하고 체크버튼 눌러도 반응이없어요', 0],
#  ['전혀 안 돼고 시간만 끌어요', 0],
#  ['마지막엔 안됨 반품하려면 수수료 왕창', 0],
#  ['뒤로 가기 누르면 처음으로 돌아가는건 리뷰보니 작년부터있는 문제인데 고치지를 못하시네요 ㅎㅎ 올 봄에 가입해서 첫구매했는데 다시 구경왔다가 불편해서 적립금있는데 수신거부하고 걍 어플지웁니다',
#   0],
#  ['시간낭비에요', 0],
#  ['어차피 특가라해봤자 싼것도아니고 말로만 특가지 쿠폰으로 장난치는거 다아는데 한곳에 모아볼려고 어플쓰는거지 이렇게 불편하면 어플을 왜써요 쓰레기어플 안써요',
#   0],
#  ['생각나면 웹페이지로 볼게요   ', 0],
#  ['가방 로고 아래부분에 기스 있어서', 0],
#  ['교환해 달라니까 미세 기스라고 교환하려면 돈내라고함 뭐 이런 경우가 다있나 싶음 최악임', 0],
#  ['만족감 최고', 1],
#  ['이거진짜 개웃긴게 싹다 정품도아닌듯하고 정품인지도 모르는물건 팔고', 0],
#  ['판매자 연락하기싫어서 고객센터로 신청했다 하니깐 고대로 판매자랑 직통으로 전화연결 시켜버림', 0],
#  ['굉장히 실망입니다', 0],
#  ['솔직히 진짜 빡쳤습니다', 0],
#  ['트렌비는 주문 상세 내역을 총 단계주문접수현지바잉중해외배송준비중배송중배송완료로 구분해 유저에게 보여주고 있습니다', 0],
#  ['전 해외배송이 필요한 상품을 월일 주문했고 월 일에 주문상세내역에서 해외배송준비중 단계임을 확인했습니다', 0],
#  ['해외배송준비중은 현지 물류센터에 상품이 입고되어 순차적인 검수 및 배송 준비중입니다', 0],
#  ['라고 설명되고 있고요', 0],
#  ['그리고 월 일에 고객센터로부터 제가 주문해서 주동안 기다린 물건이 구매처에 의해 품절되었다는 연락을 받았습니다', 0],
#  ['일을 도대체 어떻게 하는 겁니까  현지 구매처로부터 이 물건이 바잉이 완료 되었는지 확인조차 제대로 되지 않은 채로 해외배송준비중이라는 상태로 노출시키는건 뭡니까 실제로 물건은 물류센터에 존재하지도 않았던 것인데품절이었으니 그것을 구매한 유저에게는 현지물류센터에 있다고 고지하는것은 기만아닙니까 해외배송물건의 특성상 유저들은 내가 구매한 물건의 현재 위치 및 상태에 예민할 수밖에 없습니다',
#   0],
#  ['세관을 잘 거쳐 물류센터에 들어왔는지 현지에서 바잉이 되었는지 등 해당 단계들에서 문제가 많이 발생하는 것을 알기 때문에 굳이 트렌비와 같은 직구 사이트를 통해 구매를 하는거고요',
#   0],
#  ['이런 부분에 대한 수고를 덜어줌은 물론 현지 구매처와의 빠르고 정확한 소통을 책임져주는 곳이라고 생각하니까요', 0],
#  ['그런데 이번 사태는 애초에 판매처로부터 물건이 제대로 있는지 확인을 먼저 하지도 않고 현지물류센터에 입고되었다는 고지를 하는건 심지어 물건이 있는지 여부 확인을 주동안이나 하지 않다가 늦게서야 하는 트렌비의 운영 방식에 의문을 품을 수밖에 없는 사건이었습니다',
#   0],
#  ['플랫폼과 현지 판매처의 소통이 도대체 어떻게 굴러가고 있는 것인지 의문이네요', 0],
#  ['전 품절된 상품이 물류센터에 있다고 생각하고 주 넘는 시간동안 기다린 꼴입니다', 0],
#  ['심지어 기념일 선물이었는데요 ㅎㅎ', 0],
#  ['세일이나 특가 광고는 푸시알림으로 엄청 보내놓고 구매 유도하기 위해 쿠폰 왕창 뿌리고 사람들 모아 상품이 실제로 있다는 보장이 있든 없든 일단 쿠폰써서 구매하게 하고 배송 준비중이라는 말로 안심시켜둔 뒤 나중에서야 물건 유무 확인하고 품절됐다고 또 사과말씀 돌릴건가요 그러면 사람들이 그 사이에 만료된 쿠폰 쓰지 못하고 제 값 주고 물건을 구매하니 이건 결국 트렌비의 전략인가요 별 생각이 다 드네요',
#   0],
#  ['\n\n애초에 이러한 프로세스를 허술하게 구성하고 운영한 기획운영팀에게 책임을 묻고 싶습니다', 0],
#  ['고객센터 역시도 말로만 사과할 게 아니라 이 프로세스에서 시간을 낭비한 애꿎은 유저들에게 확실한 대책 제시를 할 수 있는 메뉴얼을 구축하시면 좋겠습니다',
#   0],
#  [' 직원분께 귀책이 있는 것도 아닌데 계속 정말 죄송하다고만 말씀하시는 분께 이런 이야기 하고 싶지 않아 여기에 남깁니다', 0],
#  ['싸게잘사고있어요', 1],
#  ['발란보다 많이비싸네요', 0],
#  ['로그인이 안됩니다', 0],
#  ['모바일 검색 카톡연동 가입하고 앱깔고 로그인하려하니 먹통', 0],
#  ['분명 모든 백화점 가능하다고 했는데 왜 거짓말을 시키조', 0],
#  ['해외배송 한달이상소요음', 0],
#  ['해외배송 한달이상소요 고객센터 전화시 불친절응대로 재구매의사 없음', 0],
#  ['진짜 최고임요', 1],
#  ['담당자분이 너무 친절하심', 1],
#  ['로딩 속도 너무 느리고 상품을 본후에 뒤로가기하면 스크롤이 다 올라가 있어서 짜증납니다', 0],
#  ['이건 기본아닌가요', 0],
#  ['별하나도 아까움 양아치쓰레기앱 욕도아깝다 주동안 기다린 물건이 스크레치가 있다하여 원하시면 재주문해준다해서 기다렸는데 일주일뒤 그 사이 가격이 올랐다면서 차액 만원을 더 지불하면 준다함 싫으면 취소하라고 어이가 없어서 이런게 어딨냐 하자있는 물건이라고 당신들이 정상물품으로 재구매해준다더니 왜 내가 차액을 지불해야하나 그때 세일가였으니 구매한거지 주나 더 오래 기다리게 해놓고 미안해하긴 커녕 이런 말도 안되는 경우가 어딨냐 그랬더니 구매시 상세페이지에 가격변동이 있을수있다고 홈페이지에 나와있대요 하하 그러면서 싫으면 취소하라고  고객을 완전 호구로 아는 양아치앱이에요',
#   0],
#  ['일부러 하자 있는 물건 팔지 못하는것 싸게 파는척 하고 내놓은뒤 스크레치있어 출고 안했다고 해서 재구매 유도한 뒤 가격 높여 받는게 상술인듯 아님 스크레치 나서 어차피 못 파는거 고개한테 팔면 그만이고 양심도 없고 상도덕도 없고 뻔뻔하고 아주 그냥 마인드가 썩었네요',
#   0],
#  ['가격대 넘조아용백화점에 안가도 편하게 고를수잇구용', 1],
#  ['굿드굿드', 1],
#  ['반품도 잘 안되고 반품비 만원 ㅡㅡ', 0],
#  ['범고래 나이키 원이라고 앱 깔아 보니 어디에도 그 가격은 없네 미끼입니까', 0],
#  ['최악 광고도 최악 수신거부도 자리 인증번호를 초안에 입력못하면 수신거부도 못함 최악 그자체', 0],
#  ['배송지연 안내가 문의 전에 없는 점은 아쉽지만', 0],
#  ['합리적인 가격으로 파정 구입했어요', 1],
#  ['가 잘 되어있어서 사용하기도 편하네요', 1],
#  ['트렌비 최고', 1],
#  ['가입 귀찮아서 비회원으로 결제했는데 주문확인하려면 무조건 어플 다운받아야함 대체 그럼 비회원주문 왜있는건가요', 0],
#  ['어플 개발자들이 회사를 망조들게 할려나보네요', 0],
#  ['업데이트 눌렀더니 대기중으로 무한루프중ㅎ 업데이트를 안하면 기존 버전으로 들어가야 되는거 아닌가요 ㅉㅉ', 0],
#  ['판매자가 주문한지 일짜에 배송준비중 띄워놓더니 지맘대로 취소때림ㅋㅋㅋㅋㅋㅋㅋ골때린다 쓰지마세요', 0],
#  ['배송도 빠르고', 1],
#  ['여러 상품을 한번에 볼수있어 너무좋고 할인 이런게 잘 볼수있어 너무좋네요', 1],
#  ['역대급 개판인 서비스 상품 결제이후 일동안 배송정보 업데이트 및 상담 불가 인생 최악의 고객서비스를 경험해 보고싶은분들께 추천합니다',
#   0],
#  ['크림과똑같은 매장 제품 가격이 만원 이상 비싸게 올리는 사이트ㅡㅡ', 0],
#  ['로그인이 안됨', 0],
#  ['광고는 할인 몇할인 등 되게 파격적인 세일을 하는거마냥 하면서 막상 들어가보면 원가를 무지막지하게 높여놓고 할인율을 올리는 의미없는짓거리가 되있는 허위광고 투성이에 실상도 엉터리인 앱입니다',
#   0],
#  ['럭셔리 쇼핑이 아니라 허위광고 엉터리 쇼핑이 맞겠네요', 0],
#  ['앱 이름 부터 바꾸세요', 0],
#  ['모든 전상품 정품인가요', 1],
#  ['만원돈주고버버리옷을시켰는데주넘게걸려서받았습니다', 0],
#  ['그런데옷에보풀이있더군요', 0],
#  ['떼어질줄알고손으로떼어봤는데정도가너무심해서 반품했는데 공장에서그럴수있다고하자가아니라고택배비를 받더라고요너무기가막히더군요', 0],
#  ['보풀이라면떼어져야하는데고대로붙어있는데누가그돈주고버버리를사겠냐고소비자입장에서는 택배비만원을떠나서너무기분나쁩니다', 0],
#  ['환불이나빨리해주는것도아니고 기다리는시간도있는데받았을때그런상품오면기분이어떤지사진까지첨부하고싶습니다', 0],
#  ['이게하자가아니면어떤게하자고문제인지누가이런식으로옷을만듭니까', 0],
#  ['진짜 어플 속도가 너무 느려서 답답하고', 0],
#  ['주문 잘못해서 취소하고 재주문 할려 하는데 취소도 하루 종일 걸리고 고객센터 들어가서 문의 하려는데 너무 느려서 영업시간 지났다네요',
#   0],
#  ['진짜 최악의 어플입니다', 0],
#  ['요즘 옷들 신상 유행옷들을 추천해줘서 좋아요', 1],
#  ['잘 모아져있음 간편함', 1],
#  ['광고 보고 옷이 이뻐서 클릭하니 발란으로 연결은 되는데 광고 하던 옷이 아니고 메인 페이지로 가면 그옷은 어찌 구매하나요', 0],
#  ['모바일로 보는데 광고에서 옷 이름이 나오는거도 아니고 달랑 이미지만 있어서 클릭하면 옷을 찾을수가 없어요', 0],
#  ['반품시 불만족', 0],
#  ['아주만족입니다', 1],
#  ['진심 개좋음', 1],
#  ['쓰지마세여 제발 차라리 번개장터나 당근마켓이 훨나음 괜히 택배비 날림 에휴', 0],
#  ['쓰윽둘러보기 좋음 ㅎ', 1],
#  ['상품받았을때 확인해보니 퀄리티가 가품못지 않더라구요', 0],
#  ['마감처리도 잘 안되어있고 정가품 문의해보니 다행히정품은 맞다고 하더라구요', 0],
#  ['요즘 발란 말 많던데 그냥 다른 어플 쓰시는게 나을듯 싶네요', 0],
#  ['구입 후 리뷰보고 고객센터 문의 안된다고 하길래 포기하고 그냥 입기로 했어요', 0],
#  ['좋아오', 1],
#  ['상담 서비스 진짜 느립니다', 0],
#  ['주말에 시간째 기다려도 답장을 안 주시네요', 0],
#  ['평일은 그래도 분 만에 주는데 주말은 개느려요', 0],
#  ['그리고 위탁 판매 맡겼는데 판매 현황이 오류인지 뭔지 안 뜨네요', 0],
#  ['빠른 배송 너무 좋습니다', 1],
#  ['아니 앱 사용하는데 손가락확대가 안되나요', 0],
#  ['상품도착예정일이 지나서도 제품 출고가 확인되지 않고 상담원께서는 더 기다리라 그렇지않으면 수수료는 고객님 부담으로 일관하시네요', 0],
#  ['업체 측 과실인데 왜 고객이 취소 수수료를 물어야할까요', 0],
#  ['할인도 많이 하고 좋네요', 1],
#  ['어디 보따리상들이 들어와서 장사를 하는지 몰라도 구입하고 결제 하면 품절이라고 환불되고 하나는 현지 바잉 시도중이라고 시간만 질질끌고동네 구멍가게도 이렇게 운영하면 망함',
#   0],
#  ['낚시질 짱 언제부턴가 작은게 싸고 큰게 비쌈ㅋ 차야 ㅋ 작은건 겁나 할인광고 큰건 돈 더 내놔ㅋ', 0],
#  ['여기 믿음직한 명품 쇼핑몰 백만번 고민하고 첫구매했는데 대만족입니다', 1],
#  ['판매자정보 정확하고 할인쿠폰도 마니주고 가격도 타싸이트에비해 좀더 저렴히 구입가능하네요', 1],
#  ['몬가 관리받는 느낌', 1],
#  ['아니 왜 리뷰를 삭제하지 일단 제품검색했을때 일단 가격비교를 하기힘들게 셀러들이 상품명을 엉망으로 올린다 세일많이하는것처럼 보일려고 오픈마켓보다 정사 훨씬비싼것 천지 정품 검수 어쩌고 자랑하지만 검수사진도 없거나 사진하나 달랑 떠있고 자체 상품설명 자세한 설명이 없는 상품이 대다수',
#   0],
#  ['아니 왜 리뷰를 삭제하지 일단 제품검색했을때 일단 가격비교를 하기힘들게 셀러들이 상품명을 엉망으로 올린다 세일많이하는것처럼 보일려고 오픈마켓보다 정사 훨씬비싼것 천지 정품 검수 어쩌고 자랑하지만 검수사진도 없거나 사진하나 달랑 떠있고 자체 상품설명 자세한 설명이 없는 상품이 대다수',
#   0],
#  ['판매자 관리좀 제대로 해주세요\n환불 불가한 상품이라 어쩔수 없이 손해보고 매물 내놨습니다', 0],
#  ['\n제품만 빨리 왔어도 환불 가능한 시스템만 잘 구축해놨어도 제가 손해를 봤을까요', 0],
#  ['\n요즘 명품 판매 하는 곳들 많아지는데 머스트잇은 앞으로 절대 사용 안할겁니다', 0],
#  ['유튜브에서 광고 보고 궁금해서 깔아봤는데 요거 괜찮은 앱 같네요 ㅎㅎ 일단 브랜드가 너무 많아서 좋아요', 1],
#  ['우영미 만원 올리는건 좀 아니지않나', 0],
#  ['별로', 0],
#  ['역시 믿고 사는 트렌비 정품 확실하니까 의심할 여지 없이 매번 구매하게 되네용', 1],
#  ['굳굳', 1],
#  ['한참 기다리게 해놓고 또 지연된다고 취소해준다고 했으면서 취소도 빠르지 않네요', 0],
#  ['대단하다 정말', 0],
#  ['환불도 주말에만 안들어온다면서 다른 쇼핑몰에서는 바로 바로 해주던대 온라인임에도 불구하고 환불을 하면 최소 일을 걸려서 환불을 해주고 예정일보다 배송이 늦어진 상품이 언제 오는지 자기네들도 모른다고 하네 ㅋㅋ',
#   0],
#  ['로그인 버튼이 안 눌려요', 0],
#  ['창이 넘어가질 않아요', 0],
#  ['좋아요', 1],
#  ['어플켤때 이엘 나오는거 못가리나요\n안그래도 요즘 말 많은데 내 핸드폰에서까지 봐야되나 싶어서요', 0],
#  ['정보도얻고 각격도좋고 자주사용중', 1],
#  ['최악임 프라다 로봇패치 버킷백 구매 햇으나 쓰레기가 옴 검수 상태 라고 해서 구매 검수사진에 없는 담배냄새 향수냄새바닥에 음식물 찌꺼기붙어잇고 안쪽안감 다 닳아잇음곳곳 기스 여러개발견 항의하니 트랜비는 책임이 없다함 썩을반품비내라함 ',
#   0],
#  ['그래쓰레기 장사 오래못갈듯해서 반품비주고 반품하고 탈퇴함절대사지마세요', 0],
#  ['트렌비 바로 판매하기 이용했는데 한번도 쓰지도않은 제품인데 상품미달이라길래 그럼 무슨등급이냐 했더니 그것도 안알려주고 계속 똑같은말만 반복 배송비 환불도 안해준다면서 제대로 된 설명은 없음 그래서 등급낮춰서 또 보냈는데 진행상황 알림이 없어서 들어가봤더니 판매취소저번에도 그러더니 두번째',
#   0],
#  ['일을 왜이렇게 합니까 고객센터 전화해서 문의했더니 고객센터도 상품미달이라고만 함 가품이라는거냐했더니 그건아니라고함 배송비환불해달라했더니 그건 어렵다고 함 ㅋㅋ 정확한 상품등급을 적어놓지도 않고 상품미달이라고 판매취소된건 바로 말해주지도 않고 반송보내면서 택배비환불도 안해준다는데 ㅆㄹㄱ같음 ',
#   0],
#  ['서비스란게 없음 이럴거면 위탁판매든 바로판매든 하지세요', 0],
#  ['정확한 기준이뭐고 뭐때문인지 설명을 해줘야지 그냥 기준미달이라고 반송해버리면 어떡합니까 \n진짜 트렌비 쓰지마세요', 0],
#  ['최악입니다', 0],
#  ['믿고 구매할수있는거같아요', 1],
#  ['선물하기도 좋아여', 1],
#  ['가방을 구매하고 다음날 문자 온게 검정 가방은 품절이니 다른 색 가방 안할거면 반품해라 라고 왔습니다', 0],
#  ['품절이면 사이트에는 왜 판매중이냐니까 아직 수정을 안해놨다네요', 0],
#  ['살수있는 가방이 없는데요', 0],
#  ['\n사과 안하시네요', 0],
#  ['잘 이용 중이에요 저는 직구의 직자도 모르던 사람이었는데 트렌비를 통해서 편하게 직구하고 있어요', 1],
#  ['근데 고가의 상품들을 사다보니 배송이 걱정되긴 했지만 집까지 무사히 도착하는걸 보고 마음이 놓이더라구요', 1],
#  ['믿음직스러워서 계속 이용하고있어요', 1],
#  ['다른 앱도 이용해보려고 했지만 트렌비가 제일 편하고', 1],
#  ['가격도 최저가부터 나오고 판매자가 누구인지 트렌비 인증 파트너인지도 볼 수 있으니까 좋았어요', 1],
#  ['세일도 자주 하고', 1],
#  ['제품군도 다양하니까 잘 구경해보세요', 1],
#  ['트렌비 추천해요 아 배송도 되게 빨라요', 1],
#  ['합리적 입니다', 1],
#  ['할인도 잘 해줘서 한번씩 잘 이용하고 있습니당', 1],
#  ['트렌비에는 상품 수도 많고', 1],
#  ['제가 좋아하는 디자이너 브랜드 상품이 많더라구요 넘 잘 쓰고 있어요', 1],
#  ['트렌비가 가성비 갑인듯합니다', 1],
#  ['백화점가면 실물로 확인 못하는 것들도 많은데 트렌비는 가짓수도 많고', 1],
#  ['저렴하게 살 수 있어서 정말 편하게 이용 중이에요', 1],
#  ['여행 갈때 데일리로 멜 가방이랑 신발 샀습니당 ㅎㅎㅎㅎ 트렌비  등급까지 도전 ㅎㅎ', 1],
#  ['아빠 생신 선물로 지갑 사드렸어요', 1],
#  ['더 좋은거 사드리고 싶지만 트렌비 덕분에 저렴하게 구입했어요', 1],
#  ['트렌비에서 샤넬 구매했어요', 1],
#  ['제 월급이 샤넬 가격을 따라잡질 못해서 영원히 못 만져볼 줄 알았는디 ㅎㅎ 이렇게 갖게되네요', 1],
#  ['다행히 ㅠㅠㅠ', 1],
#  ['트렌비가 할인도 많이 하지만 최근 시세도 쉽게 알수 있어서 가격 비교하기 좋더라구요 친구들한테도 추천하게 되네요', 1],
#  ['판매됐다고해서 보냈더니 갑자기 로고가 이상있다구여 그럼 판매신청할때 사진은 왜 올리고 그걸 검사하는데 몇일이나 걸리구요 그럼 그냥 신청들어오는 순서대로 확인만 누르시나보죠 일편하게 하시네요 신발이커서 박스까지 구매해서 보냈더니 박스비는 못준다구요 참나 그럼 저희는 박스비에 택배비에 수수료에 지금 장난합니까 처음부터 검수를 잘하세요 그렇게 일하시는 미안하지 않으신가요 제가 신발 안팔아도됩니다',
#   0],
#  ['근데 고객센터에서 메뉴얼데로 말씀하시는데 굉장히 불쾌하고 모든 지인들에게 트랜비에대해 이상황을 꼭 알리겠습니다', 0],
#  ['이거보시는 모든 판매자분들 한번더 생각해보세요 진짜 최악입니다', 0],
#  ['저별하나도 아깝네요', 0],
#  ['옷이든 신발이든 가방이든 저렴하게 구매할 수 있다는게 최고네요', 1],
#  ['ㅋㅋ 고가 상품의 경우 배송 서비스도 정말 잘 되어있어서 믿음이 가더라구요 트렌비는 제휴 수선점도 있어서 가방같은 경우에 수선 맡기기도 좋을것 같아요 챗봇 상담도 잘 되어있고 마음에 드는 상품 밑에 비슷한 스타일로 추천도 잘 해주고 되게 편했어요 국내외 백화점 편집샵에서 직바잉도 되고 감정사들이 따로 있어서 중고거래 할때도 걱정도 덜하구요 트렌비는 파워정품 명품 플랫폼답게 이용자들도 많아서 더 신뢰가요',
#   1],
#  ['목걸이 샀는데 이번 신상인데 할인이 꽤 많이 들어가네요', 1],
#  ['트렌비에서 사는게 최저가가 맞긴 한가봐요 ㅋㅋㅋ', 1],
#  ['디오니소스 너무 사고싶었는데 트렌비에서 구매했어요 추천해요', 1],
#  ['가성비 좋아요 너무 예뻐서 애지중지하는 중이에요', 1],
#  ['유명 브랜드 구경할 맛 나요', 1],
#  ['타임딜 같은 할인 잘 노리시면 득템 가능해요', 1],
#  ['아미 모자 너무 귀여워서 바로 득템했어요', 1],
#  ['ㅋㅋㅋ 트렌비는 할인율이 너무 좋은것 같아요', 1],
#  ['할인율 높아지면 바로 사게 되는 마법  저처럼 중독되지 마세요', 1],
#  ['트렌비에 제가 애정하는 브랜드가 많아서', 1],
#  ['배송도 되게 빠르고', 1],
#  ['고객센터 답변도 빠르고 만족했어요', 1],
#  ['얼마전에 남자친구 선물로 벨트 사줬는데 하자 없고 잘 왔어요', 1],
#  ['패션 잡화도 많이 팔아서 구경하기 좋은 어플이에요', 1],
#  ['배대지같은거 필요없어서 편하고 세일 자주해요', 1],
#  ['스톤아일랜드랑 메종 싸게 잘 샀네요', 1],
#  ['트렌비에서 부모님 선물도 사드리고 집들이 선물도 사네요 정작 저를 위한 선물은 아직  요즘 쇼핑몰들이 배송이 워낙 빠르지만은 직구인데도 익일배송이 된다는게 매우 편하고요',
#   1],
#  ['검수도 잘 해주셔서 아직 곤란했던 상황은 한번도 없었어요', 1],
#  ['이용해보시면 아시겠지만 기획전을 되게 다양하게 많이 해요 트렌비에서 구매하면 호갱 당할 일은 없는것 같아요 위시리스트에 넣어놓은거 몇 개 있는데 기획전에 뜨면 바로 사려고요',
#   1],
#  ['급하게 선물 준비할때는 익일배송으로 선택해서 보면 되니까 되게 편해요', 1],
#  ['어플에서 카테고리 보는것도 편리하게 잘 돼있고', 1],
#  ['할인만 기다리던 보테가 샀습니다', 1],
#  ['트렌비는 기획전을 항상 진행해줘서 좋습니다', 1],
#  ['트렌비에서 지인이랑 가족들 생일 선물 자주 사요 검수랑 배송도 꼼꼼하니 빨라서 좋아요', 1],
#  ['트렌비에서 지인이랑 가족들 생일 선물 자주 사요 검수랑 배송도 꼼꼼하니 빨라서 좋아요', 1],
#  ['트렌비에서 인기 상품만 봐도 어떤 스타일이 유행인지 알 수 있어서 재밌어요', 1],
#  ['해외 편집샵들이랑 연계돼있으니 저렴하게 구매할 수 있습니다', 1],
#  ['첫 샤넬 트렌비에서 구매ㅋㅋㅋ 카드지갑이지만 너무 예쁘고 맘에 들어요', 1],
#  ['ㅜㅜ 싸게 잘 샀어요', 1],
#  ...]

# %%
cate_data
# Out:
# [['월일에 주문에서 월일에 재고가 없어 환불처리 됐다고 통보하네요', 2],
#  ['어이가없어서 여기 믿고 물건 구매해서 안심하고 기다리다 뒤통수 맞고 다시 물건 찾는일 없도록 이용하지마세요', 7],
#  ['기다려도 물건 안와요', 0],
#  ['여기 상품반품비로 먹고사는 업체인것같습니다', 0],
#  ['나쁜놈들', 8],
#  ['가격이 넘 착해요', 5],
#  ['귀찮아서 리뷰 안 남기는데 너무 만족하고 잘 쓰고 있어요', 8],
#  [' 후기보는 재미도 있고요 후기보다가 급 지름신와서 텅장을 부여잡은게 한두번이 아니네요', 9],
#  ['지금도 제품 많지만 더 이쁘고 좋은거 마니 들어오면 좋겠어요', 3],
#  ['검색하다가 광고가 눈에 띄어 들어오게 되었는데 매장가보다 저렴하고', 5],
#  ['배송도 빠르게 와서 유용하게 잘 쓰고 있습니다', 0],
#  ['상품과 배송 모두 만족입니다', 0],
#  ['몽클 패딩 저렴하게 구입했습니다', 5],
#  ['추천추천', 8],
#  ['명품 쇼핑할때마다 너무 잘 쓰고 있어요', 8],
#  ['특히 오늘 배송상품 마음에 듭니다', 6],
#  ['알람설정해놓고 이벤트 참여하고 구경하는 것도 은근 재미있네요ㅋㅋ 랭킹메뉴도 자주 보는데 요즘 많이 사는 제품들 볼 수있어서 구매에도 도움이 됩니다',
#   1],
#  ['알람설정해놓고 이벤트 참여하고 구경하는 것도 은근 재미있네요ㅋㅋ 랭킹메뉴도 자주 보는데 요즘 많이 사는 제품들 볼 수있어서 구매에도 도움이 됩니다',
#   3],
#  ['좋은 앱 감사', 8],
#  ['다양한 브랜드를 한번에 볼수 있어서 편리해요', 1],
#  ['다양한 브랜드를 한번에 볼수 있어서 편리해요', 3],
#  ['카테고리 구분이나 필터 기능 잘 되있고', 1],
#  ['이벤트 많아 좋네요', 5],
#  ['편해요', 1],
#  ['제가 가장 많이 들어가는 앱 탑쓰리에요', 8],
#  ['저렴하게 세일이벤트나 쿠폰 받으면 평소보다 싸게 살 수 있으니 매일 안 볼수가 없네요', 5],
#  ['혜수언니가 모델이라 더 좋음', 8],
#  ['제품깨끗하게 잘 왔고 포장도 마음에 듭니다', 6],
#  ['잘 샀어요', 8],
#  ['감사합니다', 8],
#  ['여러 서비스 많이 생겨서 좋아요', 5],
#  ['리뷰쓰고 받은 적립도 꽤 많이 모았고 이걸루 물건살때 할인받으면 기분 좋아요', 5],
#  ['한가지 바람은 오늘도착상품 서비스지역이 늘어났으면 합니다', 0],
#  ['지방민은 너무 슬퍼요', 0],
#  ['그냥 일주일 맘놓고 기다리고있는데 갑자기 택배 도착했다고 문자와서 부리나케 집 달려갔어요', 0],
#  ['포장도 꼼꼼하게 잘되어있었어요ㅎ', 6],
#  ['상세페이지에서 본 그대로고', 9],
#  ['명품 주얼리에 눈 뜬후로 발란 애용합니다', 8],
#  ['처음에는 매장에서 샀었는데 발란이용해보니 그럴 필요가 없어졌어요', 8],
#  ['후기 꼼꼼히 살피고 구입하니 항상 성공합니다', 9],
#  ['오 검수영상 신선하네요', 7],
#  ['믿음직스럽습니다', 7],
#  ['백화점 가기 귀찮은 저에게 딱입니다', 8],
#  ['너무 편하고', 1],
#  ['빠르게 물건 받았어요', 0],
#  ['다른데서 최저가 찾았다 하고 보면 관세 미포함이라 낚인 기분이였는데 발란은 관세포함가네요', 5],
#  ['따로 계산 안해도되서 편하고 좋아요', 1],
#  ['다양한 상품이 많아요', 3],
#  ['판매자별로 가격과 배송기간 등을 비교해서 볼 수 있어 유용합니다', 0],
#  ['입점 업체 거래 만족도를 보고 사는 것도 팁', 1],
#  ['처음에는 좀 앱적응이 안됐는데 사용하다보니 상품이나 할인전 등 알아서 찾아보고 있어요 찜목록터질 지경이네요', 5],
#  ['선착순 쿠폰이나 랜덤쿠폰 이벤트 줬으면 좋겠어요', 5],
#  ['잘 쓰고 있습니다', 8],
#  ['핫딜과 쿠폰 적립금 등 잘 사용하면 최저가보다 더 싸게 살 수 있어요', 5],
#  ['가격 형성이 아주 잘되어있는것 같습니다', 5],
#  ['좋은 브랜드와', 3],
#  ['예전같으면 꼭 백화점에 가야 했는데 퇴근하면서 살펴보고 비교해놓고 월급날되면 지르고 있어요', 8],
#  ['가격 훨씬 저렴하면서', 5],
#  ['컨디션 좋은 상품 받고 있어요', 6],
#  ['가격이 좋으니 계속 구매합니다', 5],
#  ['포장이 아쉬운 것도 간혹있지만', 6],
#  ['보기편하게 잘 정리되어있어요', 1],
#  ['판매량순으로 보는데', 1],
#  ['어쩜 하나같이 다 이뿌고', 3],
#  ['가격도 착하고ㅠㅜㅠㅜㅠ', 5],
#  ['리뷰 수정하기가 없어서 엄청 불편하네요', 1],
#  ['아주 같이 만들었어요', 1],
#  ['아주 같은 앱', 1],
#  ['내일 도착하는것처럼 다 설명해놓고 막상 주문하면 맨날 주일 넘게 걸려요 ㅎㅎ 항상 도착 예정일 보면서 빨리 도착할만한곳에 돈 더주고 구매하는데 다 무용지물입니다',
#   0],
#  ['처음 구매에 예정일보다 한참 늦게 도착했을땐 아 내가 그냥 운이 안좋아서 그랬구나 하고 말혀고했는데 다음에 주문해도 똑같이 개늦게 배송돼서',
#   0],
#  ['배송으로 이렇게 장난질 치는 플랫폼은 역시 트랜비가 처음이네요', 0],
#  ['신기한 경험 감사하고 앞으로도 쭉 이용 안하겠습니다', 8],
#  ['감사합니다', 8],
#  ['가격도 착함 굿', 5],
#  ['직구인데도 불구하고 배송이 빠른편', 0],
#  ['엄마 선물로 발란에서 구매했어요', 8],
#  ['생각했던 예산보다 더 저렴하게 샀어요ㅋㅋ', 5],
#  ['전 상당히 맘에들어요', 8],
#  ['어그 슬리퍼 사려고 가입했는데 예상외로 배송도 빨리왔고', 0],
#  ['상품도 좋아요', 6],
#  ['어플 반응도 빠르기 때문에 답답하지 않아요', 1],
#  ['친절하고', 2],
#  ['빨라요', 0],
#  ['걍 오케이몰 쓰셈 정품인지도 불안함', 7],
#  ['뒤로가는거도 없어서 계속 껐다 키고', 1],
#  ['애플로 로그인해야되는데 로그인 버튼 눌러도 안되고 계속 터치도 안됨', 4],
#  ['그리고 반품비가 만원이상', 0],
#  ['추천되는 상품 보고 있으면 시간순삭이네용', 1],
#  ['가격도 다른곳에 비해 착하고', 5],
#  ['종류도 다양해서 훑어보기 바빠요', 3],
#  ['매장갔다가 이쁜거 없어서 그냥 왔는데 발란에서 득템한 것도 여러 개네요', 3],
#  ['초창기때부터 사용해왔는데요', 8],
#  ['관심있는 브랜드나 가방 등 있으면 가장 먼저 찾아보는 앱입니다', 3],
#  ['앱도 편하게 바뀌어서 잘 사용하고 있습니다', 1],
#  ['점점 서비스도 다양해지고', 5],
#  ['좋네여', 8],
#  ['가격비교하는거 너무 귀찮았는데 알아서 해주니 너무 편합니당 ㅋㅋㅋㅋ 잘 쓸게영', 1],
#  ['잘 사용하고 있고 실제로 가방 하나 사서 잘 쓰고 있어요', 8],
#  ['왜 장바구니 물건들 바로 팔렸는지 안 팔린건지 못 보게 해놓는건가요', 1],
#  ['아주 기능이 좋습니다', 1],
#  ['특정 브랜드만 고집해서 샀는데 발란 알고나서는 다양한 브랜드를 접하고 있어요', 3],
#  ['예를 들면 라는 스타일의 가방이 브랜드에만 있는지 알았는데 사에도 있는 등이요', 3],
#  ['오늘 도착하는 상품 정말 쵝오입니다', 0],
#  ['ㅜㅜ 매장만 가도 줄 서거나 대기표 뽑아야 하는데 그런것도 없고요', 8],
#  ['시간 절약합시당', 8],
#  ['이번달 쿠폰 받아서 저렴하게 잘 삿어용 이벤트 계속 많이 했으면 좋겠어용 ㅎㅎ', 5],
#  ['패알못은 옷을 사고 싶어서 어떤걸 사야 되나 고민될 때가 많은데 시즌별 이벤트별로 상품 셀렉해서 구성해서 올려주는게 도움이 많이 돼요 거기에 할인도 많이 들어가면 개이득이고요',
#   3],
#  ['거기에 할인도 많이 들어가면 개이득이고요', 5],
#  ['쉽게 간편하게 구매할수 있어서 좋아요', 1],
#  ['토할 거 같음', 8],
#  ['맘에 드는게 제품 사진이요 제품만 딱 집중해서 볼 수 있게 되어 있어서 좋아요 깔끔해서 계속 쓰려구요', 1],
#  ['쇼핑하러 돌아다니는 거 안 좋아하는 저한테 딱 맞는 앱입니다', 8],
#  ['조금이라도 더 저렴하게 구매하려고 검색 많이 하는 편인데 이 앱에서 한번에 해결하니 시간 절약되고 좋았네요', 5],
#  ['배송도 빨라서 엄청 만족했어요', 0],
#  ['최근에 발란앱에서 제품 하나 샀었는데 퀄리티도 좋고상품 받기 전엔 약간 걱정도 됐었는데 괜한 일이었네요  앞으로 더 잘되길 바랄게요',
#   6],
#  ['명품 사려는 사람은 꼭 다운 받아야할 앱임 발란앱 안 받고 명품 사는 건 돈낭비임', 5],
#  ['발란앱 깔아 놓고 가방이랑 옷 업데이트 되는 거 구경 하느라 시간 가는 줄도 모르고 있어요', 3],
#  ['스타일 다양하게 시도하는 편인데 제품이 엄청 다양해서 잘 쓰고 있어요', 3],
#  ['명품 사고 싶을 때 발란앱부터 들어가봐요', 8],
#  ['보기 쉽게 잘 되어 있어요', 1],
#  ['가격도 할인하고', 5],
#  ['백화점에 문의했을때보다 엄청 저렴하게 구입했네요', 5],
#  ['ㅋㅋ 종종 이용할 거 같아요', 8],
#  ['왜 이렇게 이쁜 게 많나여ㅠㅠㅠ 지금 장바구니 터질거 같아여ㅠㅠ 이번달도 이미 몇 개 샀는데 다 너무 이뻐여', 3],
#  ['발란앱때문에 텅장되고 있음 근데 끊을수가 없다 하루에도 몇번씩 들어가서 랭킹 확인하고 있음', 3],
#  ['중요한 날 입고 가려고 옷 구매했었는데 출발이랑 도착예정 보기 쉽게 되어있어서 좋았어요', 1],
#  ['배송도 예상일보다 빨랐어요', 0],
#  ['배송왔는데 퀄리티도 좋고 빨리 추워져서 입고 다니고 싶어용', 6],
#  ['상품이 다양해서 좋았어요', 3],
#  ['할인상품이 다양해서 좋았어요', 5],
#  ['할인상품이 다양해서 좋았어요', 3],
#  ['맘에듬', 8],
#  ['시간이 없어서 명품 사러 오프라인 매장은 가기 힘들더라구요', 8],
#  ['여기저기 보다가 여기로 정착했네요', 8],
#  ['앱 사용하기 편해요', 1],
#  ['ㅋㅋㅋ 브랜드도 많아서 잘 쓰고 있어요', 3],
#  ['백화점 멀어서 인터넷으로 사는 편인데 다양한 브랜드 한 곳에서 볼 수 있어서 이용하고 있어요', 3],
#  ['명품 선물할 일이 있어서 인터넷으로 찾아보다가 발견했는데 이용하기도 쉽고', 1],
#  ['배송도 빠르더라구요 다음에 선물 살 일 있으면 또 이용할게요', 0],
#  ['여기서 구매해서 매장가서 받는거 신박하네요', 8],
#  ['걱정도 안되고 너무 좋았어요', 8],
#  ['최저가 보기 엄청 편하네요', 1],
#  ['ㅋㅋㅋㅋ 가격이 중요해서 ㅋㅋ 계속 이렇게 해주세요', 5],
#  ['면세로만 명품 샀었는데 여기가 더 싼거 같네요', 5],
#  ['ㅋㅋ 여행 못가고 있는데 잘됐어요', 8],
#  ['이번에 가방 하나 샀는데 정품 맞네요', 7],
#  ['이제 걱정안하고 여기서 사면 되겠어요', 7],
#  ['명품 매장 안가도 돼서 종종 이용합니다', 8],
#  ['실시간 업데이트 엄청 좋아요', 1],
#  ['예쁜 거 많아서 다 사고 싶어요', 3],
#  ['해외여행 못가서 면세점 이용 못했는데 발란앱으로 다시 명품백 모으고 있네요', 8],
#  ['걱정했었는데 배송받고 걱정 싹 날라가서 계속 이 앱 쓰려구요', 7],
#  ['직구 못해서 원래 매장에서 돈주고 사는 사람인데 여기 앱쓰니까 직구 편하게 하네요', 8],
#  ['제품 사기 전에 몇가지 궁금한게 있어서 채팅 했는데 답도 빠르고 친절해서 믿고 주문했네요', 2],
#  ['배송 조회돼서 너무 좋아요', 1],
#  ['검수 영상도 있던데 그래서 믿음이 확 가더라구요', 7],
#  ['골프에 빠졌는데 여기 골프 브랜드 엄청 많아서 너무너무 좋아여', 3],
#  ['어제도 발란 구경하느라 늦잠자서 피곤해요', 8],
#  ['힘내려고 어제 봐뒀던거 결제했습니다', 8],
#  ['명품 좋아하는 사람이라면 다운 받아야할 앱인거 같아요', 8],
#  ['명품 브랜드들 많아서 좋네요', 3],
#  ['딴데는 제가 찾는 브랜드 없는데 여기엔 있어요', 3],
#  ['할인 잘하고 쿠폰 쓰기 쉬워서 좋음', 5],
#  ['배송 언제오냐고 재차 확인했는데 말씀해주신 날짜에 잘 도착해서 목숨건졌어요', 0],
#  ['저렴한 가격에', 5],
#  ['좋은 제품 정말 감사합니다', 6],
#  ['ㅎㅎㅎ 오픈런해도 못구하던 제품 득템했어요', 3],
#  ['소리벗고 팬티질러예', 8],
#  ['쿠폰 주는거 좋아요', 5],
#  ['이번에도 앱에서 쿠폰 써서 하나 질렀어요', 5],
#  ['실시간랭킹 서비스 좋네요', 1],
#  ['트렌드 못읽을까봐 걱정할 필요가 없겠어요 발란이 읽어줍니다', 3],
#  ['예쁜 신상은 또 오래걸릴줄알고 호다닥 주문했는데 진짜 빨리왔어요', 0],
#  ['심지어 당일 배송상품도있네요', 0],
#  ['제품 검색하면 바로 최저가 비교 가능 너무 편해요', 1],
#  ['진짜 감동', 8],
#  ['이용하기 편하고', 1],
#  ['이용하기 편하고 특히 제가 좋아하는 브랜드 자주 올라와서 좋아요', 3],
#  ['만족만족', 8],
#  ['요새 명품에 빠져서 발란앱만 들여다 보고 있는데 잘쓰고 있어요', 8],
#  ['어플 자체는 나쁘지은흠', 1],
#  ['어플 설치하면 쿠폰준다고 꼬시고막상 다운받고 설치하면 타쿠폰과 중복할인 안된다고 막아놓음 미리 써놓기라도 하던가하는짓이 토악질 나와서 이미 털린 개인정보지만 바로 탈퇴하고 앱삭제전 후기남김제품은 다른 백화점 온라인사이트에서 몇천원 더 주고 주문함',
#   5],
#  ['사고 싶은거 저렴하게 샀는데 계속 이 상태로 쭉 가는 그런 앱 되길', 5],
#  ['발란앱으로 시키면 배송 엄청 빠르네요 느긋하게 있었는데 배송왔다고 해서 놀랐네요', 0],
#  ['빨리 해결해주세요', 8],
#  ['애플 로그인이 안됩니다', 4],
#  ['사장님 신규가입 쿠폰 이렇게 막 뿌리셔도 되겠어요', 5],
#  ['감사합니다', 8],
#  ['현금매입가 반값으로 후려침 애매한 안내로 사람 헷갈리게 잘함 개 꾸림 바로 삭제 이딴앱 필요없음', 5],
#  ['장바구니에서 주문하기 눌러도 멈춰있고', 4],
#  ['사용하기 좋아요', 8],
#  ['맨날 살까말까했던 신발 쿠폰이랑 신규가입으로 저렴하게 겟챠', 5],
#  ['명품 쇼핑몰이라길래 나랑은 상관없겠구나 했는데 뉴발나이키같은 운동화들도 저렴하게 구매가능하네여 ', 3],
#  ['저렴한 가격 사이즈없음 비싼 가격 사이즈 있음 짜증나서 그냥 안살라했는데 발란에 있었어요', 3],
#  ['심지어 저렴하기까지해요 감격스러워서 감사의 마음으로 리뷰 남깁니다', 5],
#  ['최고최고 번창하세요 ㅎㅎㅎ', 8],
#  ['보통 면세점에서 쿠폰이랑 적립금써서 명품 구입하는데 코로나땜에 못나가다보니 인터넷으로 정품최저가 찾아보게됐어요', 5],
#  ['면세점 쿠폰이랑 이벤트적립금 쓴거보다 훨씬 저렴하고', 5],
#  ['심지어 집 앞까지 빠르게 배송오네요', 0],
#  ['남은 쿠폰도 마저 써야겠어요 ', 5],
#  ['정품 맞음ㅇㅇ 사촌형 신발 산거 예쁘길래 따라샀어요', 7],
#  ['정품인지 봐달라고했는데 맞다면서 자기보다 저렴하게 샀다고 놀라더라구요', 7],
#  ['자기보다 저렴하게 샀다고 놀라더라구요', 5],
#  ['믿고 사는 발란 정품 맞아요 이제 더 이상 의심하지 않아요', 7],
#  ['예쁘고저렴한 물건 찾기에만 집중ㅋ', 5],
#  ['해외제품 사는게 처음이라 이거저거 궁금해서 물어볼게 많았는데 친절하고 꼼꼼하게 상담해주셔서 안심됐어요', 7],
#  ['해외제품 사는게 처음이라 이거저거 궁금해서 물어볼게 많았는데 친절하고 꼼꼼하게 상담해주셔서 안심됐어요', 2],
#  ['직접 물건 받아보니 너무 겁먹었었던거같네요 정품 맞고', 7],
#  ['무엇보다 배송이 빠릅니다', 0],
#  ['강추', 8],
#  ['뭐죠 제 취향을 어떻게 이렇게 잘 아시죠 저보다 잘 아는거같아요', 8],
#  ['추천 상품 싹 다 제 서타일ㅎ', 3],
#  ['고급지네요', 6],
#  ['포장상태 아주 깔끔 이태리 그 잡채', 6],
#  ['신속정확한 배송 감사합니다', 0],
#  ['그라지아', 8],
#  ['신규가입쿠폰 너무 혜자네요', 5],
#  ['너무 저렴해서 걱정했는데 진품이고', 7],
#  ['심지어 이렇게나 빨리 받다니 최고십니다', 0],
#  ['모르던 브랜드도 많네요', 3],
#  ['시야가 넓어진 느낌 저렴하고 예쁜 아이들도 많고 좋네요', 5],
#  ['시야가 넓어진 느낌 저렴하고 예쁜 아이들도 많고 좋네요', 3],
#  ['살림살이에 도움이 되겠어요', 8],
#  ['앱 이상해요', 1],
#  ['악세서리에서 지갑 눌렀는데 아무것도 안뜸 가입할때 이런적없엇는데 지메일 인증메일도 안오고 물건을 사란건지말란건지', 4],
#  ['회원가입흐려거 하니까 회원가입창에서 계속 멈춰 있네요', 4],
#  ['뭘 눌러도 반응이 없어요 어케 해야 하나요', 4],
#  ['타사이트 물건값 완전 저렴하길래 구매할라고 보면 관부과세 폭탄때려서 훅 비싸지는데 발란은 물건값에 포함 되어있네요', 5],
#  ['이게 포함한 값이라니 개이득ㅋㅋㅋ', 5],
#  ['평일에 발란에서 찜해두고 주말에 오프라인가서 실물확인하고 집 오는 길에 결제합니다', 5],
#  ['오프라인 가격보다가 발란판매가 보면 누가 채갈까 무서워요', 5],
#  ['정품보증되니까 믿고 이용중입니다', 7],
#  ['저렴한데다가', 5],
#  ['헐헐헐 원하던 제품 발란에서 구매성공했어요', 3],
#  ['명품을 온라인에서 살때마다 불안한 맘이 있었는데 포장영상보내주시는거 보고 안심했어요', 7],
#  ['배송단계 트래킹도 잘되고', 0],
#  ['보통 초록창으로 일일히 저장하고 캡쳐하면서 최저가 찾는데 발란으로 그런 수고로움 덜었네여 가격할인율제품정보를 한번에 비교할 수 있어서 좋아요',
#   1],
#  ['예쁜거 다 담다보니 장바구니가 터지려고하네요', 3],
#  ['쿠폰땜에 하나 살거 두개 샀어요ㅋㅋㅋㅠㅜ', 5],
#  ['해외배송직구하면 그냥 주문해놓고 언젠가 오겠지 하고 맘비우고 기다리는 편인데 여기는 맘 비우려고 하는데 도착해요', 0],
#  ['ㅋㅋ배송짱빠릅니다', 0],
#  ['빨리빨리 한국인 정서에 딱 맞는 곳', 8],
#  ['백화점 쇼핑을 아직 내외하는 인왠지 매장에서 물건을 보면 사야될것만 같다는 생각에 부담스러웠는데 온라인에서 구매하니 몸도 마음도 편하네요',
#   8],
#  ['이벤트랑 쿠폰 이용해서 저렴하게 번째 구매입니다', 5],
#  ['어느새 보니 적립급이 꽤나 쌓였네요', 5],
#  ['꽁돈생긴느낌 번째구매에는 적립금도 써야겠어요 ㅎㅎㅎ', 5],
#  ['정품 보상제도가 있다해서 항상 믿고 구매합니다', 7],
#  ['새상품에 하자가 있는데 환불이 안되네요', 6],
#  ['다신 이용 안 하겠습니다', 8],
#  ['브랜드별로 모아두고 가격비교하면서 쇼핑할 수 있어서 좋아요', 5],
#  ['브랜드별로 모아두고 가격비교하면서 쇼핑할 수 있어서 좋아요', 3],
#  ['결정장애로 매번 골치아팠는데 많은 도움이 됐어요', 8],
#  ['트렌비에서 나이키 신발 샀는데 몇 주 걸려 받은', 0],
#  ['신발상태가 중고사이트였나 싶을정도 나이키 텍에 누렇게 오염있길래 환불 아니고 교환 문의 드렸더니 공정상 발생할 수 있는거라 교환불가 교환시만원정도 ㅎㅎ 바로 삭제합니다',
#   6],
#  ['다른거 이용하세요 머스트잇이나 많잖아요', 8],
#  ['최저가 제품 찾아 들어왔는데 쿠폰까지 쓰니 초초초초최저가 제 텅장을 지켜주셔서 감사합니다', 5],
#  ['날씨가 추워질거같아서 아우터 구매했는데 진짜 빨리 도착했어요', 0],
#  ['장모님 생신이라서 와이프랑 가방검색하다가 발란에서 최저가 찾아서 결제하기로했어요', 5],
#  ['와이프에게는 최저가로 샀다고 했는데 쿠폰써서 제 비상금 만들었어요 나이쑤', 5],
#  ['아니 양말 보러 들어왔다가 신발까지 사버렸네요', 8],
#  ['그치만 놓칠 수 없는 가격이였어요', 5],
#  ['저는 인터넷으로 사서 불안했는데 요목조목 다 따져보니 정품맞아요', 7],
#  ['저는 쿠폰이랑 신규가입혜택으로 백화점 가격보다 훨씬 저렴하게 사서 기분좋았어요', 5],
#  ['브랜드마다 사이즈가 달라서 제 체구랑 비슷한 구매자들 리뷰 보고 고릅니다', 3],
#  ['리뷰 잘 되어 있네요', 1],
#  ['여러분 조심하세요 예쁜거 담고 쿠폰 적용하다보면 순식간에 텅장이 되어버립니다', 5],
#  ['신상도 예쁘고 베스트 상품 보면 요새 다들 하나씩은 갖고있는거같고 찜해둔게 너무 많았어요', 3],
#  ['쿠폰 마니마니 주세용', 5],
#  ['아 필터기능 너무 좋아요', 1],
#  ['다양하고 방대한 양의 브랜드 제품들을 한눈에 볼 수 있어요', 1],
#  ['다양하고 방대한 양의 브랜드 제품들을 한눈에 볼 수 있어요', 3],
#  ['구체적으로나눠져있어서 검색하기도 좋고', 1],
#  ['가격들도 착해서 자주 사용할 것 같아요ㅎ', 5],
#  ['믿고 살 수 있어요', 7],
#  ['명품을 저렴한 가격으로', 5],
#  ['제품 상태는 물론 구성품도 다 있어서 맘에 들어요', 3],
#  ['온라인 쇼핑 불안해서 고객센터 연락했는데 친절하시고 응대도 잘 해주셨어요', 2],
#  ['다양하고 가성비좋네요', 3],
#  ['역시 백화점보다 훨씬 저렴한 가격에 겟', 5],
#  ['발란은 로케트로 배송하나요', 0],
#  ['직구상품을 어떻게 이렇게 빨리 배송해주시죠 감사합니다', 0],
#  ['다른 사이트들에서 보지 못한 제품들이 많네요 신상도 많고 다양한 제품들이 많아서 선택의 폭이 넓어졌어요', 3],
#  ['유니크한 제품들도 많고 종종와서 트랜드 읽기도 좋네요', 3],
#  ['배송이 생각했던 날보다 하루 빠르게 왔어요', 0],
#  ['상품도 이상없이 잘 왔습니다', 6],
#  ['물건 질이 좋아 자주 애용해야겠어요', 6],
#  ['다른곳 보다 할인율도 높고 쿠폰도 많이 주네요  이런 곳을 이제야 알았네요 ㅠㅠ 앞으로 자주 이용해야겠어요', 5],
#  ['ㅋㅋㅋ 시간가는 줄 모르고 명품 구경하게 됨 디자인이 깔끔해서 이용하기 편리해용', 1],
#  ['집에서 편하게 쇼팡할 때 좋아요 백화점 갈때 시간들이고 차도 막히고 가도 원하는 상품 못구하면 통탄스러운데 ㅋㅋㅋ 그럴 일 없음',
#   8],
#  ['실시간으로 세일 정보를 확인할 수 있어서 좋아요', 5],
#  ['오늘 도착하는 상품들도 있고', 0],
#  ['배송 예정날짜 확인할 수 있어서 유용해요', 8],
#  ['발란 덕에 요즘은 구매대행 안하구 이써요', 8],
#  ['쇼핑도 편리하네요 감사합니다', 1],
#  ['가격도 저렴하고', 5],
#  ['예전부터 알고있었는데 의심스러워서 구매는 이제야 해봤는데 제대로 정품 오더라고요', 7],
#  ['백화점가서 상품권 할인으로 사는거 아니어도 저렴하게 살 수 있어서 좋네요', 5],
#  ['행사 프로모션도 다양하게 합니다', 5],
#  ['서비스 만족도 최상 고객센터 피드백도 빠르고', 2],
#  ['굿임다', 8],
#  ['명품은 사고싶은데 뭐가 트렌든지 뭐가 좋은건지 잘 몰랐었는데 발란에서는 실시간 랭킹도 볼 수 있어서 요즘은 이런거 많이 사는구나 알 수 있어요',
#   1],
#  ['가격도 합리적이에요', 5],
#  ['명품 구매할 때 꼭 쓰는 앱 도 편리하고', 1],
#  ['오류도 없고', 4],
#  ['쿠폰팩이 쏠쏠함 ㅎㅎㅎ', 5],
#  ['여러사이트 진전할 필요 없이 명품 대부분 브랜드 올인원으로 둘러볼 수 있다는 점이 너무 편해요', 1],
#  ['여러사이트 진전할 필요 없이 명품 대부분 브랜드 올인원으로 둘러볼 수 있다는 점이 너무 편해요', 3],
#  ['익스프레스 배송도 넘 잘쓰고 있고요', 0],
#  ['한눈에 오늘의 할인 상품들 확인할 수 있어서 너무 좋아요 상품 보기가 여기가 젤 편하더라고요', 1],
#  ['따로 가격비교 안해도 되니까 시간 절약도 할 수 있고 관부가세 포함이라 이것저것 따로 계산할게 없어서 좋네요', 5],
#  ['편하게 쓰고 있습니다', 1],
#  ['환불 관련해서 문의 드렸었는데 고객센터에서 빠르고 정확하게 조치해주시더라구요 감사합니다', 2],
#  ['지인 소개로 깔아봤는데 상품 보기도 쉽게 되어있어서', 1],
#  ['브랜드랑 제품 종류 다양하고 가격대별로 확인할 수도 있어서 원하는 제품 구매할 때 편해요', 1],
#  ['브랜드랑 제품 종류 다양하고', 3],
#  ['가격대별로 확인할 수도 있어서 원하는 제품 구매할 때 편해요', 1],
#  ['진짜 정품이 오더라고요', 7],
#  ['배송도 빨랐고', 0],
#  ['배송 상태도 좋음', 6],
#  ['매장 둘러볼 시간 없을 때 편리하게 이용하고 있어요', 8],
#  ['금액대별 검색도 가능해서 누구 선물 구매할 때 짱조음', 1],
#  ['한번에 가격 비교 할 수 있으니까 여러 곳 진전할 필요가 없어요', 1],
#  ['좋아요', 8],
#  ['종종 구매하고 있어요', 8],
#  ['다른 명품커머스앱보다 할인을 자주 해주고 적립금 혜택도 커요', 5],
#  ['백화점이나 다른앱에는 없던 상품도 재고 있더라구요', 3],
#  ['다양한 브랜드', 3],
#  ['할인도 많이 해줌', 5],
#  ['보기도 좋고', 3],
#  ['트렌비 물건 많아서 좋긴 한데', 3],
#  ['그래서 너무 보는 데 오래 걸려요\n사이즈별로 색상별로 볼 수 있으면 좋겠어요', 1],
#  ['칼하트 트래퍼햇을 주문 했는데 주문하고 나서 가격대가 바로 올라서 취소 됐네요', 5],
#  ['좋아요', 8],
#  ['짱짱', 8],
#  ['재고 있다고 표시된 상품을 구매하고 일주일 가까이 기다려도 안오길래 보니깐 판매자 일방적 취소로 환불 기간 일까지 총 일 동안 구매도 못하는 상품때문에 스트레스 받았습니다',
#   8],
#  ['구매자에게 매우 불리한 시스템이니 다른 어플 이용하세요', 8],
#  ['싸다 싸', 5],
#  ['모든 명품은 여기서 다 살 수 있네요', 3],
#  ['오늘 출발이라면서 일째 출발 안 함ㅋㅋ', 0],
#  ['구입도 못하는 제품을 구입할 수있는 것처럼 속여파네요', 8],
#  ['고객센터는 본인들이 판매하는게 아니라 아무 조치를 할수없다하고 관리를 못할꺼면 뭐하러 이 앱을 만들었는지 모르겠네요', 2],
#  ['품절이면 품절표시를 정확하게 해놓으세요', 3],
#  ['품절이면 품절표시를 정확하게 해놓으세요', 9],
#  ['너무좋아요트렌비 믿고 구매 하는쇼핑 클릭롸잇나우', 8],
#  ['중고매입신청함 물품수거후 바로 매입이 진행되는줄알고 기다리다 며칠이 지나도 연락이 없어서 전화하니 주 검수시간이 걸린다고 그때서야 얘기함 왜 미리 고지를 하지않았냐 당장 그냥  추가 검수기간 고지안함 제안서 여부도 지금 댓글로 알았고 아무것도 고지안함 그러면서 다시보내라니',
#   9],
#  ['착불택배비 부담하라고하고', 0],
#  ['상담사는 자기가 고지한거 아니고 자기 잘못아니라고함 상담원은 트렌비에 왜있는지 모르겠네요', 2],
#  ['그래서 무슨 상담을 이따위로 진행하냐니 가이드가 그렇게 되어있다는데 이게 맞냐고요', 2],
#  ['알람 수신도안하는데 왜이렇게들 보내는겨 설정 찾기도 겁나어렵게해놓고', 1],
#  ['사용하기 편해요', 1],
#  ['명품 판매하기 편한 앱', 1],
#  ['깔끔하게 정리된 앱', 1],
#  ['제품이 많은데도 깔끔하게 정리된 앱', 3],
#  ['집에서 쉽게 명품 쇼핑 가능', 8],
#  ['검색 필터가 잘되어 있는 것이 장점', 1],
#  ['주문한지 달만에 재고 없다고 일방적으로 주문 취소 당했어요', 8],
#  ['정말 최악의 플랫폼', 8],
#  ['좋습니다', 8],
#  ['진짜 앱 개못만들었네 정신병걸리겠네', 1],
#  ['별 도 아까움 명품케이스도 없는제품팔고 리뷰사진과 완전다르게와서 가품같다고', 7],
#  ['협력업체 편만 들어서 환불요청했더니 반품비내라는 어이없는 발란업체입니다', 0],
#  ['여기서 제품사느니 조금더내고 정식매장에서 사는게 낫다고 봅니다', 8],
#  ['여기서 구매하시는거 다시한번 생각해보세요', 8],
#  ['반품하면 반품택배비로 수익창출 참 그지같다', 0],
#  ['결론은 판매자도 정확한 사이즈 모르고 판매한단 소리고 고객이 정확한 사이즈 구매했는데도', 9],
#  ['고객센터 한다는 소리는 브랜드마다 사이즈가 다를수 있다고', 2],
#  ['만족하고 있습니다', 8],
#  ['가품 없을 것 같아서 믿고 사용 중이예요', 7],
#  ['제품도 많지만', 3],
#  ['상품주문후 국내배송인데 담날에도 상품준비중이면 당연히재고를의심할수밖에없죠', 7],
#  ['상품주문후 국내배송인데 담날에도 상품준비중이면 당연히재고를의심할수밖에없죠', 0],
#  ['근데 판매자와통화도못하고 트렌비고객센터와의 통화만 가능한것도 이해가안되고 이래저래서 재고가의심스럽다 했으면 고객센터에서 빨리재고유무를 파악해줘야죠',
#   2],
#  ['계속상품준비중인상태로요', 0],
#  ['고객센타로 다시전화했더니 역시나 제예상대로 재고가없어서 다른매장서지금구했고 지금부터 또일을기다리라고 하더군요', 2],
#  ['배송일이 도래하자 아직도상품준비중이라', 0],
#  ['무슨이딴곳이있는지바로취소하고 다른데서 구매했습니다', 8],
#  ['바로발송해주더군요 트렌비 첨 이용해봤지만 시스템도 이상하고 고객입장은도생각안해주는거같아 앞으로 이용할생각이없습니다', 2],
#  ['인터넷 결재하려는데 배송지 입럭다 되었는데 배송지 입력하라는 오류 계속 발생 상품도 다 골라놨는데 시간만 버렸습니다', 4],
#  ['몇십만원어치 골라놨는데 결재가 안되어서 다른데에서 구매했습니다', 4],
#  ['가장 저렴해서 최종 구매는 트렌비에서 하게 되네요', 5],
#  ['가격이 저렴한건 당연한거고', 5],
#  ['사진을 좀 더 다양하게 볼 수 있다는 점이 저한테는 가장 편했어요', 9],
#  ['앞으로도 자주 이용하겠습니다', 8],
#  ['플랫폼이 노력하고 있다는 인상이에요', 8],
#  ['정품 안심 되서 자주 이용해요', 7],
#  ['타 플랫폼 대비 좋은 제품 최저가 많고', 5],
#  ['특히 배송 빠른거 같아서 굿굿', 0],
#  ['오늘 트렌비 어플 재설치 하고 첫주문 했는데 좋아요', 8],
#  ['타 구매대행 어플은 상품은 여기보다 더 비싸고 거기에 배송비 따로 검수비 따로 받아요', 8],
#  ['여기는 배송비검수비 따로 안받아 좋아요', 8],
#  ['여기는 웬지 믿음이 가네요', 8],
#  ['가격도 합리하고', 5],
#  ['트렌비 번창하세요', 8],
#  ['아무래도 가격 차 때문에 직구 많이 하는 편인데 배송 오류 때문에 스트레스가 많았어요', 0],
#  ['요즘 국내 사이트도 괜찮다고 해서 비교해보고 평 괜찮길래 구매했는데 왠걸 너무 편하네요', 8],
#  ['진짜 배송비도 무료인데다가 왠만하면 일주일도 안되서 도착하고 이 편한걸 왜 몰랐을까 싶네요', 0],
#  ['제품 검수도 정품 인증도 꼼꼼하게 잘 해서 오니까 믿음직스럽고 너무 맘에 듭니다', 7],
#  ['프로 보상제 문구가 마음에 듭니다', 7],
#  ['개인차는 있겠지만 앱 디자인이 세련됐고 사용자의 접근성도 좋습니다', 1],
#  ['계속 아이쇼핑중인데 이번 블프 끝나기전에 하나 더 장만하려고요', 8],
#  ['일단 믿음이가고', 7],
#  ['다양한 제품들 구경하는맛도 쏠쏠해요', 3],
#  ['그러다 구매까지 이어지는 것같아요 앞으로도 좋은제품들 부탁드려용', 8],
#  ['무료배송에 배송빠르고', 0],
#  ['럭키드로우 당첨된적은 없지만 매달쿠폰 활용하기 좋고 해서 자주 접속한답니다', 5],
#  ['그래도 젤 깔끔하고', 1],
#  ['싸서 자주 이용중입니다', 5],
#  ['옷 보러 왔다가 가방보고또 딴거볼 수밖에 업는 편함이라 텅장되고 있는 나름의 단점이 있네요ㅋㅋ', 1],
#  ['아주 좋아요', 8],
#  ['키즈까지 제품분류해서 볼 수있어서 가족들 제품을 한번에 살 수 있어서 편한 것같아요', 3],
#  ['정품도 보장받아서 안심하고 쇼핑하게 되요', 7],
#  ['배송도 빠르고', 0],
#  ['배송 정보 보려고 했는데 마이페이지가 안들어가집니다', 4],
#  ['정말 갖고 싶던 신발이 있었는데 국내에는 없고 직구는 어렵고 해서 포기하고 있다가 친구가 트렌비에 있다고 해서 바로 앱깔고 구매했어요',
#   8],
#  ['검수도 꼼꼼하게 해줘서 기분좋게 구매했답니다', 7],
#  ['처음 이용해보는 거라 약간 걱정했는데 생각보다 배송도 빨리오고', 0],
#  ['그 뒤로 갖고 싶은 제품이 있으면 젤 먼저 트렌비에 들어오는 거 같네요', 8],
#  ['앞으로도 다양한 제품 많이 올려주세요', 3],
#  ['성격이 꼼꼼한 편이라 하나를 사더라도 다 따져보고 사는 편인데 브랜드 공식부터 한꺼번에 다 조회가 되니까 너무 좋아요', 3],
#  ['따로 찾아보는 수고 덜어지니 훨씬 빠르게 살 수 있구요', 8],
#  ['일단 판매자분이 친절하게 응대해주셔서 기분이 좋았어요', 2],
#  ['일단 믿음이 가고', 7],
#  ['저렴한 제품들', 5],
#  ['구경하는 재미도 쏠쏠해서 자주 보게 되는데 다른 앱들보다 확실히 사용성이 좋다는 걸 느낍니다', 1],
#  ['앞으로도 좋은 서비스 부탁 드립니다', 8],
#  ['배송을 감사드립니다', 0],
#  ['확실한 품질과', 6],
#  ['가격대도 괜찮고', 5],
#  ['빠른배송도 좋아요', 0],
#  ['제품들이 다양하고', 3],
#  ['앞으로 자주 이용할게요 조금 욕심을 부리자면 가전이나 이런 카테고리도 있으면 더 좋을 것 같아요', 8],
#  ['쿠폰이나 혜택도 다양해서 자주 이용하고 있습니다', 5],
#  ['개만 구매해도 가격 상관없이 무료 배송이 되는 점이 너무 좋고 익일 배송으로 하루 만에 오니까 급하게 사야될 때 주문하기도 좋더라구요',
#   0],
#  ['가격 때문에 여러 사이트를 검색하고 비교하지만 결국 최종으로 구매하게 되는 곳이 트렌비 입니다', 5],
#  ['다른 쇼핑몰보다 풍부한 볼거리가 많고 선택의 폭이 넓어서 자주 이용 중인데', 3],
#  ['좋은 서비스 이용하게 해주셔서 감사합니다', 8],
#  ['뭐니뭐니해도 앱이 버벅거리지 않아서 넘나 맘에 들어요', 4],
#  ['왜자꾸 빈 푸쉬 알림을 보내세요', 8],
#  ['가품 논란이 많은 요즘에 가품 관련 문제로 한번도 시끄러운 적 없어서 좋습니다', 7],
#  ['명품 쇼핑을 자주 하는 편인데 가격이 있다보니까 그래도 최저가 비교하면서 사게 되더라구요 트렌비는 최저가 비교가 잘되어 있는 편이라 비교해서 좋은 가격에 구매할 수 있어서 좋아요',
#   5],
#  ['앞으로도 좋은 서비스 부탁 드려요', 8],
#  ['배송도빠르고좋아요', 0],
#  ['정품보증이 확실해서 신뢰가 갑니다', 7],
#  ['참 많은 사이트 돌아다녀 봤는데 명품은 여기가 최고네요', 8],
#  ['갑자기왜 무슨코드뜨면서 안되요', 4],
#  ['집에서 쇼핑할 수 있어서 편해요', 8],
#  ['자주자주 들어오게 됩니다', 8],
#  ['업뎃되는 핫한 상품 너무 많거든요', 3],
#  ['어플리케이션 쇼핑은 피드백이 느려서 답답한데 발란은 빠르고 프로모션도 참 다양해요', 5],
#  ['사고 싶은게 너무 많아서 매일마다 참고 또 참고 하고 있어요', 3],
#  ['정품 진짜 맞아요', 7],
#  ['라스트 피스로 세일하는 거 진짜 많아요', 5],
#  ['명품을 잘 모르는 저 같은 사람들에게 발란은 도움 완전 되는 앱네요', 8],
#  ['매일마다 들어가서 구경하고 사고 싶은 거 찜해놓고 하고 있어요', 8],
#  ['자주쓰는 명품구매처에요 저렴해요', 5],
#  ['다른 명품 샵은 배송이 진짜 엉망진창인데 반란은 진짜 특배송이네요', 0],
#  ['완전 빨라요', 0],
#  ['어플도 깔끔하고', 1],
#  ['오류도 없어서 좋네요', 4],
#  ['가입도 편하고 결제도 편해서 좋아요', 1],
#  ['신규 가입하니 쿠폰 많이 주네요', 5],
#  ['ㅋㅋㅋ 나이키 신발 사고 싶었던거 진짜 싸게 샀어요', 5],
#  ['ㅋㅋㅋ 완전 신나요', 8],
#  ['ㅎㅎ 자주 발란할게요', 8],
#  ['진짜 정품 오는 거 맞네요', 7],
#  ['진짜 정품 많고', 7],
#  ['최소  할인해서 샀어요', 5],
#  ['사고 싶었던 게 딱 반란에만 있네요', 3],
#  ['ㅋㅋ 완전 감사합니다', 8],
#  ['프로모션도 다양해서 좋아요', 5],
#  ['고객센터 피드백도 빠르고', 2],
#  ['반란은 믿고 구매할 수 있고', 7],
#  ['배송이나 상품 모든 최고에요', 0],
#  ['회원혜택 많아요', 5],
#  ['꼭 챙겨서 구매하세요', 8],
#  ['직구는 못 믿고 비싸게 백화점에서 샀었는데 이런 앱이 있어서 좋네요', 8],
#  ['명품 가방 선물 할 일이 있어서 알아보다 추천해주길래 여기서 보는데 참 다양하네요', 3],
#  ['물건이 여러개 있어서 좋은데 몽블랑 홈페이지에 없는 제품도 있고 똑같은 제품을 세일가격인데도 몇 만원은 더 비싼데요', 5],
#  ['물건이 여러개 있어서 좋은데', 3],
#  ['코로나 때문에 발란 이용하게 되었는데 굳이 백화점이나 면세점 가서 명품 살 필요', 8],
#  ['발란에서 찜하고 시간 될 때 백화점 가서 확인하고 저렴하게 사니까는 더 효율적이네요', 5],
#  ['자주 방문하고 있어요', 8],
#  ['아주좋아요', 8],
#  ['짱 짱 짱', 8],
#  ['배송까지 마음에 듭니다', 0],
#  ['달에 한 번은 반란에서 저를 위해서 선물을 구매합니다', 8],
#  ['저는 트렌디한 것보다 클래식한 거 좋아해서 엄청 세일하는 것만 골라서 구매하고 있어요', 5],
#  ['신상도 많고 다양한 제품들이 많아서 선택의 폭이 넓어서 좋아요', 3],
#  ['요즘 스타일을 발란에서 배워요', 8],
#  ['해외제품 사는게 처음이라 이거저거 궁금해서 물어볼게 많았는데 친절하고 꼼꼼하게 상담해주셔서 감사합니다', 2],
#  ['쿠폰 엄청 빠방 하네요', 5],
#  ['ㅋㅋㅋ 같은 가방 다른 데보다 훨씬 저렴하게 살 수 있어요', 5],
#  ['많은 종류의 브랜드가 있어 편리해 계속 이용하게 되네요', 3],
#  ['백화점 한번 가려면 거리적으로 부담돼서 시간을 내지 못하는 경우가 많은데 발란 이용하니까 시간 절약에 좋아요', 8],
#  ['유니크한 제품들도 많아서 트랜드 읽기도 좋네요', 3],
#  ['판매자와 채팅할 수 있는게 좋아요', 2],
#  ['검색하기 쉽고', 1],
#  ['가격도 착하고', 5],
#  ['예쁜 거 너무 많아요', 3],
#  ['쿠폰 좀 더 주세요', 5],
#  ['결혼 기념일에 선물 깜빡했다가 여기서 급하게 구매했는데 배송도 진짜 빠르네요', 0],
#  ['모두 좋아요', 8],
#  ['쇼핑하기 편리하고', 1],
#  ['저렴하네요', 5],
#  ['백화점보다 훨씬 저렴하게 구매 가능 하네요', 5],
#  ['일 기념 선물 급하게 구매했는데 대박 만족합니다', 8],
#  ['물건 참 다양하네요', 3],
#  ['프로모션도 의외로 많네요', 5],
#  ['어느새 명품 보거나 살 때는 발란을 사용하고 있어요', 8],
#  ['가입 이벤트 있어서 구경했는데 여기 물건 진짜 다양하고', 3],
#  ['기획전 다양하게 해서 좋아요', 5],
#  ['믿을 수 있어 좋습니다', 7],
#  ['발란 배송도 빠르고', 0],
#  ['저같이 명품 모르는 분들에게 발란에서 알아조고 사는거 추천합니다', 8],
#  ['절대 진짜네요', 7],
#  ['오픈런 기다리기 싫어서 찾다보다 발란 가입했는데 백화점보다 낫네요', 8],
#  ['내 취저 물건 많아서발란 늘 구경하고 구매도 합니다', 3],
#  ['발란 상품 수가 진짜 많은 거 같아요', 3],
#  ['매일마다 구경 옵니다', 8],
#  ['사고 싶은 거 너무 많아요', 3],
#  ['급하게 여친한테 선물하려고 구매했는데 배송 진짜 빠르네요', 0],
#  ['쉽게 구매 가능하고', 1],
#  ['가격도 맘에 들어요', 5],
#  ['코로나 시기에 면세점 못가서 발란 알게 됐는데 만족해서 지금까지 잘 사용하고 있어요', 8],
#  ['요즘 유행하는 패션을 한번에 볼수있어 좋아요', 3],
#  ['쿠폰 너무 좋아요ㅋㅋ 더 많은 쿠폰 주세요', 5],
#  ['더 자주 구매할게요', 8],
#  ['발란은 무조건 믿고 명품 구매하셔도 됩니다', 7],
#  ['엄청 세일 받아서 꼭 사고 싶었던 거 구매했습니다', 5],
#  ['믿음이 갑니다', 7],
#  ['시간 낭비하지 않고 더 저렴하고 편하게 반란에서 구매해요', 5],
#  ['해외여행 못가서 발란 이용하고 있는데 마음에 드는 물건 가격도 싸고 배송도 받아서 넘넘 좋아요', 5],
#  ['쿠폰팩 너무 좋아요', 5],
#  ['할인도 많이 하는데 쿠폰까지 줘서 엄청 싸게 구매했어요', 5],
#  ['관세 포함이라 별도로 계산할 필요가 없네요', 5],
#  ['백화점에 비해 가격이 너무 저렴해서 놀랐네요', 5],
#  ['정품보상제도 있네요', 7],
#  ['믿고 사용하는 발란 추천합니다', 7],
#  ['정품 확실하니까 의심할 여지없이 매번 구매하게 돼요', 7],
#  ['앱 구성이 심플해서 사용이 편하네요', 1],
#  ['백화점에서 보고 반란해서 구매', 8],
#  ['배송 빠르고', 0],
#  ['포장 깔끔합니다', 6],
#  ['발란 보면서 스타일도 참고하게 돼서 좋아요', 8],
#  ['세이라는 거 잘 골라서 진짜 잘 사고 있어요', 8],
#  ['너무 좋은 가격에', 5],
#  ['밖에서 나가지 않고 집에서 쇼핑 하니까 너무 편해요', 8],
#  ['직구상품 저렴하고', 5],
#  ['진짜 배송 빠르네요', 0],
#  ['배송이 진짜 마음에 들어요', 0],
#  ['해외 직구 치고는 진짜 배송 빠른 거 같애요', 0],
#  ['너무 감사합니다', 8],
#  ['여기저기 발품팔지 않아도 돼서 정말 편하네요', 8],
#  ['생일 선물로 구입한거라 배송에 대해 민감했는데 결국 그 다음주 수요일까지도 배송준비중이네요', 0],
#  ['몇번이고 고객센터에 물었는데 무슨 말도 안되는 핑계만 계속 대더니 나중엔 답도 안하네요', 2],
#  ['한두푼 하는 것도 아니고 명품취급하는 곳에서 이딴 식으로 일처리 진행하나요', 8],
#  ['저는 특히 옷에 대한 리뷰를 보고 스타일에 참고 할수 있어요', 8],
#  ['백화점 가지 않아도 돼서 편하게 고를 수 있어서 좋아요', 8],
#  ['최저가 제품 서치 하다가 들어왔는데 쿠폰까지 쓰니깐 완전 최저가 네요', 5],
#  ['굳이 백화점 가서 명품 살 필요 없네요 여기가 더 저렴하고', 5],
#  ['물건도 많아요', 3],
#  ['저렴한 가격으로 매번 기분 좋게 사용하게 되네요', 5],
#  ['딜도 많고 쉽고 깔끔하게 잘 만들었네요', 1],
#  ['지갑하나 구입했지만연결되는 구매가 없는이유 예시   그린 펀칭패턴 소가죽 미니토트백  봐보세요', 8],
#  ['빼꼼도 아니고 이사진 한장가지고 어떻게 구매합니까 큰가방이 필요했는데 가방치수 숫자보며 결국 착핏은 상상으로든 다른 사이트 검색이든 고객을 위한 편의성이 부족해요',
#   9],
#  ['명품을 거의 구매해 본 적이 없어서 발란 들어와 봤는데 랭킹도 있고 현재의 유행을 알 수 있네요', 1],
#  ['좋은 앱입니다', 8],
#  ['굿굿 상품수 많고 브랜드가 다양하네요', 3],
#  ['좋은 제품 특가 많이 해서 저렴하게 살 수 있어 좋아요', 5],
#  ['블프라 패딩 알아보고 있는데 눈 돌아가네요', 8],
#  ['연말에 나에게 명품백 선물하고 싶어서 발란 찾고 있는데 다 맘에 들어요', 8],
#  ['명품 직구때 늘 불안한데 발란서 맘편히 믿고 사고 있어요', 7],
#  ['백화점보다 저렴해서 구매했습니다', 5],
#  ['눈팅하러 왔는데 브랜드 제품 정말 다양하네요', 3],
#  ['국내 최고의 명품 어플이라고 생각합니다', 8],
#  ['명품 검수도 잘된다고 해서 처음 깔았는데', 7],
#  ['요거요거 보는 재미가 있네요', 8],
#  ['다양한 제품 볼 수 있어서 좋아요', 3],
#  ['\n우선 앱 작동이 스무스하게 잘 되고 메인도 한눈에 들어오는 거 같아 사용하기 훨씬 편하네요', 1],
#  ['쇼핑하기에도 딱 좋고 잘 쓰고 있어요', 8],
#  ['친구가 트렌비에서 찾아서 보내줬는데 가격도 적당하고', 5],
#  ['마침 구하던 사이즈도 딱 있어서 바로 질렀어요', 3],
#  ['하나만 사도 무료로 배송해주니까 쇼핑할때는 트렌비만 찾게 되네요', 0],
#  ['다른데서 못 보던 아이템도 많고', 3],
#  ['제품만 보내면 알아서 검수도 꼼꼼하게 하고 정품 인증도 전문적으로 해주니까 훨씬 좋아요', 7],
#  ['\n앞으로 거래 할거 있음 걍 스트레스 안 받고 트렌비에다 맡기는게 이득이에요', 8],
#  ['해외 직구 사이트에서도 잘 못 봤던 흔하지 않은 제품들이 많아서 자주 찾게 되네요', 3],
#  ['보통 그런 아이템들은 비쌀텐데 생각보다 가격도 괜찮아서 자꾸 지갑이 열려요', 5],
#  ['ㅎㅎ\n계속해서 좋은 아이템들 많이 소개해주셨으면 좋겠습니다', 3],
#  ['\n얼마 안되서 빠르게 확인해서 처리해주시고 판매자분 통해서도 한 번 더 추가로 안내를 주셨어요', 2],
#  ['단순 오류여서 배송도 별다른 문제 없이 일정보다 빠르고 안전하게 잘 도착했습니다', 0],
#  ['보통 해외 배송 건은 바로바로 확인이 어려운 경우도 많던데 빠르고 친절하게 안내해주셔서 좋았어요', 2],
#  ['매번 옷이나 신발만 구매했었는데 보니까 가구나 조명 같은 것도 들어와 있더라구요', 3],
#  ['\n마침 이사 준비 중이라 인테리어 아이템 보고 있었는데 옷보러 왔다 요런 것만 왕창 질렀네요', 8],
#  ['\n워낙 큐레이션이 좋아서 가구나 가전 쪽도 아이템이 더 많아지면 자주 구매하러 올거 같아요', 3],
#  ['조와요', 8],
#  ['디자인이 심플하고 복잡하지 않아 쇼핑하기에 다른 몰들에 비해 훨씬 편해서 좋아요', 1],
#  ['굿', 8],
#  ['좋아요분류가 쉽습니다', 1],
#  ['태어나서 이딴 앱은 처음 봄', 8],
#  ['품절이 너무 많습니다', 3],
#  ['품절된거 확인해서 구매 안되게 해주세요', 8],
#  ['정말 인터넷광고를 모하러하냐ㅋㅋㅋㅋ 앱 절대안깔고 절대안삼', 8],
#  ['사용할때마다 애플로그인 문제생겨서 몇십분을 고생해야하고 앱을 어떻게 만들면 이렇게 못만드나요', 4],
#  ['오케이몰 쓰세요', 8],
#  ['구매한지 한달이지나고 판매자한테 연락이왔는데 재고없으니까 취소한다고함ㅋㅋ어이가없다', 3],
#  ['트렌비 직원들아 일좀하셈 ', 8],
#  ['기껏 날짜 전에 시켰더니 혹시 몰라서 배송날짜 확인하니 품절이란다 일 안할꺼면 왜 웹 만들었나 싶네', 8],
#  ['다른 곳과는 다르게 넘버원 이라는 타이틀이 어울리다고 생각합니다', 8],
#  ['좋은제품 잘샀습니다', 6],
#  ['어플도 뒤로 가기 한번 하면 느려터지고 불편해 죽겠네 차라리 트렌비가 다 낫다', 1],
#  ['무슨 상품 가격이 제각각이고 원래 만원 하는 상품인데 만원에 프로 세일이라고 거짓 정보가 들어간게 너무 많어', 8],
#  ['다른곳 보다 할인율도 높고 쿠폰도 많이 주네요  이런 곳을 이제야 알았네요 ㅠㅠ 앞으로 자주 이용해야겠어요', 5],
#  ['주가 지나서 배송 문의 하였으나 해외배송이라 조금 늦을 수 있다는 답변주셨습니다', 0],
#  ['주가 지나서 배송 문의 하였으나 해외배송이라 조금 늦을 수 있다는 답변주셨습니다', 2],
#  ['주 주가 지나도록 배송현황이 변함이 없어 문의드렸더니 다음 주말까지 받을 수 있도록 해준답니다', 0],
#  ['주 주가 지나도록 배송현황이 변함이 없어 문의드렸더니 다음 주말까지 받을 수 있도록 해준답니다', 2],
#  ['배송 지연에 대한 패널티는 없고 환불하려면 만원 위약금 지불이라니 답답할 노릇입니다', 8],
#  ['해외에서 배송을 보내지도 않아서 송장이든 등기든 조회도 안되는 상황에서 환불 위약금을 만원 요구하는건 상식적으로 이해도 안되고 납득이 되지 않습니다',
#   8],
#  ['\n\n내생애 최악의 해외배송 사이트트렌비', 0],
#  ['발란 덕에 요즘은 구매대행 안하구 이써요', 8],
#  ['가격도 저렴하고 쇼핑도 편리하네요 감사합니다', 5],
#  ['검수 영상 문자로 보낸다더니 보내지도 않고 물건에는 칼로 그은듯한 기스 나있고 ㅡㅡ', 7],
#  ['와 비회원은 주문 조회도 안되게 해놓고 되는 것 처럼 문의하려니까 또 가입하라고 하고', 1],
#  ['다른 사이트들에서 보지 못한 제품들이 많네요 신상도 많고 다양한 제품들이 많아서 선택의 폭이 넓어졌어요', 3],
#  ['유니크한 제품들도 많고 종종와서 트랜드 읽기도 좋네요', 3],
#  ['저번에 백화점에서 봤던 신발 주말에 다시 나가기 귀찮아서 사진찍어뒀다가 발란에서 주문했어요', 8],
#  ['역시 백화점보다 훨씬 저렴한 가격에 겟', 5],
#  ['좋아요', 8],
#  ['할인', 5],
#  ['다양성 좋음', 3],
#  ['검수를잘하는듯', 7],
#  ['굿굿', 8],
#  ['사이즈 표기가 젤 문제 한국사람 체형 대비 사이즈 없음', 9],
#  ['알아서 감으로 찾아야함 결국 사이즈 안맞아서 돈 버리는 경우가 많음', 9],
#  ['새제품을 주문했는데 왜 검수단계에서 스크래치가 나는지 이해불가명품은 그래도 되는건가', 7],
#  ['배송상태가 업데이트 제대로 안됨', 0],
#  ['결론은 트랜비 이용안할예정', 8],
#  ['진짜 지웠다가 다시 깔아도 똑같네요', 8],
#  ['최고에요', 8],
#  ['여자 패션 키워드는 있는데 남성 패션이나 남성 상품 탭은 없어요', 1],
#  ['이 앱 자체가 여성 쇼핑몰 중점인듯 합니다', 8],
#  ['사려던 마음도 싹 사라짐 서버 무한 로딩에 로그인도 자꾸 튕김 그냥 기본조차 안되있는 어플 사려 해도 서버가 팅기는데 무슨 옷을 팔겠다고 ㅋㅋ 광고 전에서버나 잘 챙기세요',
#   4],
#  ['앱도 괜찮고 잘만드신거같은데 푸시알람 안오게설정에서 바뀠는데 내용없는 없는 알람이 계속옵니다', 8],
#  ['광고로 유일해서 설치 악질', 8],
#  ['괜춘', 8],
#  ['다양한제품을즐기고 구매할수있어좋은거같네요', 3],
#  ['저렴한가격에 구매가능하고 믿을수있어 ', 7],
#  ['저렴한가격에 구매가능하고 믿을수있어 ', 5],
#  ['저렴히', 5],
#  ['다양한 물건', 3],
#  ['어렵게 구할물건들도 종종있어서 득보고있네요', 3],
#  ['다많은 제품 보여주세요\n감사합니다', 8],
#  ['자주쓰는 명품구매처에요 저렴한편이고 좋아요', 5],
#  ['슈퍼스타 구매 했는데 아무슨 검수도 안 하고\n보내는 곳이 어디있나요', 7],
#  ['상품 하자가 있는데', 6],
#  ['그냥 검수도 안 하고 보내네요', 7],
#  ['출근 길에 발견해서 회 착용 때문에 환불도 안 되고 이런 진짜하', 8],
#  ['살짝만 사용 안 하면 로그인 다시 하라고 뜨는 거 짜증나네요 로그인 다시 할라고 비밀번호 치는데 뭔 확인 버튼만 누르면 비번이 지 혼자 두글자는 더 늘어나더니 비밀번호 틀렸다는 오류까지 나고 비번 찾을라고 인증번호 받기 눌렀더니 뭔 인증번호 하나 오는데 분이나 걸리네요',
#   1],
#  ['괜츈네요', 8],
#  ['주 내내 배송 준비 중', 0],
#  ['주문 상태 좀 더 디테일하게 좀', 8],
#  ['문의하면 계속 본질에 벗어나는 답변만 하고 ㅡㅡ', 2],
#  ['도대체 로그인을 어떻게 하는건가요 로그인 페이지가 안나와요', 4],
#  ['회원가입 하라고만 되어있고', 8],
#  ['여기서시계삿는데 무슨사용한지개월만에 고장남 와돈만 오십날렸네', 6],
#  ['좋은 상품들이 저렴하게 올라오네요', 5],
#  ['아직은잘모르지만 검색하고상품보기편해요', 1],
#  ['여기서 살바에 머스트잇에서 사겠습니딘', 8],
#  ['다른 쇼핑몰보다 풍부한 볼거리가 많고 선택의 폭이 넓은것 같습니다', 8],
#  ['상품 옵션 고를때 조금더 세밀하게 고를수 있도록 해 주세요', 1],
#  ['월일 주문한 제품이 몇 주 동안 계속 국내 배송중으로 배송정보가 뜨고 있는데 한땀 한땀 꿰매는 수제 양복 만들듯이 한걸음 한걸음 조심스럽게 배송하는건지요',
#   0],
#  ['\n아무런 해명이나 사과 통지도 없어 고객센터에 접수했더니 고객선테 마저도 느릿느릿 일주일이나 되서야 미안하다는 답변이나 보내고\n대단한 업체인듯',
#   2],
#  ['구매신청도착예정 일', 0],
#  ['한달 후 현지바잉중', 8],
#  ['기다리다 ㅈ같아서 환불처리', 8],
#  ['응 그래도 수수료 떼간다 판매자가 잘못이든 물건을 배송 안했든 아무튼 우리는 수수료 떼간다', 5],
#  ['그냥 다들 크림 사용하세요', 8],
#  ['머갈통 텅텅 빈 상담원들직원들 빡쳐서 취소하는 환불 수수료로 생계 유지 하는듯', 2],
#  ['쓰레기 앱', 8],
#  ['구매하려는데 배송지 입력이 안되네요이', 4],
#  ['배송지 추가 우편번호 검색 들어가면  에러 발생해서 주문을 못해요', 4],
#  ['다른 사이트에 광고로 랑크되어올려있는 상품좀 보려고 그상품 클릭하면 왜그상품 볼수없고 항상 메인으로 넘아가죠다른 사이트들은 안그런데요',
#   1],
#  ['어플 어쩔수없이 설치하고 그상품 클릭해도 계속 메인으로 넘어감 사이트설치 강제로 시키려고 그런의도같은데 설치하면 링크되어있는 그상품 클릭하면 바로볼수있게는 해야 하잖아요 짜증나서 어플삭제해요',
#   4],
#  ['진짜 너무 화가나요 왜 우편번호찾기 버튼이 안눌리냐고요', 4],
#  ['ㅠㅠㅠㅠㅠ주소 입력이 안되서 주문을 못하잔아요', 4],
#  ['불편해요', 1],
#  ['반품이나 사이즈교환시 비용이 만만치 않네요', 0],
#  ['구매시 신중하세요', 8],
#  ['정품이고 너무 좋습니다', 7],
#  ['배송도 빠르고', 0],
#  ['아주좋아요', 8],
#  ['왜 여기제품은 정가보다 프로정도 더 비싼건지모르겟음 다른사이트는싼대', 5],
#  ['가격은 최저가 검색되게 해놓고 키즈사이즈 끼워놓고 실제 가격은 시세에비해 너무 비쌈네이버나 지마켓 옵션 장난질하고 다를게 없음', 5],
#  ['머스트잇측에서 재고부족으로 판매취소되면 ', 8],
#  ['달랑 프로 쿠폰 한달 기간짜리줘놓고 ', 5],
#  ['첫구매 쿠폰 기회는 날라갑니다', 5],
#  ['좋은제품마니올려주세요', 6],
#  ['오류가 너무 심해요', 4],
#  ['ㅠ\n물건 볼려고 누르면 하얀색 바탕화면 나오고 \n구매할려고 시간 투자해가면서 보는데 계속 오류 걸리니깐 앱만 껏다 켯다 무한반복 설치한지 몇일되지도 않았는데답답',
#   4],
#  ['오래되지는 않았지만 좋은 느낌이예요', 8],
#  ['해외배송 상황도 볼수있었으면 합니다', 1],
#  ['너무 좋아용\n맘에 들어용', 8],
#  ['다운받았는데 쿠폰없네요', 4],
#  ['전 물건도 잘받고 생각보다 빨리오긴 했는데 어머니 생신 선물 로 바뻐서 발란 으로 주문했는데 발란박스에 딸랑 구찌주머니 그렇게줌 그걸어떻게 최소한 쇼핑백만 이라도 주었다면 말안겠슴 이젠 발란에서 안삼 명품에 가치가 있지 그걸 어떻게 선물함 꼴랑 신발주머니 같은거 포장에서 최소한에 예의지 리뷰사진보니가 박스랑 쇼핑백 포장 다 가짜리뷰 이젠안삼 여기서',
#   6],
#  ['앱 반응속도가 정말 잣같지만 상품 구매에 관해서는 괜찮네요', 1],
#  ['대부분 구매대행이라 박스 상태는 기대하지 마셈', 0],
#  ['어플도 잘되어있고 쇼핑하기도 편해요', 1],
#  ['배송 보려니까 아이폰으로 로그인 하기 눌러도 안돼서 계속 시도 해봐도 안되는데 ', 4],
#  ['오류라면 빨리 시정해주시길 바랍니다', 4],
#  ['일점도 아깝네요', 8],
#  ['구매한디 일주일이 지나도록 재고 확인도 안하고 ', 3],
#  ['배송 문의하니 품절이라며 취소해버리네요', 0],
#  ['\n발란이나 머스트비에 안되는 이유가 있네요', 4],
#  ['불쾌합니다', 8],
#  ['도대체 언제 배송이 되려고 현지 바잉으로 넘어가지도않고 입금 완료만 띄워주시는지 그냥 예상수령일을 보여주질 마시던가요', 0],
#  ['수령일보고 생일선물 주문한건데 하도 기미가 안보여서 더는 못기다리겠어요', 0],
#  ['배송도빠르고', 0],
#  ['친절하게 대응해주시고 이쁘게잘받았습니다', 2],
#  ['오늘출발 주문했으나 이틀뒤 배송준비만 뜨더니 품절이라고 취소문자옴이용할일 도 없을거 같네여', 0],
#  ['짭이 좀 있네요', 7],
#  ['좋은상품 저렴히 살수있어 좋아요', 5],
#  ['색도 바래서 진품같지도 않아보이고', 7],
#  ['저는 가슴에 해골 로고가 있는 지포어 골프 티셔츠를 구매했는데 해골 로고가 없는 티가 배송이왔고 색도 바래서 진품같지도 않아보이고 환불요청해서 반품해간지 일이 되었는데도 아직도 환불처리도 안해주고 사과도없네요',
#   2],
#  ['벨트도 주문했는데 다른컬러가와서 라운딩 다 망쳤습니다', 8],
#  ['인터넷 광고에서 제품보고 클릭해도 어플로 연결되지않네요', 4],
#  ['그럴거면 뭐하러 돈들여서 광고하십니까 광고하는 목적이 제품판매가 아니라 어플 방문회 늘리는 거에요', 5],
#  ['그제품 분 찾아보고 포기 지웁니다', 8],
#  ['자동로그인 걸어놔도 매번 로그아웃되는데다가', 4],
#  ['심지어 얼마전부턴 업데이트해도 카카오톡으로', 4],
#  ['로그인이 안되는현상이있어서 사고싶은게 있어도', 4],
#  ['못사고있네요', 8],
#  ['카카오톡 로그인 되게 해주세요', 4],
#  ['상세이미지아왜 자꾸 짤려서 나와요', 9],
#  ['원하는 명품을 쉽게 구입했습니다', 3],
#  ['옷 사 입기 좋은 어플', 8],
#  ['품절은 품절이라고 바로 표기됬으면 좋겠어요', 9],
#  ['편의성 있고 아주 유용하게 사용하고 있습니다', 1],
#  ['화면도 깔끔하고 단순해서 거래하기 쉬워서 좋아요', 1],
#  ['아이템 구성이 한 눈에 들어와 쇼핑하기에 매우 편리하고 좋습니다', 1],
#  ['명품을 싸게 살 수 있어 좋고', 5],
#  ['여러가지 패션 의류나 캠핑용품 등 다양하고 질 좋은 제품이 있어 자주 이용하고 있어요', 3],
#  ['앞으로 계속해서 이용 할께요 감사 드립니다', 8],
#  ['혜택도 좋은 것 같고 쿠폰도 구간별로 잘 지원해주는 것 같으며', 5],
#  ['고품질의 질 좋은 제품들도 기대 이상으로 꽤 많이 확보되어 있는 것 같아요', 6],
#  ['그래서 유사한 제품에 대한 라인별 퀄리티를 다양하게 비교하면서 확인할 수 있어서 좋은 것 같네요', 6],
#  ['또한 네이버페이처럼 다양한 결제 시스템을 호환 지원 가능하게 해놓아서 결제 편의성이 정말 뛰어나네요', 1],
#  ['이때까지 수십년간 사용해본 사이트 중에서 단연코 최고라 할만합니다', 8],
#  ['다만 조금 보완해야 할 점을 요청한다면 리셀상품의 경우 화질적인 측면에서 제품의 퀄리티와 상태를 선명하게 확인할 수 있도록 제품 사진에 대한 해상도를 좀 더 높여서 업로더해주시면 좋을 것 같습니다',
#   1],
#  ['현재 갤럭시 노트  사용중이므로 화질 대응에는 전혀 문제없으며 의류의 경우에는 최고 해상도로 설정 후 쇼핑합니다', 1],
#  ['베타이후가 확실히 편하고 좋아요 그런데 알림설정은 어디서 하는지 잘 모르겠네요', 1],
#  ['나머지는 리뉴얼되어서 많이 좋아진 듯 합니다', 1],
#  ['아 그리고 검색화면에 나오는 목록의 사진 크기가 살짝 크고 여백이 많은 듯 한데 이걸 좀 줄여서 한 화면에 보다 여러 상품을 볼 수 있으면 좋을 것 같아요 사진들도 하나만 나오는 것이 아니라 좀 더 추가하면 좋을 것 같구요 검색한 목록에서도 아예 거래내역이 없는 것들이 왜 최근인기순으로 나열하면 위쪽에 있는지 잘 모르겠어요',
#   1],
#  ['검색결과가 깔끔하게 정렬되는것도 맘에드는 부분중 하나입니다', 1],
#  ['트렌비에서 구매 번정도 해봤는데 쿠폰도 다양하게주시고 배송비도 무료에다가', 5],
#  ['앞으로도 계속 쿠폰 마니마니 주시고ㅎㅎ 계속 사용하겠습니다', 5],
#  ['그리고 랭킹 서비스는 옷 못입는 저에게는 가뭄에 단비같은 느낌이였습니다', 1],
#  ['ㅠㅠ ㅠ사랑해용 ㅋ', 8],
#  ['세일 정보 확인할 때 유용하게 사용중입니다', 5],
#  ['다만 푸시알림으로 찜한 상품에 대해서라도 가격 하락이나 입고 유무 등 받는 기능이 생겼으면 좋겠습니다', 1],
#  ['그리고 리셀상품의 경우 네고하기 같은 기능이 추가됐으면 합니다', 1],
#  ['감사합니다', 8],
#  ['모든 상품이 무료배송인거 같네요 넘 좋아요', 5],
#  ['익일 배송으로 하루만에 오는것도 넘 편하구요', 0],
#  ['도 다른 앱처럼 정신없이 옷사진들이 바뀌지 않아서 맘에 들어요', 8],
#  ['옷을 벌밖에 안 사봤지만 다 만족스러워서 환불한 적은 아직 없네요', 8],
#  ['요 몇 주 동안 써보면서 깨달은건 리뷰많은 상품은 사기로 결정했을 때 안 사면 품절 빨리 된다는거', 3],
#  ['기능과 아이디어는 패션 앱중 정말 혁신적이고 되게 좋습니다', 1],
#  ['하지만 보완해야 할 점이 몇 군데 보이는 것 같아서 의견 보내봅니다', 1],
#  ['패션 전문가들은 알지만 일반인들은 모르는 패션용어  각 패션용어에다 부가 설명을 붙이거나 각 패션 카테고리별로 예시 코디컷들을 보여주는 창 하나를 추가하셔도 정말 좋을 것 같네요',
#   9],
#  ['기능 상 보완 오늘 처음으로 회원가입해서 게시물 몇 개씩 보는데 같은 상품인데 다른 가격으로 노출되는 상품들이 많네요', 1],
#  ['한눈에 보면 좋을텐데 이것들만 수정되면 메이저 패션 앱으로 거듭날 것 같은 좋은 느낌을 받았습니다', 1],
#  ['유저들의 의견도 반영하려고 하는 모습도 보이는 것 같네요', 8],
#  ['번창하십시오', 8],
#  ['정말 잘 쓰고 있는데 몇가지 기능이 추가로 생기면 더 좋을거 같아요', 1],
#  ['정렬 기준에 판매순과 리뷰순이 생기면 좋을거 같습니다', 1],
#  ['찜 해놓은 상품을 사용자가 임의로 그룹으로 묶어 정리할 수 있은 기능이 생기면 편할거 같습니다', 1],
#  ['괜찮다 싶어 찜 해놓은 상품들을 보니까 너무 중구난방으로 섞여있어 보기가 힘들어요 이정도만 돼도 트렌비이란 앱이 더 인기가 많아질 수 있다고 생각해요',
#   1],
#  ['화이팅 하시길 바랍니다', 8],
#  ['기획전 상품들도 좋은거 같고', 3],
#  ['아무래도 사이즈나 디자인은 온라인으로 디테일하게 확인하기는 좀 힘드는데 다각도로 모델 사진과 제품 상세컷이 다양해 도움이 됩니다',
#   9],
#  ['교환 반품시에 드는 비용이나 시간을 생각 해 보면 특정 브렌드 때문에 앱을 사용하기에 저로썬 자주 이용하지 않게 됩니다', 5],
#  ['자주 이용할 수 있도록 콘텐츠들이 많았으면 좋겠습니다', 8],
#  ['저렴한 가격으로 매번 사용하게 됩니다', 5],
#  ['직관적인 인터페이스 ', 1],
#  ['없는게 없는 쇼핑몰이라 네이버 검색보다 먼저 찾게되네요', 3],
#  ['결제와 같은 일부 기능들은 늘 그래왔듯 신속히 개선될거라 생각되니 크게 걱정은 되지 않습니다', 8],
#  ['언제나 소비자를 위해 고민해주시는점 감사하게 생각하며 요즘 핫한 수입 중저가 가전 등도 추가되길 기원해봅니다', 8],
#  ['명품 판매하기 매우매우매우 유용한 앱입니다', 8],
#  ['앱이 엄청 좋은데 이런 앱이 있다는 홍보가 자주 보이지 않아서 꽤 많은 사람들이 모른다는 게 아쉽네요', 8],
#  ['앱 와 탭들의 디자인들도 쉽고 심플합니다', 1],
#  ['다만 이건 저의 개인적인 취향이지만 앱로고가 조금 별로네요', 1],
#  ['앱 로고와 앱 이름에 따라서 소비자가 그 앱에 대한 이미지와 분위기가 확 달라지는데 조금 아쉽네요 제 생각에는 앱 이름이나 로고를 수정하고 광고를 한다면 정말 정말 대성할 앱이라 생각합니다',
#   1],
#  ['주식이 있다면 사고 싶을 정도로요 이 앱을 만드는데 일조하신 모든분들께 감사를 표합니다', 8],
#  ['오래전부터 사용하는 사이트인데 최근 메뉴도 조금씩 개선되고 사용하기 편해지는거 같아 좋습니다', 1],
#  ['정품 명품은 이곳이 가장 안전해서 자주들어가는데', 7],
#  ['초기화면에 제가 관심없는 상품이 떠서 살짝 아쉽습니다', 1],
#  ['인기상품 내가 좋아할만한 상품시기별 추천상품 등으로 다양하게 보여주면 더 좋을거 같습니다', 1],
#  ['여름부터 알게되어서 사용했는데 진짜 잘 이용하고 있어요 특히 여름에 겨울옷 특가할때 겨울점퍼하나 샀는데 진짜 완전 득템한기분입니다',
#   5],
#  ['어떤건 너무 상품이 많고 복잡하고 어떤건 너무 상품이 없었는데 트렌비는 딱 제가원하는 스타일들이 많이 있고 사용법도 너무 간단해서 최종적으로 남은 어플이에요',
#   1],
#  ['그 후로는 틈틈히 들어가서 세일 상품도 자주 보게 되는거 같아요 세일 제품 아니더라도 기본적으로 백화점보다 조금씩 저렴하거나', 5],
#  ['매장에는 없는 상품들도 있어서 쇼핑하기 정말 좋아요', 3],
#  ['사용자에게 편리한 를 갖추고 있는 어플리케이션이라는 생각이 들었습니다', 1],
#  ['아이템 구성이 한 눈에 들어와 쇼핑하기에 매우 편리하고 좋습니다', 1],
#  ['앞으로도 편리하고 간편하게 이용하겠습니다', 1],
#  ['좋은 어플리케이션 개발해주시고 구성해주셔서 감사드립니다', 1],
#  ['앱 깔끔하고 조아요', 1],
#  ['여러 사이트를 검색하지만 결국 최후로 구매결정하게 되는 사이트가 바로 머스팃입니다', 8],
#  ['감사합니다', 8],
#  ['가격이 좋아요', 5],
#  ['작성하려고 하는데 사진 선택하고 체크버튼 눌러도 반응이없어요', 4],
#  ['전혀 안 돼고 시간만 끌어요', 8],
#  ['마지막엔 안됨 반품하려면 수수료 왕창', 5],
#  ['뒤로 가기 누르면 처음으로 돌아가는건 리뷰보니 작년부터있는 문제인데 고치지를 못하시네요 ㅎㅎ 올 봄에 가입해서 첫구매했는데 다시 구경왔다가 불편해서 적립금있는데 수신거부하고 걍 어플지웁니다',
#   4],
#  ['시간낭비에요', 8],
#  ['어차피 특가라해봤자 싼것도아니고 말로만 특가지 쿠폰으로 장난치는거 다아는데 한곳에 모아볼려고 어플쓰는거지 이렇게 불편하면 어플을 왜써요 쓰레기어플 안써요',
#   1],
#  ['생각나면 웹페이지로 볼게요   ', 1],
#  ['가방 로고 아래부분에 기스 있어서', 6],
#  ['교환해 달라니까 미세 기스라고 교환하려면 돈내라고함 뭐 이런 경우가 다있나 싶음 최악임', 8],
#  ['만족감 최고', 8],
#  ['이거진짜 개웃긴게 싹다 정품도아닌듯하고 정품인지도 모르는물건 팔고', 7],
#  ['판매자 연락하기싫어서 고객센터로 신청했다 하니깐 고대로 판매자랑 직통으로 전화연결 시켜버림', 2],
#  ['굉장히 실망입니다', 8],
#  ['솔직히 진짜 빡쳤습니다', 8],
#  ['트렌비는 주문 상세 내역을 총 단계주문접수현지바잉중해외배송준비중배송중배송완료로 구분해 유저에게 보여주고 있습니다', 0],
#  ['전 해외배송이 필요한 상품을 월일 주문했고 월 일에 주문상세내역에서 해외배송준비중 단계임을 확인했습니다', 0],
#  ['해외배송준비중은 현지 물류센터에 상품이 입고되어 순차적인 검수 및 배송 준비중입니다', 0],
#  ['라고 설명되고 있고요', 0],
#  ['그리고 월 일에 고객센터로부터 제가 주문해서 주동안 기다린 물건이 구매처에 의해 품절되었다는 연락을 받았습니다', 2],
#  ['일을 도대체 어떻게 하는 겁니까  현지 구매처로부터 이 물건이 바잉이 완료 되었는지 확인조차 제대로 되지 않은 채로 해외배송준비중이라는 상태로 노출시키는건 뭡니까 실제로 물건은 물류센터에 존재하지도 않았던 것인데품절이었으니 그것을 구매한 유저에게는 현지물류센터에 있다고 고지하는것은 기만아닙니까 해외배송물건의 특성상 유저들은 내가 구매한 물건의 현재 위치 및 상태에 예민할 수밖에 없습니다',
#   8],
#  ['세관을 잘 거쳐 물류센터에 들어왔는지 현지에서 바잉이 되었는지 등 해당 단계들에서 문제가 많이 발생하는 것을 알기 때문에 굳이 트렌비와 같은 직구 사이트를 통해 구매를 하는거고요',
#   8],
#  ['이런 부분에 대한 수고를 덜어줌은 물론 현지 구매처와의 빠르고 정확한 소통을 책임져주는 곳이라고 생각하니까요', 8],
#  ['그런데 이번 사태는 애초에 판매처로부터 물건이 제대로 있는지 확인을 먼저 하지도 않고 현지물류센터에 입고되었다는 고지를 하는건 심지어 물건이 있는지 여부 확인을 주동안이나 하지 않다가 늦게서야 하는 트렌비의 운영 방식에 의문을 품을 수밖에 없는 사건이었습니다',
#   8],
#  ['플랫폼과 현지 판매처의 소통이 도대체 어떻게 굴러가고 있는 것인지 의문이네요', 8],
#  ['전 품절된 상품이 물류센터에 있다고 생각하고 주 넘는 시간동안 기다린 꼴입니다', 0],
#  ['심지어 기념일 선물이었는데요 ㅎㅎ', 8],
#  ['세일이나 특가 광고는 푸시알림으로 엄청 보내놓고 구매 유도하기 위해 쿠폰 왕창 뿌리고 사람들 모아 상품이 실제로 있다는 보장이 있든 없든 일단 쿠폰써서 구매하게 하고 배송 준비중이라는 말로 안심시켜둔 뒤 나중에서야 물건 유무 확인하고 품절됐다고 또 사과말씀 돌릴건가요 그러면 사람들이 그 사이에 만료된 쿠폰 쓰지 못하고 제 값 주고 물건을 구매하니 이건 결국 트렌비의 전략인가요 별 생각이 다 드네요',
#   8],
#  ['\n\n애초에 이러한 프로세스를 허술하게 구성하고 운영한 기획운영팀에게 책임을 묻고 싶습니다', 8],
#  ['고객센터 역시도 말로만 사과할 게 아니라 이 프로세스에서 시간을 낭비한 애꿎은 유저들에게 확실한 대책 제시를 할 수 있는 메뉴얼을 구축하시면 좋겠습니다',
#   2],
#  [' 직원분께 귀책이 있는 것도 아닌데 계속 정말 죄송하다고만 말씀하시는 분께 이런 이야기 하고 싶지 않아 여기에 남깁니다', 8],
#  ['싸게잘사고있어요', 5],
#  ['발란보다 많이비싸네요', 5],
#  ['로그인이 안됩니다', 4],
#  ['모바일 검색 카톡연동 가입하고 앱깔고 로그인하려하니 먹통', 4],
#  ['분명 모든 백화점 가능하다고 했는데 왜 거짓말을 시키조', 8],
#  ['해외배송 한달이상소요음', 0],
#  ['해외배송 한달이상소요 고객센터 전화시 불친절응대로 재구매의사 없음', 2],
#  ['진짜 최고임요', 8],
#  ['담당자분이 너무 친절하심', 2],
#  ['로딩 속도 너무 느리고 상품을 본후에 뒤로가기하면 스크롤이 다 올라가 있어서 짜증납니다', 1],
#  ['이건 기본아닌가요', 8],
#  ['별하나도 아까움 양아치쓰레기앱 욕도아깝다 주동안 기다린 물건이 스크레치가 있다하여 원하시면 재주문해준다해서 기다렸는데 일주일뒤 그 사이 가격이 올랐다면서 차액 만원을 더 지불하면 준다함 싫으면 취소하라고 어이가 없어서 이런게 어딨냐 하자있는 물건이라고 당신들이 정상물품으로 재구매해준다더니 왜 내가 차액을 지불해야하나 그때 세일가였으니 구매한거지 주나 더 오래 기다리게 해놓고 미안해하긴 커녕 이런 말도 안되는 경우가 어딨냐 그랬더니 구매시 상세페이지에 가격변동이 있을수있다고 홈페이지에 나와있대요 하하 그러면서 싫으면 취소하라고  고객을 완전 호구로 아는 양아치앱이에요',
#   8],
#  ['일부러 하자 있는 물건 팔지 못하는것 싸게 파는척 하고 내놓은뒤 스크레치있어 출고 안했다고 해서 재구매 유도한 뒤 가격 높여 받는게 상술인듯 아님 스크레치 나서 어차피 못 파는거 고개한테 팔면 그만이고 양심도 없고 상도덕도 없고 뻔뻔하고 아주 그냥 마인드가 썩었네요',
#   8],
#  ['가격대 넘조아용백화점에 안가도 편하게 고를수잇구용', 5],
#  ['굿드굿드', 8],
#  ['반품도 잘 안되고 반품비 만원 ㅡㅡ', 0],
#  ['범고래 나이키 원이라고 앱 깔아 보니 어디에도 그 가격은 없네 미끼입니까', 5],
#  ['최악 광고도 최악 수신거부도 자리 인증번호를 초안에 입력못하면 수신거부도 못함 최악 그자체', 4],
#  ['배송지연 안내가 문의 전에 없는 점은 아쉽지만', 0],
#  ['합리적인 가격으로 파정 구입했어요', 5],
#  ['가 잘 되어있어서 사용하기도 편하네요', 1],
#  ['트렌비 최고', 8],
#  ['가입 귀찮아서 비회원으로 결제했는데 주문확인하려면 무조건 어플 다운받아야함 대체 그럼 비회원주문 왜있는건가요', 1],
#  ['어플 개발자들이 회사를 망조들게 할려나보네요', 4],
#  ['업데이트 눌렀더니 대기중으로 무한루프중ㅎ 업데이트를 안하면 기존 버전으로 들어가야 되는거 아닌가요 ㅉㅉ', 4],
#  ['판매자가 주문한지 일짜에 배송준비중 띄워놓더니 지맘대로 취소때림ㅋㅋㅋㅋㅋㅋㅋ골때린다 쓰지마세요', 0],
#  ['배송도 빠르고', 0],
#  ['여러 상품을 한번에 볼수있어 너무좋고 할인 이런게 잘 볼수있어 너무좋네요', 1],
#  ['역대급 개판인 서비스 상품 결제이후 일동안 배송정보 업데이트 및 상담 불가 인생 최악의 고객서비스를 경험해 보고싶은분들께 추천합니다',
#   8],
#  ['크림과똑같은 매장 제품 가격이 만원 이상 비싸게 올리는 사이트ㅡㅡ', 5],
#  ['로그인이 안됨', 4],
#  ['광고는 할인 몇할인 등 되게 파격적인 세일을 하는거마냥 하면서 막상 들어가보면 원가를 무지막지하게 높여놓고 할인율을 올리는 의미없는짓거리가 되있는 허위광고 투성이에 실상도 엉터리인 앱입니다',
#   5],
#  ['럭셔리 쇼핑이 아니라 허위광고 엉터리 쇼핑이 맞겠네요', 8],
#  ['앱 이름 부터 바꾸세요', 8],
#  ['모든 전상품 정품인가요', 7],
#  ['만원돈주고버버리옷을시켰는데주넘게걸려서받았습니다', 0],
#  ['그런데옷에보풀이있더군요', 6],
#  ['떼어질줄알고손으로떼어봤는데정도가너무심해서 반품했는데 공장에서그럴수있다고하자가아니라고택배비를 받더라고요너무기가막히더군요', 0],
#  ['보풀이라면떼어져야하는데고대로붙어있는데누가그돈주고버버리를사겠냐고소비자입장에서는 택배비만원을떠나서너무기분나쁩니다', 5],
#  ['환불이나빨리해주는것도아니고 기다리는시간도있는데받았을때그런상품오면기분이어떤지사진까지첨부하고싶습니다', 8],
#  ['이게하자가아니면어떤게하자고문제인지누가이런식으로옷을만듭니까', 6],
#  ['진짜 어플 속도가 너무 느려서 답답하고', 4],
#  ['주문 잘못해서 취소하고 재주문 할려 하는데 취소도 하루 종일 걸리고 고객센터 들어가서 문의 하려는데 너무 느려서 영업시간 지났다네요',
#   8],
#  ['진짜 최악의 어플입니다', 8],
#  ['요즘 옷들 신상 유행옷들을 추천해줘서 좋아요', 8],
#  ['잘 모아져있음 간편함', 1],
#  ['광고 보고 옷이 이뻐서 클릭하니 발란으로 연결은 되는데 광고 하던 옷이 아니고 메인 페이지로 가면 그옷은 어찌 구매하나요', 1],
#  ['모바일로 보는데 광고에서 옷 이름이 나오는거도 아니고 달랑 이미지만 있어서 클릭하면 옷을 찾을수가 없어요', 1],
#  ['반품시 불만족', 0],
#  ['아주만족입니다', 8],
#  ['진심 개좋음', 8],
#  ['쓰지마세여 제발 차라리 번개장터나 당근마켓이 훨나음 괜히 택배비 날림 에휴', 8],
#  ['쓰윽둘러보기 좋음 ㅎ', 1],
#  ['상품받았을때 확인해보니 퀄리티가 가품못지 않더라구요', 7],
#  ['마감처리도 잘 안되어있고 정가품 문의해보니 다행히정품은 맞다고 하더라구요', 6],
#  ['요즘 발란 말 많던데 그냥 다른 어플 쓰시는게 나을듯 싶네요', 8],
#  ['구입 후 리뷰보고 고객센터 문의 안된다고 하길래 포기하고 그냥 입기로 했어요', 8],
#  ['좋아오', 8],
#  ['상담 서비스 진짜 느립니다', 2],
#  ['주말에 시간째 기다려도 답장을 안 주시네요', 2],
#  ['평일은 그래도 분 만에 주는데 주말은 개느려요', 2],
#  ['그리고 위탁 판매 맡겼는데 판매 현황이 오류인지 뭔지 안 뜨네요', 4],
#  ['빠른 배송 너무 좋습니다', 0],
#  ['아니 앱 사용하는데 손가락확대가 안되나요', 1],
#  ['상품도착예정일이 지나서도 제품 출고가 확인되지 않고 상담원께서는 더 기다리라 그렇지않으면 수수료는 고객님 부담으로 일관하시네요', 2],
#  ['업체 측 과실인데 왜 고객이 취소 수수료를 물어야할까요', 8],
#  ['할인도 많이 하고 좋네요', 5],
#  ['어디 보따리상들이 들어와서 장사를 하는지 몰라도 구입하고 결제 하면 품절이라고 환불되고 하나는 현지 바잉 시도중이라고 시간만 질질끌고동네 구멍가게도 이렇게 운영하면 망함',
#   8],
#  ['낚시질 짱 언제부턴가 작은게 싸고 큰게 비쌈ㅋ 차야 ㅋ 작은건 겁나 할인광고 큰건 돈 더 내놔ㅋ', 8],
#  ['여기 믿음직한 명품 쇼핑몰 백만번 고민하고 첫구매했는데 대만족입니다', 7],
#  ['판매자정보 정확하고 할인쿠폰도 마니주고 가격도 타싸이트에비해 좀더 저렴히 구입가능하네요', 5],
#  ['몬가 관리받는 느낌', 8],
#  ['아니 왜 리뷰를 삭제하지 일단 제품검색했을때 일단 가격비교를 하기힘들게 셀러들이 상품명을 엉망으로 올린다 세일많이하는것처럼 보일려고 오픈마켓보다 정사 훨씬비싼것 천지 정품 검수 어쩌고 자랑하지만 검수사진도 없거나 사진하나 달랑 떠있고 자체 상품설명 자세한 설명이 없는 상품이 대다수',
#   7],
#  ['아니 왜 리뷰를 삭제하지 일단 제품검색했을때 일단 가격비교를 하기힘들게 셀러들이 상품명을 엉망으로 올린다 세일많이하는것처럼 보일려고 오픈마켓보다 정사 훨씬비싼것 천지 정품 검수 어쩌고 자랑하지만 검수사진도 없거나 사진하나 달랑 떠있고 자체 상품설명 자세한 설명이 없는 상품이 대다수',
#   9],
#  ['판매자 관리좀 제대로 해주세요\n환불 불가한 상품이라 어쩔수 없이 손해보고 매물 내놨습니다', 8],
#  ['\n제품만 빨리 왔어도 환불 가능한 시스템만 잘 구축해놨어도 제가 손해를 봤을까요', 0],
#  ['\n요즘 명품 판매 하는 곳들 많아지는데 머스트잇은 앞으로 절대 사용 안할겁니다', 8],
#  ['유튜브에서 광고 보고 궁금해서 깔아봤는데 요거 괜찮은 앱 같네요 ㅎㅎ 일단 브랜드가 너무 많아서 좋아요', 3],
#  ['우영미 만원 올리는건 좀 아니지않나', 5],
#  ['별로', 8],
#  ['역시 믿고 사는 트렌비 정품 확실하니까 의심할 여지 없이 매번 구매하게 되네용', 7],
#  ['굳굳', 8],
#  ['한참 기다리게 해놓고 또 지연된다고 취소해준다고 했으면서 취소도 빠르지 않네요', 0],
#  ['대단하다 정말', 8],
#  ['환불도 주말에만 안들어온다면서 다른 쇼핑몰에서는 바로 바로 해주던대 온라인임에도 불구하고 환불을 하면 최소 일을 걸려서 환불을 해주고 예정일보다 배송이 늦어진 상품이 언제 오는지 자기네들도 모른다고 하네 ㅋㅋ',
#   0],
#  ['로그인 버튼이 안 눌려요', 4],
#  ['창이 넘어가질 않아요', 4],
#  ['좋아요', 8],
#  ['어플켤때 이엘 나오는거 못가리나요\n안그래도 요즘 말 많은데 내 핸드폰에서까지 봐야되나 싶어서요', 8],
#  ['정보도얻고 각격도좋고 자주사용중', 8],
#  ['최악임 프라다 로봇패치 버킷백 구매 햇으나 쓰레기가 옴 검수 상태 라고 해서 구매 검수사진에 없는 담배냄새 향수냄새바닥에 음식물 찌꺼기붙어잇고 안쪽안감 다 닳아잇음곳곳 기스 여러개발견 항의하니 트랜비는 책임이 없다함 썩을반품비내라함 ',
#   7],
#  ['그래쓰레기 장사 오래못갈듯해서 반품비주고 반품하고 탈퇴함절대사지마세요', 8],
#  ['트렌비 바로 판매하기 이용했는데 한번도 쓰지도않은 제품인데 상품미달이라길래 그럼 무슨등급이냐 했더니 그것도 안알려주고 계속 똑같은말만 반복 배송비 환불도 안해준다면서 제대로 된 설명은 없음 그래서 등급낮춰서 또 보냈는데 진행상황 알림이 없어서 들어가봤더니 판매취소저번에도 그러더니 두번째',
#   8],
#  ['일을 왜이렇게 합니까 고객센터 전화해서 문의했더니 고객센터도 상품미달이라고만 함 가품이라는거냐했더니 그건아니라고함 배송비환불해달라했더니 그건 어렵다고 함 ㅋㅋ 정확한 상품등급을 적어놓지도 않고 상품미달이라고 판매취소된건 바로 말해주지도 않고 반송보내면서 택배비환불도 안해준다는데 ㅆㄹㄱ같음 ',
#   2],
#  ['서비스란게 없음 이럴거면 위탁판매든 바로판매든 하지세요', 8],
#  ['정확한 기준이뭐고 뭐때문인지 설명을 해줘야지 그냥 기준미달이라고 반송해버리면 어떡합니까 \n진짜 트렌비 쓰지마세요', 9],
#  ['최악입니다', 8],
#  ['믿고 구매할수있는거같아요', 7],
#  ['선물하기도 좋아여', 8],
#  ['가방을 구매하고 다음날 문자 온게 검정 가방은 품절이니 다른 색 가방 안할거면 반품해라 라고 왔습니다', 3],
#  ['품절이면 사이트에는 왜 판매중이냐니까 아직 수정을 안해놨다네요', 9],
#  ['살수있는 가방이 없는데요', 3],
#  ['\n사과 안하시네요', 2],
#  ['잘 이용 중이에요 저는 직구의 직자도 모르던 사람이었는데 트렌비를 통해서 편하게 직구하고 있어요', 8],
#  ['근데 고가의 상품들을 사다보니 배송이 걱정되긴 했지만 집까지 무사히 도착하는걸 보고 마음이 놓이더라구요', 8],
#  ['믿음직스러워서 계속 이용하고있어요', 7],
#  ['다른 앱도 이용해보려고 했지만 트렌비가 제일 편하고', 1],
#  ['가격도 최저가부터 나오고 판매자가 누구인지 트렌비 인증 파트너인지도 볼 수 있으니까 좋았어요', 1],
#  ['세일도 자주 하고', 5],
#  ['제품군도 다양하니까 잘 구경해보세요', 3],
#  ['트렌비 추천해요 아 배송도 되게 빨라요', 0],
#  ['합리적 입니다', 5],
#  ['할인도 잘 해줘서 한번씩 잘 이용하고 있습니당', 5],
#  ['트렌비에는 상품 수도 많고', 3],
#  ['제가 좋아하는 디자이너 브랜드 상품이 많더라구요 넘 잘 쓰고 있어요', 3],
#  ['트렌비가 가성비 갑인듯합니다', 5],
#  ['백화점가면 실물로 확인 못하는 것들도 많은데 트렌비는 가짓수도 많고', 3],
#  ['저렴하게 살 수 있어서 정말 편하게 이용 중이에요', 5],
#  ['여행 갈때 데일리로 멜 가방이랑 신발 샀습니당 ㅎㅎㅎㅎ 트렌비  등급까지 도전 ㅎㅎ', 8],
#  ['아빠 생신 선물로 지갑 사드렸어요', 8],
#  ['더 좋은거 사드리고 싶지만 트렌비 덕분에 저렴하게 구입했어요', 5],
#  ['트렌비에서 샤넬 구매했어요', 8],
#  ['제 월급이 샤넬 가격을 따라잡질 못해서 영원히 못 만져볼 줄 알았는디 ㅎㅎ 이렇게 갖게되네요', 5],
#  ['다행히 ㅠㅠㅠ', 8],
#  ['트렌비가 할인도 많이 하지만 최근 시세도 쉽게 알수 있어서 가격 비교하기 좋더라구요 친구들한테도 추천하게 되네요', 5],
#  ['판매됐다고해서 보냈더니 갑자기 로고가 이상있다구여 그럼 판매신청할때 사진은 왜 올리고 그걸 검사하는데 몇일이나 걸리구요 그럼 그냥 신청들어오는 순서대로 확인만 누르시나보죠 일편하게 하시네요 신발이커서 박스까지 구매해서 보냈더니 박스비는 못준다구요 참나 그럼 저희는 박스비에 택배비에 수수료에 지금 장난합니까 처음부터 검수를 잘하세요 그렇게 일하시는 미안하지 않으신가요 제가 신발 안팔아도됩니다',
#   8],
#  ['근데 고객센터에서 메뉴얼데로 말씀하시는데 굉장히 불쾌하고 모든 지인들에게 트랜비에대해 이상황을 꼭 알리겠습니다', 2],
#  ['이거보시는 모든 판매자분들 한번더 생각해보세요 진짜 최악입니다', 8],
#  ['저별하나도 아깝네요', 8],
#  ['옷이든 신발이든 가방이든 저렴하게 구매할 수 있다는게 최고네요', 5],
#  ['ㅋㅋ 고가 상품의 경우 배송 서비스도 정말 잘 되어있어서 믿음이 가더라구요 트렌비는 제휴 수선점도 있어서 가방같은 경우에 수선 맡기기도 좋을것 같아요 챗봇 상담도 잘 되어있고 마음에 드는 상품 밑에 비슷한 스타일로 추천도 잘 해주고 되게 편했어요 국내외 백화점 편집샵에서 직바잉도 되고 감정사들이 따로 있어서 중고거래 할때도 걱정도 덜하구요 트렌비는 파워정품 명품 플랫폼답게 이용자들도 많아서 더 신뢰가요',
#   7],
#  ['목걸이 샀는데 이번 신상인데 할인이 꽤 많이 들어가네요', 5],
#  ['트렌비에서 사는게 최저가가 맞긴 한가봐요 ㅋㅋㅋ', 5],
#  ['디오니소스 너무 사고싶었는데 트렌비에서 구매했어요 추천해요', 3],
#  ['가성비 좋아요 너무 예뻐서 애지중지하는 중이에요', 5],
#  ['유명 브랜드 구경할 맛 나요', 3],
#  ['타임딜 같은 할인 잘 노리시면 득템 가능해요', 5],
#  ['아미 모자 너무 귀여워서 바로 득템했어요', 3],
#  ['ㅋㅋㅋ 트렌비는 할인율이 너무 좋은것 같아요', 5],
#  ['할인율 높아지면 바로 사게 되는 마법  저처럼 중독되지 마세요', 5],
#  ['트렌비에 제가 애정하는 브랜드가 많아서', 3],
#  ['배송도 되게 빠르고', 0],
#  ['고객센터 답변도 빠르고 만족했어요', 2],
#  ['얼마전에 남자친구 선물로 벨트 사줬는데 하자 없고 잘 왔어요', 6],
#  ['패션 잡화도 많이 팔아서 구경하기 좋은 어플이에요', 8],
#  ['배대지같은거 필요없어서 편하고 세일 자주해요', 5],
#  ['스톤아일랜드랑 메종 싸게 잘 샀네요', 5],
#  ['트렌비에서 부모님 선물도 사드리고 집들이 선물도 사네요 정작 저를 위한 선물은 아직  요즘 쇼핑몰들이 배송이 워낙 빠르지만은 직구인데도 익일배송이 된다는게 매우 편하고요',
#   0],
#  ['검수도 잘 해주셔서 아직 곤란했던 상황은 한번도 없었어요', 7],
#  ['이용해보시면 아시겠지만 기획전을 되게 다양하게 많이 해요 트렌비에서 구매하면 호갱 당할 일은 없는것 같아요 위시리스트에 넣어놓은거 몇 개 있는데 기획전에 뜨면 바로 사려고요',
#   5],
#  ['급하게 선물 준비할때는 익일배송으로 선택해서 보면 되니까 되게 편해요', 0],
#  ['어플에서 카테고리 보는것도 편리하게 잘 돼있고', 1],
#  ['할인만 기다리던 보테가 샀습니다', 5],
#  ['트렌비는 기획전을 항상 진행해줘서 좋습니다', 5],
#  ['트렌비에서 지인이랑 가족들 생일 선물 자주 사요 검수랑 배송도 꼼꼼하니 빨라서 좋아요', 7],
#  ['트렌비에서 지인이랑 가족들 생일 선물 자주 사요 검수랑 배송도 꼼꼼하니 빨라서 좋아요', 0],
#  ['트렌비에서 인기 상품만 봐도 어떤 스타일이 유행인지 알 수 있어서 재밌어요', 8],
#  ['해외 편집샵들이랑 연계돼있으니 저렴하게 구매할 수 있습니다', 5],
#  ['첫 샤넬 트렌비에서 구매ㅋㅋㅋ 카드지갑이지만 너무 예쁘고 맘에 들어요', 8],
#  ['ㅜㅜ 싸게 잘 샀어요', 5],
#  ...]

# %%
data
# Out:
#       platform   store        date  \
# 0       trenbe   apple  2023-02-02
# 1       trenbe   apple  2023-02-02
# 2       trenbe   apple  2023-02-02
# 3       trenbe  google  2023-02-01
# 4       trenbe  google  2023-02-01
# ...        ...     ...         ...
# 12644   balaan  google  2023-02-02
# 12645   balaan  google  2023-02-02
# 12646   balaan  google  2023-02-02
# 12647   trenbe   apple  2023-02-02
# 12648   trenbe   apple  2023-02-02
#
#                                                   review  rating   category  \
# 0                     월일에 주문에서 월일에 재고가 없어 환불처리 됐다고 통보하네요     1.0       고객센터
# 1      어이가없어서 여기 믿고 물건 구매해서 안심하고 기다리다 뒤통수 맞고 다시 물건 찾는...     1.0     정품 안전성
# 2                                            기다려도 물건 안와요     1.0         배송
# 3                                여기 상품반품비로 먹고사는 업체인것같습니다     1.0         배송
# 4                                                   나쁜놈들     1.0     만족도&기타
# ...                                                  ...     ...        ...
# 12644                  관부가세 포함되어서 추가 비용 없어 가격 계산하기도 편하네요     5.0  UX/UI 편의성
# 12645                    명품 브랜드 쇼핑할 때 아주 잘 사용하고 있는 어플입니다     5.0      상품 구색
# 12646  구찌 카드지갑 상자에 담겨서 잘 받았음 발란 더스트백에 한번 더 담아져서 깔끔했음 ...     5.0  UX/UI 편의성
# 12647   광고도 하고 믿을수 있겠다 싶어서 이곳에서 주문했는데 제가 경험한곳중에 제일 최악이에요     1.0     정품 안전성
# 12648                 월일에 주문에서 월일에 재고가 없어 환불처리 됐다고 통보하네요     1.0     만족도&기타
#
#        label  cate_label
# 0          0           2
# 1          0           7
# 2          0           0
# 3          0           0
# 4          0           8
# ...      ...         ...
# 12644      1           1
# 12645      1           3
# 12646      1           1
# 12647      0           7
# 12648      0           8
#
# [12644 rows x 8 columns]

# %%
data['year'] = data['date'].str.split('-', expand=True)[0]
data['month'] = data['date'].str.split('-', expand=True)[1]
data['day'] = data['date'].str.split('-', expand=True)[2]
data['y_month'] = data['year'] + '-' +  data['month']
data
# Out:
#       platform   store        date  \
# 0       trenbe   apple  2023-02-02
# 1       trenbe   apple  2023-02-02
# 2       trenbe   apple  2023-02-02
# 3       trenbe  google  2023-02-01
# 4       trenbe  google  2023-02-01
# ...        ...     ...         ...
# 12644   balaan  google  2023-02-02
# 12645   balaan  google  2023-02-02
# 12646   balaan  google  2023-02-02
# 12647   trenbe   apple  2023-02-02
# 12648   trenbe   apple  2023-02-02
#
#                                                   review  rating   category  \
# 0                     월일에 주문에서 월일에 재고가 없어 환불처리 됐다고 통보하네요     1.0       고객센터
# 1      어이가없어서 여기 믿고 물건 구매해서 안심하고 기다리다 뒤통수 맞고 다시 물건 찾는...     1.0     정품 안전성
# 2                                            기다려도 물건 안와요     1.0         배송
# 3                                여기 상품반품비로 먹고사는 업체인것같습니다     1.0         배송
# 4                                                   나쁜놈들     1.0     만족도&기타
# ...                                                  ...     ...        ...
# 12644                  관부가세 포함되어서 추가 비용 없어 가격 계산하기도 편하네요     5.0  UX/UI 편의성
# 12645                    명품 브랜드 쇼핑할 때 아주 잘 사용하고 있는 어플입니다     5.0      상품 구색
# 12646  구찌 카드지갑 상자에 담겨서 잘 받았음 발란 더스트백에 한번 더 담아져서 깔끔했음 ...     5.0  UX/UI 편의성
# 12647   광고도 하고 믿을수 있겠다 싶어서 이곳에서 주문했는데 제가 경험한곳중에 제일 최악이에요     1.0     정품 안전성
# 12648                 월일에 주문에서 월일에 재고가 없어 환불처리 됐다고 통보하네요     1.0     만족도&기타
#
#        label  cate_label  year month day  y_month
# 0          0           2  2023    02  02  2023-02
# 1          0           7  2023    02  02  2023-02
# 2          0           0  2023    02  02  2023-02
# 3          0           0  2023    02  01  2023-02
# 4          0           8  2023    02  01  2023-02
# ...      ...         ...   ...   ...  ..      ...
# 12644      1           1  2023    02  02  2023-02
# 12645      1           3  2023    02  02  2023-02
# 12646      1           1  2023    02  02  2023-02
# 12647      0           7  2023    02  02  2023-02
# 12648      0           8  2023    02  02  2023-02
#
# [12644 rows x 12 columns]

# %%
data['y_month'].unique()
# Out:
# array(['2023-02', '2023-01', '2022-12', '2022-11', '2022-10', '2022-09',
#        '2022-08', '2022-07', '2022-06', '2022-05', '2021-12', '2021-11',
#        '2021-10', '2021-09', '2021-08', '2021-07', '2021-06', '2021-05',
#        '2021-04', '2021-03', '2021-02', '2022-02', '2022-01', '2021-01',
#        '2020-11', '2020-10', '2020-09', '2020-08', '2020-07', '2020-06',
#        '2020-05', '2020-04', '2020-01', '2019-12', '2019-11', '2019-10',
#        '2019-09', '2019-08', '2019-07', '2019-06', '2019-05', '2019-04',
#        '2019-03', '2019-01', '2018-04', '2018-03', '2018-02', '2018-01',
#        '2017-09', '2014-12', '2014-10', '2023-09', '2023-08', '2023-07',
#        '2023-06', '2023-05', '2023-04', '2023-03'], dtype=object)

# %%
data_b = data[data['platform'] == 'balaan']
data_m = data[data['platform'] == 'mustit']
data_t = data[data['platform'] == 'trenbe']

# %% [markdown]
# - 리뷰 수

# %%
print('review len: ', data_b.groupby(['year'])['platform'].count().sum(), '/', len(data))
plt.figure(figsize=(12, 8))
data_b.groupby(['year'])['platform'].count().plot(kind='bar')
plt.show()
# Out:
# review len:  3540 / 12644

# %%
print('review len: ', data_m.groupby(['year'])['platform'].count().sum(), '/', len(data))
plt.figure(figsize=(12, 8))
data_m.groupby(['year'])['platform'].count().plot(kind='bar')
plt.show()
# Out:
# review len:  1307 / 12644

# %%
print('review len: ', data_t.groupby(['year'])['platform'].count().sum(), '/', len(data))
plt.figure(figsize=(12, 8))
data_t.groupby(['year'])['platform'].count().plot(kind='bar')
plt.show()
# Out:
# review len:  7797 / 12644

# %% [markdown]
# - 별점

# %%
plt.figure(figsize=(12, 8))
data_b.groupby(['rating'])['platform'].count().sort_index().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(12, 8))
data_m.groupby(['rating'])['platform'].count().sort_index().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(12, 8))
data_t.groupby(['rating'])['platform'].count().sort_index().plot(kind='bar')
plt.show()

# %%
data_b[data_b['rating'] == 5].groupby(['rating'])['platform'].count()
# Out:
# rating
# 5.0    2845
# Name: platform, dtype: int64

# %% [markdown]
# ### 날짜별 별점 수

# %% [markdown]
# - 발란

# %%
plt.figure(figsize=(30, 10))


plt.subplot(151)
data_b[data_b['rating'] == 5].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 5')


plt.subplot(152)
data_b[data_b['rating'] == 4].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 4')

plt.subplot(153)
data_b[data_b['rating'] == 3].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 3')

plt.subplot(154)
data_b[data_b['rating'] == 2].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 2')

plt.subplot(155)
data_b[data_b['rating'] == 1].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 1')

plt.show()

# %% [markdown]
# - 머스트 잇

# %%
plt.figure(figsize=(30, 10))


plt.subplot(151)
data_m[data_m['rating'] == 5].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 5')


plt.subplot(152)
data_m[data_m['rating'] == 4].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 4')

plt.subplot(153)
data_m[data_m['rating'] == 3].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 3')

plt.subplot(154)
data_m[data_m['rating'] == 2].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 2')

plt.subplot(155)
data_m[data_m['rating'] == 1].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 1')

plt.show()

# %% [markdown]
# - 트렌비

# %%
plt.figure(figsize=(30, 10))


plt.subplot(151)
data_t[data_t['rating'] == 5].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 5')


plt.subplot(152)
data_t[data_t['rating'] == 4].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 4')

plt.subplot(153)
data_t[data_t['rating'] == 3].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 3')

plt.subplot(154)
data_t[data_t['rating'] == 2].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 2')

plt.subplot(155)
data_t[data_t['rating'] == 1].groupby(['y_month'])['platform'].count().sort_index().plot()
plt.title('rating 1')

plt.show()

# %%
data['label'].value_counts().plot(kind='bar')
plt.gcf().set_size_inches(12, 8)
plt.show()

# %%
data_b['label'].value_counts().plot(kind='bar')
plt.gcf().set_size_inches(12, 8)
plt.show()

# %%
data_m['label'].value_counts().plot(kind='bar')
plt.gcf().set_size_inches(12, 8)
plt.show()

# %%
data_t['label'].value_counts().plot(kind='bar')
plt.gcf().set_size_inches(12, 8)
plt.show()

# %%
from matplotlib import rc
rc("font", family="Malgun Gothic")
get_ipython().run_line_magic("matplotlib", "inline")

# %%
po_or_ne = ['긍정', '부정']
data_b = [len(data_b[data_b['label'] == 1]), len(data_b[data_b['label'] == 0])]
data_m = [len(data_m[data_m['label'] == 1]), len(data_m[data_m['label'] == 0])]
data_t = [len(data_t[data_t['label'] == 1]), len(data_t[data_t['label'] == 0])]
my_colors_m = ['#fc4e4e', '#dedcdc']
my_colors_b = ['#404dff', '#dedcdc']
my_colors_t = ['#a849f5', '#dedcdc']

# %%
plt.figure(figsize= (15, 5))

plt.subplot(131)
plt.pie(data_m, labels=po_or_ne, autopct='%.1f%%', colors=my_colors_m)
plt.title("머스트잇")

plt.subplot(132)
plt.pie(data_b, labels=po_or_ne, autopct='%.1f%%', colors=my_colors_b)
plt.title("발란")

plt.subplot(133)
plt.pie(data_t, labels=po_or_ne, autopct='%.1f%%', colors=my_colors_t)
plt.title("트렌비")

plt.show()

# %%
data.groupby('cate_label').size().reset_index(name='count').set_index('cate_label')
# Out:
#             count
# cate_label
# 0            1030
# 1            1524
# 2             755
# 3            1432
# 4             738
# 5            2299
# 6             318
# 7            1137
# 8            3222
# 9             189

# %%
data['cate_label'].unique()
# Out:
# array([2, 7, 0, 8, 5, 9, 3, 6, 1, 4], dtype=int64)

# %%
data['category'].unique()
# Out:
# array(['고객센터', '정품 안전성', '배송', '만족도&기타', '가격&프로모션', '상품 설명', '상품 구색',
#        '상품 품질', 'UX/UI 편의성', '앱 오류'], dtype=object)

# %%
data['cate_label'].value_counts().plot(kind='bar')
plt.gcf().set_size_inches(12, 8)

# %%
data_b['cate_label'].value_counts().plot(kind='bar')
plt.gcf().set_size_inches(12, 8)

# %%
data_m['cate_label'].value_counts().plot(kind='bar')
plt.gcf().set_size_inches(12, 8)

# %%
data_t['cate_label'].value_counts().plot(kind='bar')
plt.gcf().set_size_inches(12, 8)

# %%
def get_TF(x):
    if x == 1:
        x = '긍정'
    else:
        x = '부정'
    
    return x

data['TF'] = data['label'].apply(get_TF)
data
# Out:
#       platform   store        date  \
# 0       trenbe   apple  2023-02-02
# 1       trenbe   apple  2023-02-02
# 2       trenbe   apple  2023-02-02
# 3       trenbe  google  2023-02-01
# 4       trenbe  google  2023-02-01
# ...        ...     ...         ...
# 12644   balaan  google  2023-02-02
# 12645   balaan  google  2023-02-02
# 12646   balaan  google  2023-02-02
# 12647   trenbe   apple  2023-02-02
# 12648   trenbe   apple  2023-02-02
#
#                                                   review  rating   category  \
# 0                     월일에 주문에서 월일에 재고가 없어 환불처리 됐다고 통보하네요     1.0       고객센터
# 1      어이가없어서 여기 믿고 물건 구매해서 안심하고 기다리다 뒤통수 맞고 다시 물건 찾는...     1.0     정품 안전성
# 2                                            기다려도 물건 안와요     1.0         배송
# 3                                여기 상품반품비로 먹고사는 업체인것같습니다     1.0         배송
# 4                                                   나쁜놈들     1.0     만족도&기타
# ...                                                  ...     ...        ...
# 12644                  관부가세 포함되어서 추가 비용 없어 가격 계산하기도 편하네요     5.0  UX/UI 편의성
# 12645                    명품 브랜드 쇼핑할 때 아주 잘 사용하고 있는 어플입니다     5.0      상품 구색
# 12646  구찌 카드지갑 상자에 담겨서 잘 받았음 발란 더스트백에 한번 더 담아져서 깔끔했음 ...     5.0  UX/UI 편의성
# 12647   광고도 하고 믿을수 있겠다 싶어서 이곳에서 주문했는데 제가 경험한곳중에 제일 최악이에요     1.0     정품 안전성
# 12648                 월일에 주문에서 월일에 재고가 없어 환불처리 됐다고 통보하네요     1.0     만족도&기타
#
#        label  cate_label  year month day  y_month  TF
# 0          0           2  2023    02  02  2023-02  부정
# 1          0           7  2023    02  02  2023-02  부정
# 2          0           0  2023    02  02  2023-02  부정
# 3          0           0  2023    02  01  2023-02  부정
# 4          0           8  2023    02  01  2023-02  부정
# ...      ...         ...   ...   ...  ..      ...  ..
# 12644      1           1  2023    02  02  2023-02  긍정
# 12645      1           3  2023    02  02  2023-02  긍정
# 12646      1           1  2023    02  02  2023-02  긍정
# 12647      0           7  2023    02  02  2023-02  부정
# 12648      0           8  2023    02  02  2023-02  부정
#
# [12644 rows x 13 columns]

# %%
data_balaan = data[data['platform'] == 'balaan']
data_trenbe = data[data['platform'] == 'trenbe']
data_mustit = data[data['platform'] == 'mustit']

# %%
import jpype
from konlpy.tag import Okt
from collections import Counter
import re
okt = Okt()

# %% [markdown]
# ### 머스트잇 워드클라우드

# %%
pos_reviews= data_mustit[data_mustit['label'] == 1]
neg_reviews= data_mustit[data_mustit['label'] == 0]

#-- 긍정 리뷰
pos_reviews['review'] = pos_reviews['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))
#-- 부정 리뷰
neg_reviews['review'] = neg_reviews['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))

# %%
pos_comment_nouns = []
for cmt in pos_reviews['review']:
    pos_comment_nouns.extend(okt.nouns(cmt)) #-- 명사만 추출
#-- 추출된 명사 중에서 길이가 1보다 큰 단어만 추출
pos_comment_nouns2 = []
word = [w for w in pos_comment_nouns if len(w) > 1]  
pos_comment_nouns2.extend(word)

# %%
#-- 긍정 리뷰 명사 추출
pos_comment_nouns = []
for cmt in pos_reviews['review']:
    pos_comment_nouns.extend(okt.nouns(cmt)) 

pos_comment_nouns2 = []
word = [w for w in pos_comment_nouns if len(w) > 1]  
pos_comment_nouns2.extend(word)
    
#-- 단어 빈도 계산
pos_word_count = Counter(pos_comment_nouns2)

# 제외할 단어 리스트
exclude_words = ['머스트잇', '머스트', '발란', '트렌비', '명품', '상품', '제품', '구매', '굿굿', '판매', '백화점', '진짜', '정말', '고민', '걱정', '최고', '사용', '다른', '자주', '마음', '플랫폼', '여기', '살수', '굿굿굿', '항상', '구입', '이용', '아주', '쇼핑', '물건', '만족', '어플', '사이트']

# Counter 객체 생성
pos_word_count = Counter(pos_comment_nouns2)

# 제외할 단어들을 반복문으로 확인하고 제거
for word in exclude_words:
    if word in pos_word_count:
        del pos_word_count[word]

#-- 빈도수가 많은 상위 50개 단어 추출
pos_top_50 = {}
max = 10
for word, counts in pos_word_count.most_common(max):
    pos_top_50[word] = counts
    print(f'{word} : {counts}')


#-- 그래프 작성
plt.figure(figsize=(10, 5))
plt.title('긍정 리뷰의 단어 상위 (%d개)' % max, fontsize=17)    
plt.ylabel('단어의 빈도수')    
plt.xticks(rotation=70)
for key, value in pos_top_50.items():
    plt.bar(key, value, color='lightgrey') 
plt.show()
# Out:
# 배송 : 71
# 가격 : 34
# 정품 : 17
# 보기 : 17
# 브랜드 : 16
# 검색 : 13
# 할인 : 12
# 생각 : 8
# 이벤트 : 8
# 애용 : 8

# %%
#-- 부정 리뷰 명사 추출
neg_comment_nouns = []
for cmt in neg_reviews['review']:
    neg_comment_nouns.extend(okt.nouns(cmt)) 

neg_comment_nouns2 = []
word = [w for w in neg_comment_nouns if len(w) > 1]  
neg_comment_nouns2.extend(word)
    
#-- 단어 빈도 계산
neg_word_count = Counter(neg_comment_nouns2)

# 제외할 단어 리스트
exclude_words = ['머스트잇', '머스트', '발란', '트렌비', '명품', '상품', '제품', '구매', '굿굿', '판매', '백화점', '진짜', '정말', '고민', '걱정', '최고', '사용', '이용', '아주', '쇼핑', '물건', '만족']

# Counter 객체 생성
neg_word_count = Counter(neg_comment_nouns2)

# 제외할 단어들을 반복문으로 확인하고 제거
for word in exclude_words:
    if word in neg_word_count:
        del neg_word_count[word]

#-- 빈도수가 많은 상위 50개 단어 추출
neg_top_50 = {}
for word, counts in neg_word_count.most_common(max):
    neg_top_50[word] = counts
    print(f'{word} : {counts}')


#-- 그래프 작성
plt.figure(figsize=(10, 5))
plt.title('부정 리뷰의 단어 상위 (%d개)' % max, fontsize=17)    
plt.ylabel('단어의 빈도수')    
plt.xticks(rotation=70)
for key, value in neg_top_50.items():
    plt.bar(key, value, color='lightgrey') 
plt.show()
# Out:
# 로그인 : 28
# 가격 : 26
# 계속 : 24
# 어플 : 21
# 배송 : 19
# 취소 : 18
# 광고 : 17
# 품절 : 16
# 확인 : 16
# 다시 : 16

# %%
from wordcloud import WordCloud
font_path = "C:/Windows/Fonts/malgun.ttf"

wc = WordCloud(font_path, background_color='white', colormap = 'OrRd', width=800, height=600)
cloud = wc.generate_from_frequencies(pos_word_count)
plt.figure(figsize=(12,12))
plt.title('긍정', fontsize=20)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
wc = WordCloud(font_path, background_color='ivory', width=800, height=600)
cloud = wc.generate_from_frequencies(neg_word_count)
plt.figure(figsize=(12,12))
plt.title('부정', fontsize=20)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 발란 워드클라우드

# %%
pos_reviews= data_balaan[data_balaan['label'] == 1]
neg_reviews= data_balaan[data_balaan['label'] == 0]

#-- 긍정 리뷰
pos_reviews['review'] = pos_reviews['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))
#-- 부정 리뷰
neg_reviews['review'] = neg_reviews['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))

# %%
#-- 긍정 리뷰 명사 추출
pos_comment_nouns = []
for cmt in pos_reviews['review']:
    pos_comment_nouns.extend(okt.nouns(cmt)) 

pos_comment_nouns2 = []
word = [w for w in pos_comment_nouns if len(w) > 1]  
pos_comment_nouns2.extend(word)
    
#-- 단어 빈도 계산
pos_word_count = Counter(pos_comment_nouns2)

# 제외할 단어 리스트
exclude_words = ['머스트잇', '머스트', '발란', '트렌비', '명품', '상품', '제품', '구매', '굿굿', '판매', '백화점', '진짜', '정말', '고민', '걱정', '최고', '사용', '이용', '아주', '쇼핑', '물건', '만족']

# Counter 객체 생성
pos_word_count = Counter(pos_comment_nouns2)

# 제외할 단어들을 반복문으로 확인하고 제거
for word in exclude_words:
    if word in pos_word_count:
        del pos_word_count[word]

#-- 빈도수가 많은 상위 50개 단어 추출
pos_top_50 = {}
for word, counts in pos_word_count.most_common(max):
    pos_top_50[word] = counts
    print(f'{word} : {counts}')


#-- 그래프 작성
plt.figure(figsize=(10, 5))
plt.title('긍정 리뷰의 단어 상위 (%d개)' % max, fontsize=17)    
plt.ylabel('단어의 빈도수')    
plt.xticks(rotation=70)
for key, value in pos_top_50.items():
    plt.bar(key, value, color='lightgrey') 
plt.show()
# Out:
# 가격 : 279
# 배송 : 259
# 정품 : 142
# 쿠폰 : 140
# 브랜드 : 109
# 할인 : 106
# 최저 : 80
# 비교 : 77
# 직구 : 77
# 여기 : 77

# %%
#-- 부정 리뷰 명사 추출
neg_comment_nouns = []
for cmt in neg_reviews['review']:
    neg_comment_nouns.extend(okt.nouns(cmt)) 

neg_comment_nouns2 = []
word = [w for w in neg_comment_nouns if len(w) > 1]  
neg_comment_nouns2.extend(word)
    
#-- 단어 빈도 계산
neg_word_count = Counter(neg_comment_nouns2)

# 제외할 단어 리스트
exclude_words = ['머스트잇', '머스트', '발란', '트렌비', '명품', '상품', '제품', '구매', '굿굿', '판매', '백화점', '진짜', '정말', '고민', '걱정', '최고', '사용', '이용', '아주', '쇼핑', '물건', '만족']

# Counter 객체 생성
neg_word_count = Counter(neg_comment_nouns2)

# 제외할 단어들을 반복문으로 확인하고 제거
for word in exclude_words:
    if word in neg_word_count:
        del neg_word_count[word]

#-- 빈도수가 많은 상위 50개 단어 추출
neg_top_50 = {}
for word, counts in neg_word_count.most_common(max):
    neg_top_50[word] = counts
    print(f'{word} : {counts}')


#-- 그래프 작성
plt.figure(figsize=(10, 5))
plt.title('부정 리뷰의 단어 상위 (%d개)' % max, fontsize=17)    
plt.ylabel('단어의 빈도수')    
plt.xticks(rotation=70)
for key, value in neg_top_50.items():
    plt.bar(key, value, color='lightgrey') 
plt.show()
# Out:
# 취소 : 77
# 배송 : 64
# 결제 : 64
# 어플 : 62
# 고객 : 58
# 리뷰 : 50
# 반품 : 49
# 만원 : 48
# 주문 : 47
# 광고 : 46

# %%
wc = WordCloud(font_path, background_color='white', colormap = 'OrRd', width=800, height=600)
cloud = wc.generate_from_frequencies(pos_word_count)
plt.figure(figsize=(12, 12))
plt.title('긍정', fontsize=20)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
wc = WordCloud(font_path, background_color='ivory', width=800, height=600)
cloud = wc.generate_from_frequencies(neg_word_count)
plt.figure(figsize=(12, 12))
plt.title('부정', fontsize=20)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 트렌비 워드클라우드

# %%
pos_reviews= data_trenbe[data_trenbe['label'] == 1]
neg_reviews= data_trenbe[data_trenbe['label'] == 0]

#-- 긍정 리뷰
pos_reviews['review'] = pos_reviews['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))
#-- 부정 리뷰
neg_reviews['review'] = neg_reviews['review'].apply(lambda x: re.sub(r'[^ㄱ-ㅣ가-힝+]', ' ', x))

# %%
pos_comment_nouns = []
for cmt in pos_reviews['review']:
    pos_comment_nouns.extend(okt.nouns(cmt)) #-- 명사만 추출
#-- 추출된 명사 중에서 길이가 1보다 큰 단어만 추출
pos_comment_nouns2 = []
word = [w for w in pos_comment_nouns if len(w) > 1]  
pos_comment_nouns2.extend(word)

# %%
#-- 긍정 리뷰 명사 추출
pos_comment_nouns = []
for cmt in pos_reviews['review']:
    pos_comment_nouns.extend(okt.nouns(cmt)) 

pos_comment_nouns2 = []
word = [w for w in pos_comment_nouns if len(w) > 1]  
pos_comment_nouns2.extend(word)
    
#-- 단어 빈도 계산
pos_word_count = Counter(pos_comment_nouns2)

# 제외할 단어 리스트
exclude_words = ['머스트잇', '머스트', '발란', '트렌비', '명품', '상품', '제품', '구매', '굿굿', '판매', '백화점', '진짜', '정말', '고민', '걱정', '최고', '사용', '다른', '자주', '마음', '플랫폼', '여기', '살수', '굿굿굿', '항상', '구입', '이용', '아주', '쇼핑', '물건', '만족', '어플', '사이트']

# Counter 객체 생성
pos_word_count = Counter(pos_comment_nouns2)

# 제외할 단어들을 반복문으로 확인하고 제거
for word in exclude_words:
    if word in pos_word_count:
        del pos_word_count[word]

#-- 빈도수가 많은 상위 50개 단어 추출
pos_top_50 = {}
max = 10
for word, counts in pos_word_count.most_common(max):
    pos_top_50[word] = counts
    print(f'{word} : {counts}')


#-- 그래프 작성
plt.figure(figsize=(10, 5))
plt.title('긍정 리뷰의 단어 상위 (%d개)' % max, fontsize=17)    
plt.ylabel('단어의 빈도수')    
plt.xticks(rotation=70)
for key, value in pos_top_50.items():
    plt.bar(key, value, color='lightgrey') 
plt.show()
# Out:
# 가격 : 750
# 배송 : 604
# 할인 : 457
# 브랜드 : 450
# 정품 : 425
# 비교 : 276
# 하나 : 265
# 생각 : 228
# 해외 : 218
# 가방 : 215

# %%
#-- 부정 리뷰 명사 추출
neg_comment_nouns = []
for cmt in neg_reviews['review']:
    neg_comment_nouns.extend(okt.nouns(cmt)) 

neg_comment_nouns2 = []
word = [w for w in neg_comment_nouns if len(w) > 1]  
neg_comment_nouns2.extend(word)
    
#-- 단어 빈도 계산
neg_word_count = Counter(neg_comment_nouns2)

# 제외할 단어 리스트
exclude_words = ['머스트잇', '머스트', '발란', '트렌비', '명품', '상품', '제품', '구매', '굿굿', '판매', '백화점', '진짜', '정말', '고민', '걱정', '최고', '사용', '이용', '아주', '쇼핑', '물건', '만족']

# Counter 객체 생성
neg_word_count = Counter(neg_comment_nouns2)

# 제외할 단어들을 반복문으로 확인하고 제거
for word in exclude_words:
    if word in neg_word_count:
        del neg_word_count[word]

#-- 빈도수가 많은 상위 50개 단어 추출
neg_top_50 = {}
for word, counts in neg_word_count.most_common(max):
    neg_top_50[word] = counts
    print(f'{word} : {counts}')


#-- 그래프 작성
plt.figure(figsize=(10, 5))
plt.title('부정 리뷰의 단어 상위 (%d개)' % max, fontsize=17)    
plt.ylabel('단어의 빈도수')    
plt.xticks(rotation=70)
for key, value in neg_top_50.items():
    plt.bar(key, value, color='lightgrey') 
plt.show()
# Out:
# 업데이트 : 143
# 고객 : 120
# 취소 : 117
# 배송 : 111
# 환불 : 105
# 계속 : 103
# 주문 : 92
# 센터 : 91
# 반품 : 90
# 화면 : 80

# %%
wc = WordCloud(font_path, background_color='white', colormap = 'OrRd', width=800, height=600)
cloud = wc.generate_from_frequencies(pos_word_count)
plt.figure(figsize=(12, 12))
plt.title('부정', fontsize=20)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
wc = WordCloud(font_path, background_color='ivory', width=800, height=600)
cloud = wc.generate_from_frequencies(neg_word_count)
plt.figure(figsize=(12, 12))
plt.title('부정', fontsize=20)
plt.imshow(cloud)
plt.axis('off')
plt.show()
